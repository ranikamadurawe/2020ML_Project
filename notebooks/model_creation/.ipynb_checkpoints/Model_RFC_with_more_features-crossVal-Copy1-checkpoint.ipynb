# %% [markdown]
# <h1>Imports</h1>

# %%
from pathlib import Path

import numpy as np
import sklearn as slearn
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import fbeta_score
from sklearn.metrics import classification_report

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.utils.class_weight import compute_class_weight

from imblearn.combine import SMOTETomek

import glob
import os
# Out:
# Using TensorFlow backend.

# %%
pd.set_option("display.max_columns", 100)
# %matplotlib inline

# %%
RANDOM_SEED = 6

# %% [markdown]
# <h1>Dataset Importing</h1>

# %%
DATA_PATH = Path.cwd() / "../../datasets"

# %%
training_df = pd.read_csv(DATA_PATH / "train.csv", index_col="tripid")
training_df.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0              0.0000
# 189125358             10.5     791.0           47.0              0.0000
# 189125719             10.5    1087.0           80.0              0.0000
# 189127273             10.5     598.0          271.0             15.6638
# 189128020              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup     pickup_time       drop_time  \
# tripid
# 189123628                       64.0  11/1/2019 0:20  11/1/2019 0:34
# 189125358                      134.0  11/1/2019 0:56  11/1/2019 1:09
# 189125719                       61.0  11/1/2019 1:08  11/1/2019 1:26
# 189127273                       68.0  11/1/2019 2:27  11/1/2019 2:37
# 189128020                        NaN  11/1/2019 3:34  11/1/2019 3:51
#
#            pick_lat  pick_lon  drop_lat  drop_lon    fare    label
# tripid
# 189123628   6.86252   79.8993   6.90330   79.8783  270.32  correct
# 189125358   6.88589   79.8984   6.91373   79.8923  197.85  correct
# 189125719   6.90839   79.8651   6.93669   79.9146  301.64  correct
# 189127273   6.92570   79.8895   6.92748   79.8971   82.30  correct
# 189128020   6.87441   79.8615   6.84478   79.9290  358.39  correct

# %%
training_df['fare'] = training_df['fare'].fillna(0)

# %%
training_df[training_df['fare'] == 0]
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189157607             10.5    2956.0         1686.0             97.4508
# 189164806             10.5    3549.0         2689.0            146.9854
# 189164831              NaN       NaN            NaN                 NaN
# 190066074              NaN       NaN            NaN                 NaN
# 190111701              NaN       NaN            NaN                 NaN
# 190144719              NaN       NaN            NaN                 NaN
# 190243365              NaN       NaN            NaN                 NaN
# 190284995              NaN       NaN            NaN                 NaN
# 190398300              NaN       NaN            NaN                 NaN
# 190584973              NaN       NaN            NaN                 NaN
# 190793611              NaN       NaN            NaN                 NaN
# 190999290              NaN       NaN            NaN                 NaN
# 191251150              NaN       NaN            NaN                 NaN
# 191255869              NaN       NaN            NaN                 NaN
# 191263471              5.0      39.0           19.0              1.1077
# 191331013              NaN       NaN            NaN                 NaN
# 191444740              0.0    2505.0          538.0              0.0000
# 191568349              NaN       NaN            NaN                 NaN
# 191674103              NaN       NaN            NaN                 NaN
# 191838640              0.0    1404.0          310.0              0.0000
# 191839729              NaN       NaN            NaN                 NaN
# 191840284              0.0    2699.0          340.0              0.0000
# 191841099              0.0    2446.0          840.0              0.0000
# 191839931              0.0    1837.0          194.0              0.0000
# 191838505              0.0    2652.0          326.0              0.0000
# 191847685              0.0    2225.0          349.0              0.0000
# 191857740              0.0    2260.0          232.0              0.0000
# 191860971              NaN       NaN            NaN                 NaN
# 191873008              0.0     861.0           28.0              0.0000
# 192087257              NaN       NaN            NaN                 NaN
# ...                    ...       ...            ...                 ...
# 211850466              NaN       NaN            NaN                 NaN
# 211886110              NaN       NaN            NaN                 NaN
# 211907371              NaN       NaN            NaN                 NaN
# 212002913              NaN       NaN            NaN                 NaN
# 212006160              NaN       NaN            NaN                 NaN
# 212149385              NaN       NaN            NaN                 NaN
# 212252918              NaN       NaN            NaN                 NaN
# 212253021              NaN       NaN            NaN                 NaN
# 212281673              NaN       NaN            NaN                 NaN
# 212531957              NaN       NaN            NaN                 NaN
# 212654053              NaN       NaN            NaN                 NaN
# 212713786              NaN       NaN            NaN                 NaN
# 212725065              NaN       NaN            NaN                 NaN
# 212885786              NaN       NaN            NaN                 NaN
# 212960160              NaN       NaN            NaN                 NaN
# 212968291              NaN       NaN            NaN                 NaN
# 212969874              NaN       NaN            NaN                 NaN
# 213112837              0.0       0.0            0.0              0.0000
# 213169867              NaN       NaN            NaN                 NaN
# 213203232              NaN       NaN            NaN                 NaN
# 213241611              NaN       NaN            NaN                 NaN
# 213258442              NaN       NaN            NaN                 NaN
# 213310572              NaN       NaN            NaN                 NaN
# 213394162              NaN       NaN            NaN                 NaN
# 213439115              NaN       NaN            NaN                 NaN
# 213449192              NaN       NaN            NaN                 NaN
# 213510465              NaN       NaN            NaN                 NaN
# 213538831              NaN       NaN            NaN                 NaN
# 213674502              NaN       NaN            NaN                 NaN
# 213758346              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup       pickup_time         drop_time  \
# tripid
# 189157607                       29.0    11/1/2019 8:40    11/1/2019 9:21
# 189164806                       69.0    11/1/2019 9:16    11/1/2019 9:29
# 189164831                        NaN    11/1/2019 9:17    11/1/2019 9:25
# 190066074                        NaN   11/5/2019 16:49   11/5/2019 17:01
# 190111701                        NaN   11/5/2019 21:13   11/5/2019 21:15
# 190144719                        NaN    11/6/2019 7:39    11/6/2019 7:40
# 190243365                        NaN   11/6/2019 17:23   11/6/2019 17:47
# 190284995                        NaN   11/6/2019 19:22   11/6/2019 19:49
# 190398300                        NaN   11/7/2019 13:54   11/7/2019 14:31
# 190584973                        NaN    11/8/2019 9:24   11/8/2019 10:03
# 190793611                        NaN   11/8/2019 17:55   11/8/2019 17:55
# 190999290                        NaN   11/9/2019 16:11   11/9/2019 17:33
# 191251150                        NaN   11/11/2019 9:07   11/11/2019 9:52
# 191255869                        NaN   11/11/2019 9:57  11/11/2019 10:22
# 191263471                        0.0  11/11/2019 11:00  11/11/2019 11:09
# 191331013                        NaN  11/11/2019 17:23  11/11/2019 17:56
# 191444740                      163.0  11/12/2019 16:14  11/12/2019 16:56
# 191568349                        NaN  11/13/2019 11:53  11/13/2019 12:10
# 191674103                        NaN  11/13/2019 18:43  11/13/2019 21:22
# 191838640                      144.0   11/14/2019 8:17   11/14/2019 8:41
# 191839729                        NaN   11/14/2019 8:18   11/14/2019 9:15
# 191840284                      322.0   11/14/2019 8:23   11/14/2019 9:08
# 191841099                      231.0   11/14/2019 8:25   11/14/2019 9:06
# 191839931                      402.0   11/14/2019 8:27   11/14/2019 8:57
# 191838505                        6.0   11/14/2019 8:28   11/14/2019 9:12
# 213439115   6.89366   79.9241   6.83812   79.9323   0.0  incorrect
# 213449192   6.88183   79.8577   6.84729   79.8734   0.0  incorrect
# 213510465   6.92600   79.8681   6.92596   79.8679   0.0  incorrect
# 213538831   6.70807   79.9125   6.70815   79.9127   0.0  incorrect
# 213674502   6.87969   79.8597   6.97458   79.9380   0.0  incorrect
# 213758346   6.93046   79.8903   6.91713   79.8910   0.0  incorrect
#
# [151 rows x 13 columns]

# %% [markdown]
# <h1>Data Preprocessing</h1>

# %% [markdown]
# <h2>Data Conversions</h2>

# %%
# Converting date time objects from Objects to datetime64
training_df['pickup_time'] = pd.to_datetime(training_df['pickup_time'], format="%m/%d/%Y %H:%M")
training_df['drop_time'] = pd.to_datetime(training_df['drop_time'], format="%m/%d/%Y %H:%M")

# %% [markdown]
# <h2>Adding Features</h2>
# Adding features deemed useful from Feature Engineering

# %%
durations = []
for index,row in training_df.iterrows():
  provided_duration = row['duration'] #first row of location.lat column here
  if math.isnan(provided_duration) or provided_duration <= 0 :
    time_dif = (row['drop_time'] - row['pickup_time']).seconds
    if(time_dif == 0):
        time_dif = np.nan
    durations.append(time_dif)
  else :  
    durations.append(provided_duration)

training_df.insert(4,"time_dif",durations)

# %%
def dist_from_coordinates(lat1, lon1, lat2, lon2):
  R = 6371  # Earth radius in km

  #conversion to radians
  d_lat = np.radians(lat2-lat1)
  d_lon = np.radians(lon2-lon1)

  r_lat1 = np.radians(lat1)
  r_lat2 = np.radians(lat2)

  #haversine formula
  a = np.sin(d_lat/2.) **2 + np.cos(r_lat1) * np.cos(r_lat2) * np.sin(d_lon/2.)**2

  haversine = 2 * R * np.arcsin(np.sqrt(a))

  return haversine

# %%
training_df = training_df.assign(timeOfDay=pd.cut(training_df.pickup_time.dt.hour,[-1, 8, 20, 24],labels=['dawn','day', 'night']))

# %%
new_column = []                    #empty column for distance
for index,row in training_df.iterrows():
  lat1 = row['pick_lat'] #first row of location.lat column here
  lon1 = row['pick_lon'] #first row of location.long column here
  lat2 = row['drop_lat'] #second row of location.lat column here
  lon2 = row['drop_lon'] #second row of location.long column here
  value = dist_from_coordinates(lat1, lon1, lat2, lon2)  #get the distance
  new_column.append(value)   #append the empty list with distance values

training_df.insert(4,"distance",new_column)

# %%
training_df['time_driven'] = training_df['duration']  - training_df['meter_waiting']

# %%
training_df['charge_per_hour'] = training_df['meter_waiting_fare'] / training_df['meter_waiting'] * 3600

# %%
training_df['driving_fare'] = training_df['fare']  - training_df['meter_waiting_fare'] - training_df['additional_fare']

# %%
avgspeeds = []
for index,row in training_df.iterrows():
    if(row['time_driven'] == 0):
        if( row['label'] == 'correct'):
            avgspeed = np.nan
        else:
            avgspeed = 0
    else:
        avgspeed = (row['distance'] / row['time_driven'])
    avgspeeds.append(avgspeed)

training_df.insert(4,"avg_speed",avgspeeds)

# %%
costsperkm = []
for index,row in training_df.iterrows():
    if row['driving_fare'] == 0:
        if( row['label'] == 'correct'):
            costperkm = np.nan
        else:
            costperkm = 0
    else:
        costperkm = (row['distance'] / row['driving_fare'])
    costsperkm.append(costperkm)

training_df.insert(4,"cost_per_km",costsperkm)

# %%
training_df = training_df.drop(index=190167541)

# %%
training_df.nlargest(100,'avg_speed')
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
#
# 197013051       day          2.0             0.00      399.8800
# 210552623      dawn          2.0             0.00      380.4100
# 200154190     night          3.0             0.00      540.9900
# 211764856       day          2.0             0.00      341.4200
# 197050724       day          2.0             0.00      391.9400
# 209972600      dawn          3.0             0.00       56.0500
# 198793721       day          2.0             0.00      324.1300
# 213412611       day          2.0             0.00       50.0000
# 210202123       day          3.0             0.00      510.1000
# ...             ...          ...              ...           ...
# 208055298       day          3.0             0.00       50.0000
# 206766239       day          2.0             0.00       50.0000
# 204932258       day          1.0           209.88       49.9927
# 207887491       day          2.0             0.00       50.0000
# 211078046       day          4.0             0.00       50.0000
# 212064554      dawn          2.0             0.00       50.0000
# 195284371      dawn         13.0             0.00       96.0200
# 212931727      dawn          3.0             0.00       50.0000
# 210591969       day          3.0             0.00      215.3700
# 202727581     night          2.0             0.00       50.0000
# 189734544       day          9.0             0.00      642.3600
# 195269699     night          7.0             0.00      466.1800
# 213337125       day          2.0             0.00       50.0000
# 202702798     night          3.0             0.00       50.0000
# 211164631       day          2.0             0.00      171.7400
# 201108278      dawn          2.0             0.00       50.0000
# 192471577       day          7.0             0.00      522.6600
# 193164831       day          3.0             0.00      240.6000
# 207616164       day          4.0           209.88       49.9959
# 201654842       day          7.0             0.00       50.5000
# 210468314       day          3.0             0.00       50.0000
# 190947488       day          6.0             0.00      371.0800
# 190044131       day          5.0             0.00      316.2700
# 213620129       day          2.0             0.00       50.0000
# 204197239      dawn          2.0           209.88       49.9993
# 189326852     night          6.0             0.00      384.1200
# 191513790      dawn          8.0             0.00      491.0200
# 192459342       day         11.0             0.00      674.7100
# 197506698     night          3.0             0.00       50.0000
# 212826449       day          5.0             0.00      347.5500
#
# [100 rows x 21 columns]

# %% [markdown]
# <h1>Model Training</h1>

# %%
# Set of new columns
new_columns = ['additional_fare', 'time_dif', 'meter_waiting', 'meter_waiting_fare',
       'meter_waiting_till_pickup','distance','avg_speed','fare',"cost_per_km",'charge_per_hour','time_driven','driving_fare']

# %%
# Extract the useful features deemed in feature engineering
features_classifier = training_df[new_columns]
label_classifier = training_df[['label']]
mapping = {'correct': 1, 'incorrect': 0}
label_classifier = label_classifier.replace({'label':mapping})

# %%
features_classifier.dtypes
# Out:
# additional_fare              float64
# time_dif                     float64
# meter_waiting                float64
# meter_waiting_fare           float64
# meter_waiting_till_pickup    float64
# distance                     float64
# avg_speed                    float64
# fare                         float64
# cost_per_km                  float64
# charge_per_hour              float64
# time_driven                  float64
# driving_fare                 float64
# dtype: object

# %%
numerical_features = features_classifier.columns[features_classifier.dtypes == "float64"].values
categorical_features = features_classifier.columns[features_classifier.dtypes == "category" ].values

# %%
kf = StratifiedKFold(n_splits=10)

# %%
numeric_preprocessing_steps = Pipeline([
    ('simple_imputer', SimpleImputer(strategy='median'))
])

non_numeric_preprocessing_steps = Pipeline([
    ('simple_imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot_encoder', OneHotEncoder(handle_unknown='ignore')),
#     ('label_encoder', LabelEncoder())
])

## create preprocessor stage of the final pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('non_numeric', non_numeric_preprocessing_steps, categorical_features),
        ('numeric', numeric_preprocessing_steps, numerical_features)
    ],
    remainder = 'drop'
)

# %%
X_train, X_eval, y_train, y_eval = train_test_split(features_classifier, label_classifier, test_size=0.3, shuffle=True,stratify=label_classifier)

# %%
classifier = RandomForestClassifier(random_state=42, class_weight='balanced')

# %%
for train_index, test_index in kf.split(X_train,y_train):
    X_train_fold, X_eval_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    y_train_fold, y_eval_fold = y_train.iloc[train_index], y_train.iloc[test_index]
    # Transform training data columns 
    preprocessed_train_features = preprocessor.fit_transform(X_train_fold)
    preprocessed_train_features_data_frame = pd.DataFrame(data=preprocessed_train_features, columns=new_columns)
    
    
    ## Train the model
    classifier.fit(preprocessed_train_features_data_frame, y_train_fold)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.

# %%
preprocessed_test_features = preprocessor.fit_transform(X_eval)
preprocessed_test_features_data_frame = pd.DataFrame(data=preprocessed_test_features, columns=new_columns)

# %%
# Predict for the evaluation set
print("Training Accuracy: %.2f" % (classifier.score(preprocessed_test_features_data_frame, y_eval)*100), "%")
y_pred = classifier.predict(preprocessed_test_features_data_frame)
# Out:
# Training Accuracy: 95.30 %

# %%
classifier.fit(preprocessed_test_features_data_frame, y_eval)

# %%
classifier.fit(preprocessed_train_features_data_frame, y_train_fold)(pd.Series(classifier.feature_importances_, index=new_columns)
   .nlargest(30)
   .plot(kind='barh'))

# %%
confusion_matrix = confusion_matrix(y_eval, y_pred)
confusion_matrix
# Out:
# array([[ 316,  188],
#        [  54, 4595]])

# %%
print(classification_report(y_eval, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.63      0.72       504
#            1       0.96      0.99      0.97      4649
#
#     accuracy                           0.95      5153
#    macro avg       0.91      0.81      0.85      5153
# weighted avg       0.95      0.95      0.95      5153

# %% [markdown]
# <h1>Model Validation</h1>

# %% [markdown]
# <h2>Loading the test data set</h2>

# %%
test_set = pd.read_csv(DATA_PATH / "test.csv", index_col="tripid")
test_set.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 213284604             10.5       924             42              2.4486
# 213286352             10.5      4249             20              0.0000
# 213293973             10.5      1552            255              2.6588
# 213294622             10.5       462             16              0.0000
# 213298687             10.5       814            392             12.3692
#
#            meter_waiting_till_pickup    pickup_time      drop_time  pick_lat  \
# tripid
# 213284604                        148  2/1/2020 0:38  2/1/2020 0:53   6.83454
# 213286352                         91  2/1/2020 1:02  2/1/2020 2:13   6.91168
# 213293973                         23  2/1/2020 5:02  2/1/2020 5:28   6.92145
# 213294622                        198  2/1/2020 5:30  2/1/2020 5:38   6.77433
# 213298687                         69  2/1/2020 7:00  2/1/2020 7:14   6.97968
#
#            pick_lon  drop_lat  drop_lon     fare
# tripid
# 213284604   79.8750   6.77490   79.8840   289.27
# 213286352   79.8723   6.55091   79.9706  1912.70
# 213293973   79.8478   6.90539   79.8989   394.00
# 213294622   79.9416   6.80401   79.9407   154.32
# 213298687   79.9130   6.98875   79.8914   147.47

# %%
test_set.isna().sum()
# Out:
# additional_fare              0
# duration                     0
# meter_waiting                0
# meter_waiting_fare           0
# meter_waiting_till_pickup    0
# pickup_time                  0
# drop_time                    0
# pick_lat                     0
# pick_lon                     0
# drop_lat                     0
# drop_lon                     0
# fare                         0
# dtype: int64

# %% [markdown]
# <h2>Feature Addition for the Test Dataset</h2>

# %%
test_set['pickup_time'] = pd.to_datetime(test_set['pickup_time'], format="%m/%d/%Y %H:%M")
test_set['drop_time'] = pd.to_datetime(test_set['drop_time'], format="%m/%d/%Y %H:%M")

# %%
test_set = test_set.assign(timeOfDay=pd.cut(test_set.pickup_time.dt.hour,[-1, 8, 20, 24],labels=['dawn','day', 'night']))

# %%
new_column = []                    #empty column for distance
for index,row in test_set.iterrows():
  lat1 = row['pick_lat'] #first row of location.lat column here
  lon1 = row['pick_lon'] #first row of location.long column here
  lat2 = row['drop_lat'] #second row of location.lat column here
  lon2 = row['drop_lon'] #second row of location.long column here
  value = dist_from_coordinates(lat1, lon1, lat2, lon2)  #get the distance
  new_column.append(value)   #append the empty list with distance values

test_set .insert(4,"distance",new_column)

# %%
test_set['driving_fare'] = test_set['fare']  - test_set['meter_waiting_fare'] - test_set['additional_fare']

# %%
costsperkm = []
for index,row in test_set.iterrows():
    if row['driving_fare'] == 0:
        costperkm = 0 
    else:
        costperkm = (row['distance'] / row['driving_fare'])
    costsperkm.append(costperkm)

test_set.insert(4,"cost_per_km",costsperkm)

# %%
durations = []
for index,row in test_set.iterrows():
  provided_duration = row['duration'] #first row of location.lat column here
  if math.isnan(provided_duration) or provided_duration <= 0 :
    time_dif = (row['drop_time'] - row['pickup_time']).seconds
    if(time_dif == 0):
        time_dif = np.nan
    durations.append(time_dif)
  else :  
    durations.append(provided_duration)

test_set.insert(4,"time_dif",durations)

# %%
test_set['time_driven'] = test_set['duration']  - test_set['meter_waiting']

# %%
avgspeeds = []
for index,row in test_set.iterrows():
    avgspeed = 0
    avgspeeds.append(avgspeed)

test_set.insert(4,"avg_speed",avgspeeds)

# %%
test_set['charge_per_hour'] = test_set['meter_waiting_fare'] / test_set['meter_waiting'] * 3600

# %%
test_set
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 213284604             10.5       924             42            2.448600
# 213286352             10.5      4249             20            0.000000
# 213293973             10.5      1552            255            2.658800
# 213294622             10.5       462             16            0.000000
# 213298687             10.5       814            392           12.369200
# 213299545             10.5      2495            351           16.530800
# 213302332             10.5      1108            454           23.929200
# 213302671             10.5      2737            320           18.496000
# 213305594             10.5      1154             29            0.000000
# 213305134             10.5      1372            277           16.046498
# 213306304             10.5      2808            760           44.308000
# 213308616             10.5       780             54            3.148200
# 213309839             10.5      5632           1186           68.580489
# 213310068             10.5       368              3            0.000000
# 213309032             10.5      1028            154            8.901200
# 213310105             10.5      1677            101            0.000000
# 213311364             10.5      1505             84            0.000000
# 213309929             10.5      1742            119            6.924990
# 213310221             10.5      1612             70            0.000000
# 213312453             10.5       500             36            0.000000
# 213313921             30.5      1334            213            0.000000
# 213314038             10.5       712            134            0.000000
# 213314867             10.5       363             10            0.000000
# 213316124              5.0       261             32            1.865600
# 213315491             10.5       932            321            0.000000
# 213315522             10.5       872             48            2.774400
# 213317715              5.0       277              0            0.000000
# 213316458             10.5      1554              4            0.000000
# 213316409             10.5      2832            629            0.000000
# 213317742             10.5       273             28            1.618400
# ...                    ...       ...            ...                 ...
# 213312453   6.85062   79.9542   6.84118   79.9754   144.29      dawn
# 213313921   6.84587   79.9286   6.81980   79.8733   304.52      dawn
# 213314038   6.83821   79.8959   6.84453   79.9248   145.51      dawn
# 213314867   7.48130   80.6225   7.46458   80.6203   103.59       day
# 213316124   6.93074   80.0086   6.93539   79.9972    80.02       day
# 213315491   6.87514   79.9343   6.88132   79.9680   158.93       day
# 213315522   6.84892   79.8883   6.88032   79.8708   191.29       day
# 213317715   6.91227   79.8647   6.92800   79.8648    91.20       day
# 213316458   6.95365   79.8809   6.91555   79.9602   494.91       day
# 213316409   6.86792   79.8704   6.95217   79.9167   543.65       day
# 213317742   7.28818   80.6287   7.28907   80.6204    87.68       day
# ...             ...       ...       ...       ...      ...       ...
# 222825708   6.94231   79.9884   6.96582   79.9657   220.93       day
# 222826396   6.97695   79.9255   7.00496   79.9030   216.98       day
# 222826895   6.83707   79.8974   6.84118   79.9755   337.75       day
# 222826635   6.90949   79.8523   6.82492   79.8667   339.15       day
# 222827460   7.14288   80.0972   7.12295   79.9081   924.93       day
# 222828746   6.96621   79.8709   6.93699   79.8495   208.66       day
# 222830021   6.87578   79.8678   6.87574   79.8678   272.29       day
# 222830132   6.84511   79.8778   6.83276   79.8718   101.54       day
# 222830743   7.02412   79.8997   7.02358   79.8998    84.07       day
# 222831987   7.20351   79.8635   7.34212   79.8837   744.31       day
# 222833285   6.90226   79.8978   6.90295   79.9424   282.48       day
# 222833707   6.90318   79.8522   6.84278   79.8754   299.74       day
# 222832962   6.97484   79.8907   6.94750   79.8703   201.71       day
# 222835856   6.86026   79.9063   6.86236   79.9971   430.89       day
# 222837330   7.27454   80.6119   7.25964   80.5856   197.51       day
# 222837378   6.98980   79.8931   6.98434   79.9001    73.05       day
# 222837360   7.40724   79.8180   7.17909   79.8622  1174.75       day
# 222840348   6.88485   79.9022   6.93582   79.8957   267.38       day
# 222849083   7.48909   80.3501   7.49438   80.3736   134.31       day
# 222850789   7.09155   79.8954   7.09127   79.8954   531.65       day
# 222851642   6.86079   79.9146   6.87529   79.9043   104.39       day
# 222854087   7.15432   79.8719   7.20299   79.8605   268.95       day
# 222853276   6.98701   79.9039   6.92111   79.8506   451.45       day
# 222854061   7.06835   79.9608   7.05500   79.9228   220.81     night
# 222855526   6.98878   79.8912   6.99458   79.8864   111.02     night
# 222856243   6.85103   79.9567   6.85588   79.9214   388.48     night
# 222857785   6.91293   79.9656   6.92112   79.8980   379.85     night
# 222858416   6.85718   79.9081   6.83868   79.9083   112.79     night
# 222858691   6.91289   79.8846   6.93159   79.9145   248.46     night
# 222860703   6.91682   79.9192   6.87020   79.9340   339.63     night
#
#            driving_fare  time_driven  charge_per_hour
# tripid
# 213284604    276.321400          882       209.880000
# 213286352   1902.200000         4229         0.000000
# 213293973    380.841200         1297        37.536000
# 213294622    143.820000          446         0.000000
# 213298687    124.600800          422       113.594694
# 213299545   1129.939200         2144       169.546667
# 213302332    162.380800          654       189.746960
# 213302671    659.434000         2417       208.080000
# 213305594    278.270000         1125         0.000000
# 213305134    173.023502         1095       208.546547
# 213306304    495.832000         2048       209.880000
# 213308616    150.921800          726       209.880000
# 213309839   1062.199511         4446       208.170117
# 213310068   1250.720000          365         0.000000
# 213309032    227.818800          874       208.080000
# 213310105    331.470000         1576         0.000000
# 213311364    316.000000         1421         0.000000
# 213309929    404.435010         1623       209.495510
# 213310221    418.580000         1542         0.000000
# 213312453    133.790000          464         0.000000
# 213313921    274.020000         1121         0.000000
# 213314038    135.010000          578         0.000000
# 213314867     93.090000          353         0.000000
# 213316124     73.154400          229       209.880000
# 213315491    148.430000          611         0.000000
# 213315522    178.015600          824       208.080000
# 213317715     86.200000          277              NaN
# 213316458    484.410000         1550         0.000000
# 213316409    533.150000         2203         0.000000
# 213317742     75.561600          245       208.080000
# ...                 ...          ...              ...
# 222825708    210.430000          805         0.000000
# 222826396    206.480000          953         0.000000
# 222826895    327.250000         1297         0.000000
# 222826635    328.650000         1146         0.000000
# 222827460    914.430000         2635         0.000000
# 222828746    198.160000          655         0.000000
# 222830021    173.348900          753       209.880000
# 222830132     91.040000          435         0.000000
# 222830743     73.570000           48         0.000000
# 222831987    704.077000         8332       209.880000
# 222833285    271.980000         1124         0.000000
# 222833707    289.240000         1005         0.000000
# 222832962    189.476000          710       208.080000
# 222835856    420.390000         1969         0.000000
# 222837330    183.195200          728       208.080000
# 222837378     62.550000          195              NaN
# 222837360   1155.464400         3253       208.080000
# 222840348    256.880000         1549         0.000000
# 222849083    112.616400          405       209.880000
# 222850789    437.860200         1430       208.080000
# 222851642     93.540200          384       209.880000
# 222854087    258.450000          683         0.000000
# 222853276    416.813800         1798       209.880000
# 222854061    209.905400          875       208.080000
# 222855526     96.647400          341       208.080000
# 222856243    353.146680         1294       208.391497
# 222857785    369.350000         1298         0.000000
# 222858416     99.005600          362       211.140000
# 222858691    206.285600         1056       208.080000
# 222860703    296.241800         1007       171.342287
#
# [8576 rows x 20 columns]

# %%
test_features = test_set[new_columns]
preprocessed_test_features = preprocessor.fit_transform(test_features)
preprocessed_test_features_data_frame = pd.DataFrame(data=preprocessed_test_features, columns=new_columns)

# %% [markdown]
# <h2>Fare prediction and correctness prediction using Test Dataset </h2>

# %%
predicted_labels = classifier.predict(preprocessed_test_features_data_frame)

# %% [markdown]
# <h2>Writing to the Submission File</h2>

# %%
submission_set = pd.read_csv(DATA_PATH / "sample_submission.csv", index_col="tripid")
submission_set.head()

submission_set['prediction']= predicted_labels

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "theNotebook = " + "'"+thename+"'";
# kernel.execute(command);

# %%
filename = '../../submissions/'+theNotebook+'/'+theNotebook+'_{%i}.csv'
dirname = '../../submissions/'+theNotebook
fileversion = 1

if not os.path.exists(dirname):
    os.makedirs(dirname)
while glob.glob(filename.replace('{%i}',str(fileversion))) :
    fileversion+=1
submission_set.to_csv(filename.replace('{%i}',str(fileversion)), index=True)
print("Completed!")
# Out:
# Completed!

# %%
submission_set['prediction'].idxmin()
# Out:
# 213310068

# %%
submission_set['prediction'].value_counts()
# Out:
# 1    8236
# 0     340
# Name: prediction, dtype: int64
