# %% [markdown]
# <h1>Imports</h1>

# %%
import numpy as np
import pandas as pd
import lightgbm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import math
from sklearn import metrics
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import os
import glob

# %%
from lightgbm import LGBMRegressor
from lightgbm import LGBMClassifier

# %%
pd.set_option("display.max_columns", 100)
# %matplotlib inline

# %%
RANDOM_SEED = 6

# %% [markdown]
# <h1>Dataset Importing</h1>

# %%
data_path='/home/madnisal/Documents/ML_Project/datasets/'
training_df = pd.read_csv(data_path+'train.csv', index_col="tripid")

# %% [markdown]
# <h1>Data Preprocessing</h1>

# %%
def dist_from_coordinates(lat1, lon1, lat2, lon2):
  R = 6371  # Earth radius in km

  #conversion to radians
  d_lat = np.radians(lat2-lat1)
  d_lon = np.radians(lon2-lon1)

  r_lat1 = np.radians(lat1)
  r_lat2 = np.radians(lat2)

  #haversine formula
  a = np.sin(d_lat/2.) **2 + np.cos(r_lat1) * np.cos(r_lat2) * np.sin(d_lon/2.)**2

  haversine = 2 * R * np.arcsin(np.sqrt(a))

  return haversine

# %%
training_df['pickup_time'] = pd.to_datetime(training_df['pickup_time'], format="%m/%d/%Y %H:%M")
training_df['drop_time'] = pd.to_datetime(training_df['drop_time'], format="%m/%d/%Y %H:%M")

# %%
training_df = training_df.assign(timeOfDay=pd.cut(training_df.pickup_time.dt.hour,[-1, 8, 20, 24],labels=['dawn','day', 'night']))

# %%
training_df.loc[training_df['timeOfDay'] == 'day', 'isNormalCharge'] = 1
training_df.loc[training_df['timeOfDay'] != 'day', 'isNormalCharge'] = 0

# %%
durations = []
for index,row in training_df.iterrows():
  provided_duration = row['duration'] #first row of location.lat column here
  if math.isnan(provided_duration) or provided_duration <= 0 :
    time_dif = (row['drop_time'] - row['pickup_time']).seconds
    if(time_dif == 0):
        time_dif = np.nan
    durations.append(time_dif)
  else :  
    durations.append(provided_duration)

training_df.insert(4,"time_dif",durations)

# %%
new_column = []                    #empty column for distance
for index,row in training_df.iterrows():
  lat1 = row['pick_lat'] #first row of location.lat column here
  lon1 = row['pick_lon'] #first row of location.long column here
  lat2 = row['drop_lat'] #second row of location.lat column here
  lon2 = row['drop_lon'] #second row of location.long column here
  value = dist_from_coordinates(lat1, lon1, lat2, lon2)  #get the distance
  new_column.append(value)   #append the empty list with distance values

training_df.insert(4,"distance",new_column)

# %%
training_df['time_driven'] = training_df['duration']  - training_df['meter_waiting']

# %%
chargeperhours = []
for index,row in training_df.iterrows():
    if(row['meter_waiting'] == 0):
        chargeperhour = np.nan
    else:
        chargeperhour = (row['meter_waiting_fare'] / row['meter_waiting'] * 3600)
    chargeperhours.append(chargeperhour)

training_df.insert(4,'charge_per_hour',chargeperhours)

# %%
training_df['driving_fare'] = training_df['fare']  - training_df['meter_waiting_fare'] - training_df['additional_fare']

# %%
avgspeeds = []
for index,row in training_df.iterrows():
    if(row['time_driven'] == 0):
        avgspeed = np.nan
    else:
        avgspeed = (row['distance'] / row['time_driven'] * 3600)
    avgspeeds.append(avgspeed)

training_df.insert(4,"avg_speed",avgspeeds)

# %%
costsperkm = []
for index,row in training_df.iterrows():
    if row['distance'] == 0:
        costperkm = np.nan
            
    else:
        costperkm = (row['driving_fare'] / row['distance'])
    costsperkm.append(costperkm)

training_df.insert(4,"cost_per_km",costsperkm)

# %%
training_df = training_df.replace({'label': {'incorrect': 0, 'correct' : 1}})

# %%
training_df = training_df.drop(190167541)

# %% [markdown]
# <h1>Model Training</h1>

# %% [markdown]
# <h2> Part 1 : Fare Predictor </h2>
# Predict fare using features

# %%
# Extract Correctly predicted fares
correct_training_df = training_df[training_df['label'] == 1]

# %%
fare_prediction_features =  ['additional_fare','cost_per_km', 'avg_speed', 'charge_per_hour',  'isNormalCharge']

# %%
fare_prediction_target_column = ['fare']

# %%
predictor_x = correct_training_df[fare_prediction_features].values
predictor_y = correct_training_df[fare_prediction_target_column].values

# %%
x, x_test, y, y_test = train_test_split(predictor_x, predictor_y, test_size=0.2, random_state=RANDOM_SEED)

# %%
gkf = KFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)

# %%
estimator = LGBMRegressor()

# %%
for training_index, testing_index in gkf.split(X=x, y=y):
    x_train_fold, y_train_fold = x[training_index], y[training_index]
    x_test_fold, y_test_fold = x[testing_index], y[testing_index]
    estimator.fit(x_train_fold, y_train_fold)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
predicted_prices = estimator.predict(training_df[fare_prediction_features])

# %%
training_df.insert(13,'predicted_price',predicted_prices)

# %%
# Training dataset after new features inserted
training_df[training_df['label']==1]
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0            0.000000
# 189125358             10.5     791.0           47.0            0.000000
# 189125719             10.5    1087.0           80.0            0.000000
# 189127273             10.5     598.0          271.0           15.663800
# 189128020              NaN       NaN            NaN                 NaN
# 189129552             10.5    3407.0          182.0            0.000000
# 189132829             10.5    1246.0          487.0            0.000000
# 189135103             10.5    1333.0          295.0           17.198500
# 189139296             10.5     360.0           80.0            4.664000
# 189138671             10.5    1539.0          588.0           33.986400
# 189144528             10.5    2011.0          199.0            0.000000
# 189145904             10.5     335.0           10.0            0.583000
# 189146174             10.5    4221.0         1608.0           84.214600
# 189150541             10.5    1472.0          219.0           12.699976
# 189153229             10.5     284.0            0.0            0.000000
# 189151585             10.5    2435.0          381.0            0.000000
# 189157464             10.5     891.0          170.0            0.000000
# 189157476             10.5    3176.0          390.0            0.000000
# 189157559             10.5     693.0          280.0            9.883800
# 189159951              5.0     850.0          143.0            8.336900
# 189158726             10.5    1443.0           59.0            0.000000
# 189163162             10.5     618.0          128.0            7.398400
# 189164454             10.5    1407.0          210.0            0.000000
# 189164880             10.5     575.0           23.0            0.000000
# 189165701              5.0    1588.0          302.0           17.606600
# 189165828             10.5    2523.0          140.0            8.108414
# 189165178             10.5     537.0           30.0            1.734000
# 189165865             10.5     345.0           10.0            0.000000
# 189166546             10.5    1892.0           50.0            0.000000
# 189168392             10.5    1952.0          484.0           25.894400
# ...                    ...       ...            ...                 ...
# 213740361             10.5     959.0          133.0            0.000000
# 213743810             10.5    2122.0          248.0           14.458400
# 189165828      1       day             1.0       2383.0    521.891586
# 189165178      1       day             1.0        507.0    119.886000
# 189165865      1       day             1.0        335.0     97.290000
# 189166546      1       day             1.0       1842.0    413.440000
# 189168392      1       day             1.0       1468.0    308.445600
# ...          ...       ...             ...          ...           ...
# 213740361      1       day             1.0        826.0    140.790000
# 213743810      1       day             1.0       1874.0    443.821600
# 213747503      1       day             1.0       2234.0    558.042600
# 213751620      1       day             1.0        177.0     65.633400
# 213749432      1       day             1.0        965.0    170.641800
# 213754172      1       day             1.0       1044.0    300.380000
# 213759061      1       day             1.0        402.0    128.530000
# 213761623      1       day             1.0       2516.0    634.655800
# 213776255      1       day             1.0        328.0    108.471000
# 213774316      1       day             1.0        368.0     91.181100
# 213774593      1       day             1.0       1055.0    204.430000
# 213775846      1       day             1.0        591.0     98.785800
# 213774642      1       day             1.0        615.0    129.188023
# 213774742      1       day             1.0        411.0     86.200000
# 213779882      1       day             1.0        747.0    156.184573
# 213782178      1       day             1.0        653.0    185.740000
# 213782382      1       day             1.0       1306.0    351.304000
# 213784559      1       day             1.0       1040.0    388.140000
# 213784596      1       day             1.0        804.0    171.280000
# 213787716      1       day             1.0        690.0    200.240000
# 213789771      1     night             0.0        831.0    183.780000
# 213799350      1     night             0.0        794.0    199.760000
# 213800748      1     night             0.0        383.0     94.920000
# 213802197      1     night             0.0       2517.0    797.496000
# 213802222      1     night             0.0        305.0     70.730000
# 213803193      1     night             0.0        745.0    182.338100
# 213812756      1     night             0.0       1723.0    570.730000
# 213813930      1     night             0.0        254.0     65.700000
# 213815405      1     night             0.0        743.0    122.810000
# 213817296      1     night             0.0        241.0     86.845700
#
# [15494 rows x 23 columns]

# %% [markdown]
# <h2>Part 2: Training the classifier</h2>

# %%
from sklearn.metrics import f1_score
def evaluate_macroF1_lgb(y_true, y_pred):  
    y_hat = np.where(y_pred < 0.5, 0, 1) 
    f1 = f1_score(y_true, y_hat, average='macro')
    return ('macroF1', f1, True)

# %%
def focal_loss_lgb_eval_error(y_true, y_pred, alpha=.25, gamma=2.):
    a,g = alpha, gamma
    p = 1/(1+np.exp(-y_pred))
    loss = -( a*y_true + (1-a)*(1-y_true) ) * (( 1 - ( y_true*p + (1-y_true)*(1-p)) )**g) * ( y_true*np.log(p)+(1-y_true)*np.log(1-p) )
    return 'focal_loss', np.mean(loss), False

# %%
classifier_features = ['predicted_price','fare']
classifier_label = ['label']

# %%
class_x = training_df[classifier_features].values
class_y = training_df[classifier_label].values

# %%
x, x_test, y, y_test = train_test_split(class_x, class_y ,test_size=0.2, random_state=RANDOM_SEED)

# %%
sgkf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)

# %%
model = lightgbm.LGBMClassifier(class_weight={0:3,1:1}, learning_rate=0.1)

# %%
for training_index, testing_index in sgkf.split(X=x, y=y):
    x_train_fold, y_train_fold = x[training_index], y[training_index]
    x_test_fold, y_test_fold = x[testing_index], y[testing_index]
    model.fit(x_train_fold, y_train_fold, eval_set=(x_test_fold,y_test_fold),eval_metric = lambda y_true, y_pred: [evaluate_macroF1_lgb(y_true,y_pred)])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	valid_0's binary_logloss: 0.371076	valid_0's macroF1: 0.474268
# [2]	valid_0's binary_logloss: 0.355005	valid_0's macroF1: 0.474268
# [3]	valid_0's binary_logloss: 0.341902	valid_0's macroF1: 0.474268
# [4]	valid_0's binary_logloss: 0.33091	valid_0's macroF1: 0.597088
# [5]	valid_0's binary_logloss: 0.321741	valid_0's macroF1: 0.671744
# [6]	valid_0's binary_logloss: 0.313766	valid_0's macroF1: 0.710228
# [7]	valid_0's binary_logloss: 0.306864	valid_0's macroF1: 0.715136
# [8]	valid_0's binary_logloss: 0.301029	valid_0's macroF1: 0.719918
# [9]	valid_0's binary_logloss: 0.296251	valid_0's macroF1: 0.721245
# [10]	valid_0's binary_logloss: 0.291769	valid_0's macroF1: 0.721245
# [11]	valid_0's binary_logloss: 0.287806	valid_0's macroF1: 0.724581
# [12]	valid_0's binary_logloss: 0.284668	valid_0's macroF1: 0.720751
# [13]	valid_0's binary_logloss: 0.281611	valid_0's macroF1: 0.724996
# [14]	valid_0's binary_logloss: 0.279124	valid_0's macroF1: 0.72382
# [15]	valid_0's binary_logloss: 0.276785	valid_0's macroF1: 0.727722
# [16]	valid_0's binary_logloss: 0.274341	valid_0's macroF1: 0.728202
# [17]	valid_0's binary_logloss: 0.272361	valid_0's macroF1: 0.725297
# [18]	valid_0's binary_logloss: 0.270966	valid_0's macroF1: 0.728915
# [19]	valid_0's binary_logloss: 0.269435	valid_0's macroF1: 0.728915
# [20]	valid_0's binary_logloss: 0.268054	valid_0's macroF1: 0.729578
# [21]	valid_0's binary_logloss: 0.266934	valid_0's macroF1: 0.729578
# [22]	valid_0's binary_logloss: 0.265994	valid_0's macroF1: 0.730243
# [23]	valid_0's binary_logloss: 0.26472	valid_0's macroF1: 0.728255
# [24]	valid_0's binary_logloss: 0.264015	valid_0's macroF1: 0.728255
# [25]	valid_0's binary_logloss: 0.263565	valid_0's macroF1: 0.728255
# [26]	valid_0's binary_logloss: 0.262818	valid_0's macroF1: 0.729578
# [27]	valid_0's binary_logloss: 0.262167	valid_0's macroF1: 0.728915
# [28]	valid_0's binary_logloss: 0.261141	valid_0's macroF1: 0.730671
# [29]	valid_0's binary_logloss: 0.260812	valid_0's macroF1: 0.730671
# [30]	valid_0's binary_logloss: 0.260888	valid_0's macroF1: 0.728034
# [31]	valid_0's binary_logloss: 0.260701	valid_0's macroF1: 0.728034
# [32]	valid_0's binary_logloss: 0.260402	valid_0's macroF1: 0.729347
# [33]	valid_0's binary_logloss: 0.260262	valid_0's macroF1: 0.727597
# [34]	valid_0's binary_logloss: 0.260175	valid_0's macroF1: 0.726289
# [35]	valid_0's binary_logloss: 0.259663	valid_0's macroF1: 0.726289
# [36]	valid_0's binary_logloss: 0.259614	valid_0's macroF1: 0.726289
# [37]	valid_0's binary_logloss: 0.259247	valid_0's macroF1: 0.723888
# [38]	valid_0's binary_logloss: 0.259225	valid_0's macroF1: 0.724536
# [39]	valid_0's binary_logloss: 0.258866	valid_0's macroF1: 0.724536
# [40]	valid_0's binary_logloss: 0.258654	valid_0's macroF1: 0.724536
# [41]	valid_0's binary_logloss: 0.258646	valid_0's macroF1: 0.723242
# [42]	valid_0's binary_logloss: 0.258482	valid_0's macroF1: 0.724536
# [43]	valid_0's binary_logloss: 0.258627	valid_0's macroF1: 0.725187
# [44]	valid_0's binary_logloss: 0.258422	valid_0's macroF1: 0.725187
# [45]	valid_0's binary_logloss: 0.258375	valid_0's macroF1: 0.723424
# [46]	valid_0's binary_logloss: 0.258094	valid_0's macroF1: 0.718936
# [47]	valid_0's binary_logloss: 0.257934	valid_0's macroF1: 0.724344
# [48]	valid_0's binary_logloss: 0.257673	valid_0's macroF1: 0.726948
# [49]	valid_0's binary_logloss: 0.25752	valid_0's macroF1: 0.726948
# [50]	valid_0's binary_logloss: 0.257488	valid_0's macroF1: 0.72415
# [51]	valid_0's binary_logloss: 0.257038	valid_0's macroF1: 0.725436
# [52]	valid_0's binary_logloss: 0.256951	valid_0's macroF1: 0.726082
# [53]	valid_0's binary_logloss: 0.25694	valid_0's macroF1: 0.726082
# [54]	valid_0's binary_logloss: 0.256709	valid_0's macroF1: 0.722874
# [55]	valid_0's binary_logloss: 0.256633	valid_0's macroF1: 0.721783
# [56]	valid_0's binary_logloss: 0.256344	valid_0's macroF1: 0.722419
# [57]	valid_0's binary_logloss: 0.256186	valid_0's macroF1: 0.721783
# [58]	valid_0's binary_logloss: 0.256016	valid_0's macroF1: 0.7237
# [59]	valid_0's binary_logloss: 0.256076	valid_0's macroF1: 0.722598
# [60]	valid_0's binary_logloss: 0.256101	valid_0's macroF1: 0.720846
# [61]	valid_0's binary_logloss: 0.256173	valid_0's macroF1: 0.718449
# [62]	valid_0's binary_logloss: 0.256129	valid_0's macroF1: 0.717815
# [63]	valid_0's binary_logloss: 0.256053	valid_0's macroF1: 0.718449
# [64]	valid_0's binary_logloss: 0.256088	valid_0's macroF1: 0.717815
# [65]	valid_0's binary_logloss: 0.256051	valid_0's macroF1: 0.716554
# [66]	valid_0's binary_logloss: 0.256237	valid_0's macroF1: 0.717047
# [67]	valid_0's binary_logloss: 0.25622	valid_0's macroF1: 0.714679
# [68]	valid_0's binary_logloss: 0.256269	valid_0's macroF1: 0.717532
# [69]	valid_0's binary_logloss: 0.256124	valid_0's macroF1: 0.718157
# [70]	valid_0's binary_logloss: 0.256161	valid_0's macroF1: 0.716909
# [71]	valid_0's binary_logloss: 0.256147	valid_0's macroF1: 0.716288
# [72]	valid_0's binary_logloss: 0.256102	valid_0's macroF1: 0.716909
# [73]	valid_0's binary_logloss: 0.255962	valid_0's macroF1: 0.716288
# [74]	valid_0's binary_logloss: 0.25601	valid_0's macroF1: 0.718157
# [75]	valid_0's binary_logloss: 0.256111	valid_0's macroF1: 0.718157
# [76]	valid_0's binary_logloss: 0.256187	valid_0's macroF1: 0.718157
# [77]	valid_0's binary_logloss: 0.25624	valid_0's macroF1: 0.717532
# [78]	valid_0's binary_logloss: 0.256289	valid_0's macroF1: 0.717532
# [79]	valid_0's binary_logloss: 0.256395	valid_0's macroF1: 0.717532
# [80]	valid_0's binary_logloss: 0.25656	valid_0's macroF1: 0.716288
# [81]	valid_0's binary_logloss: 0.256704	valid_0's macroF1: 0.715052
# [82]	valid_0's binary_logloss: 0.256739	valid_0's macroF1: 0.714559
# [83]	valid_0's binary_logloss: 0.256965	valid_0's macroF1: 0.715178
# [84]	valid_0's binary_logloss: 0.257247	valid_0's macroF1: 0.71344
# [85]	valid_0's binary_logloss: 0.257283	valid_0's macroF1: 0.71344
# [86]	valid_0's binary_logloss: 0.257323	valid_0's macroF1: 0.714059
# [87]	valid_0's binary_logloss: 0.257438	valid_0's macroF1: 0.714679
# [88]	valid_0's binary_logloss: 0.257546	valid_0's macroF1: 0.714059
# [89]	valid_0's binary_logloss: 0.257746	valid_0's macroF1: 0.715799
# [90]	valid_0's binary_logloss: 0.25777	valid_0's macroF1: 0.714059
# [91]	valid_0's binary_logloss: 0.257754	valid_0's macroF1: 0.714679
# [92]	valid_0's binary_logloss: 0.257913	valid_0's macroF1: 0.71344
# [93]	valid_0's binary_logloss: 0.257817	valid_0's macroF1: 0.71344
# [94]	valid_0's binary_logloss: 0.257935	valid_0's macroF1: 0.713943
# [95]	valid_0's binary_logloss: 0.257892	valid_0's macroF1: 0.714559
# [96]	valid_0's binary_logloss: 0.257723	valid_0's macroF1: 0.713943
# [97]	valid_0's binary_logloss: 0.257866	valid_0's macroF1: 0.713943
# [98]	valid_0's binary_logloss: 0.257895	valid_0's macroF1: 0.713329
# [99]	valid_0's binary_logloss: 0.258164	valid_0's macroF1: 0.713329
# [100]	valid_0's binary_logloss: 0.258168	valid_0's macroF1: 0.712716
# [1]	valid_0's binary_logloss: 0.369294	valid_0's macroF1: 0.474268
# [2]	valid_0's binary_logloss: 0.35227	valid_0's macroF1: 0.474268
# [3]	valid_0's binary_logloss: 0.33851	valid_0's macroF1: 0.474268
# [4]	valid_0's binary_logloss: 0.327237	valid_0's macroF1: 0.684755
# [5]	valid_0's binary_logloss: 0.31769	valid_0's macroF1: 0.735761
# [6]	valid_0's binary_logloss: 0.309495	valid_0's macroF1: 0.758297
# [7]	valid_0's binary_logloss: 0.30273	valid_0's macroF1: 0.761227
# [8]	valid_0's binary_logloss: 0.296671	valid_0's macroF1: 0.760736
# [9]	valid_0's binary_logloss: 0.29181	valid_0's macroF1: 0.764376
# [10]	valid_0's binary_logloss: 0.287444	valid_0's macroF1: 0.760529
# [11]	valid_0's binary_logloss: 0.283746	valid_0's macroF1: 0.755569
# [12]	valid_0's binary_logloss: 0.280288	valid_0's macroF1: 0.752949
# [13]	valid_0's binary_logloss: 0.277758	valid_0's macroF1: 0.749293
# [14]	valid_0's binary_logloss: 0.275429	valid_0's macroF1: 0.749293
# [15]	valid_0's binary_logloss: 0.273282	valid_0's macroF1: 0.746144
# [16]	valid_0's binary_logloss: 0.271147	valid_0's macroF1: 0.74478
# [17]	valid_0's binary_logloss: 0.2692	valid_0's macroF1: 0.74478
# [18]	valid_0's binary_logloss: 0.267587	valid_0's macroF1: 0.752422
# [19]	valid_0's binary_logloss: 0.26586	valid_0's macroF1: 0.758729
# [20]	valid_0's binary_logloss: 0.264386	valid_0's macroF1: 0.757094
# [21]	valid_0's binary_logloss: 0.263341	valid_0's macroF1: 0.758729
# [22]	valid_0's binary_logloss: 0.262223	valid_0's macroF1: 0.76106
# [23]	valid_0's binary_logloss: 0.261281	valid_0's macroF1: 0.76198
# [24]	valid_0's binary_logloss: 0.260454	valid_0's macroF1: 0.761278
# [25]	valid_0's binary_logloss: 0.259752	valid_0's macroF1: 0.761278
# [26]	valid_0's binary_logloss: 0.259308	valid_0's macroF1: 0.759882
# [27]	valid_0's binary_logloss: 0.258689	valid_0's macroF1: 0.762397
# [28]	valid_0's binary_logloss: 0.258391	valid_0's macroF1: 0.760938
# [29]	valid_0's binary_logloss: 0.25777	valid_0's macroF1: 0.762798
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [30]	valid_0's binary_logloss: 0.257369	valid_0's macroF1: 0.762798
# [31]	valid_0's binary_logloss: 0.256932	valid_0's macroF1: 0.759785
# [32]	valid_0's binary_logloss: 0.256385	valid_0's macroF1: 0.763183
# [33]	valid_0's binary_logloss: 0.256294	valid_0's macroF1: 0.763183
# [34]	valid_0's binary_logloss: 0.256129	valid_0's macroF1: 0.759316
# [35]	valid_0's binary_logloss: 0.256114	valid_0's macroF1: 0.759316
# [36]	valid_0's binary_logloss: 0.256045	valid_0's macroF1: 0.759316
# [37]	valid_0's binary_logloss: 0.255851	valid_0's macroF1: 0.759316
# [38]	valid_0's binary_logloss: 0.255882	valid_0's macroF1: 0.758648
# [39]	valid_0's binary_logloss: 0.25577	valid_0's macroF1: 0.756444
# [40]	valid_0's binary_logloss: 0.255743	valid_0's macroF1: 0.757108
# [41]	valid_0's binary_logloss: 0.255694	valid_0's macroF1: 0.757108
# [42]	valid_0's binary_logloss: 0.2556	valid_0's macroF1: 0.756444
# [43]	valid_0's binary_logloss: 0.255769	valid_0's macroF1: 0.756444
# [44]	valid_0's binary_logloss: 0.255539	valid_0's macroF1: 0.7549
# [45]	valid_0's binary_logloss: 0.255656	valid_0's macroF1: 0.7549
# [46]	valid_0's binary_logloss: 0.255321	valid_0's macroF1: 0.759112
# [47]	valid_0's binary_logloss: 0.255246	valid_0's macroF1: 0.758442
# [48]	valid_0's binary_logloss: 0.255009	valid_0's macroF1: 0.758442
# [49]	valid_0's binary_logloss: 0.255142	valid_0's macroF1: 0.758442
# [50]	valid_0's binary_logloss: 0.254819	valid_0's macroF1: 0.7549
# [51]	valid_0's binary_logloss: 0.254845	valid_0's macroF1: 0.757561
# [52]	valid_0's binary_logloss: 0.254901	valid_0's macroF1: 0.757561
# [53]	valid_0's binary_logloss: 0.254882	valid_0's macroF1: 0.756226
# [54]	valid_0's binary_logloss: 0.254724	valid_0's macroF1: 0.756892
# [55]	valid_0's binary_logloss: 0.254703	valid_0's macroF1: 0.757561
# [56]	valid_0's binary_logloss: 0.254759	valid_0's macroF1: 0.757561
# [57]	valid_0's binary_logloss: 0.254827	valid_0's macroF1: 0.757561
# [58]	valid_0's binary_logloss: 0.254997	valid_0's macroF1: 0.759112
# [59]	valid_0's binary_logloss: 0.254919	valid_0's macroF1: 0.758442
# [60]	valid_0's binary_logloss: 0.255021	valid_0's macroF1: 0.758442
# [61]	valid_0's binary_logloss: 0.25516	valid_0's macroF1: 0.759112
# [62]	valid_0's binary_logloss: 0.255367	valid_0's macroF1: 0.760658
# [63]	valid_0's binary_logloss: 0.255458	valid_0's macroF1: 0.759112
# [64]	valid_0's binary_logloss: 0.255754	valid_0's macroF1: 0.760658
# [65]	valid_0's binary_logloss: 0.2557	valid_0's macroF1: 0.760658
# [66]	valid_0's binary_logloss: 0.255841	valid_0's macroF1: 0.760658
# [67]	valid_0's binary_logloss: 0.255941	valid_0's macroF1: 0.760658
# [68]	valid_0's binary_logloss: 0.255587	valid_0's macroF1: 0.759316
# [69]	valid_0's binary_logloss: 0.255723	valid_0's macroF1: 0.757982
# [70]	valid_0's binary_logloss: 0.255862	valid_0's macroF1: 0.757108
# [71]	valid_0's binary_logloss: 0.255788	valid_0's macroF1: 0.757108
# [72]	valid_0's binary_logloss: 0.255566	valid_0's macroF1: 0.757982
# [73]	valid_0's binary_logloss: 0.255757	valid_0's macroF1: 0.757319
# [74]	valid_0's binary_logloss: 0.255585	valid_0's macroF1: 0.757319
# [75]	valid_0's binary_logloss: 0.256207	valid_0's macroF1: 0.757319
# [76]	valid_0's binary_logloss: 0.256251	valid_0's macroF1: 0.75885
# [77]	valid_0's binary_logloss: 0.256303	valid_0's macroF1: 0.75885
# [78]	valid_0's binary_logloss: 0.256572	valid_0's macroF1: 0.75885
# [79]	valid_0's binary_logloss: 0.25663	valid_0's macroF1: 0.75885
# [80]	valid_0's binary_logloss: 0.256425	valid_0's macroF1: 0.75885
# [81]	valid_0's binary_logloss: 0.256958	valid_0's macroF1: 0.75885
# [82]	valid_0's binary_logloss: 0.256942	valid_0's macroF1: 0.758187
# [83]	valid_0's binary_logloss: 0.25707	valid_0's macroF1: 0.758187
# [84]	valid_0's binary_logloss: 0.257169	valid_0's macroF1: 0.758187
# [85]	valid_0's binary_logloss: 0.257063	valid_0's macroF1: 0.758187
# [86]	valid_0's binary_logloss: 0.257136	valid_0's macroF1: 0.758187
# [87]	valid_0's binary_logloss: 0.257236	valid_0's macroF1: 0.757319
# [88]	valid_0's binary_logloss: 0.257309	valid_0's macroF1: 0.757319
# [89]	valid_0's binary_logloss: 0.257234	valid_0's macroF1: 0.757319
# [90]	valid_0's binary_logloss: 0.257216	valid_0's macroF1: 0.757319
# [91]	valid_0's binary_logloss: 0.25713	valid_0's macroF1: 0.757319
# [92]	valid_0's binary_logloss: 0.257264	valid_0's macroF1: 0.755782
# [93]	valid_0's binary_logloss: 0.257423	valid_0's macroF1: 0.756444
# [94]	valid_0's binary_logloss: 0.257707	valid_0's macroF1: 0.755999
# [95]	valid_0's binary_logloss: 0.257509	valid_0's macroF1: 0.755999
# [96]	valid_0's binary_logloss: 0.2574	valid_0's macroF1: 0.755999
# [97]	valid_0's binary_logloss: 0.257763	valid_0's macroF1: 0.755999
# [98]	valid_0's binary_logloss: 0.257917	valid_0's macroF1: 0.755342
# [99]	valid_0's binary_logloss: 0.257764	valid_0's macroF1: 0.753157
# [100]	valid_0's binary_logloss: 0.257946	valid_0's macroF1: 0.751858
# [1]	valid_0's binary_logloss: 0.369386	valid_0's macroF1: 0.474268
# [2]	valid_0's binary_logloss: 0.35196	valid_0's macroF1: 0.474268
# [3]	valid_0's binary_logloss: 0.338021	valid_0's macroF1: 0.474268
# [4]	valid_0's binary_logloss: 0.32642	valid_0's macroF1: 0.567133
# [5]	valid_0's binary_logloss: 0.316595	valid_0's macroF1: 0.730115
# [6]	valid_0's binary_logloss: 0.308438	valid_0's macroF1: 0.760736
# [7]	valid_0's binary_logloss: 0.301305	valid_0's macroF1: 0.761787
# [8]	valid_0's binary_logloss: 0.29511	valid_0's macroF1: 0.761826
# [9]	valid_0's binary_logloss: 0.289942	valid_0's macroF1: 0.760317
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [10]	valid_0's binary_logloss: 0.285635	valid_0's macroF1: 0.75882
# [11]	valid_0's binary_logloss: 0.281643	valid_0's macroF1: 0.76159
# [12]	valid_0's binary_logloss: 0.278236	valid_0's macroF1: 0.758353
# [13]	valid_0's binary_logloss: 0.2752	valid_0's macroF1: 0.760101
# [14]	valid_0's binary_logloss: 0.272552	valid_0's macroF1: 0.758716
# [15]	valid_0's binary_logloss: 0.269889	valid_0's macroF1: 0.758252
# [16]	valid_0's binary_logloss: 0.267698	valid_0's macroF1: 0.763596
# [17]	valid_0's binary_logloss: 0.265836	valid_0's macroF1: 0.762892
# [18]	valid_0's binary_logloss: 0.26413	valid_0's macroF1: 0.761765
# [19]	valid_0's binary_logloss: 0.262432	valid_0's macroF1: 0.761765
# [20]	valid_0's binary_logloss: 0.261276	valid_0's macroF1: 0.765765
# [21]	valid_0's binary_logloss: 0.259959	valid_0's macroF1: 0.764185
# [22]	valid_0's binary_logloss: 0.25886	valid_0's macroF1: 0.764185
# [23]	valid_0's binary_logloss: 0.25798	valid_0's macroF1: 0.765068
# [24]	valid_0's binary_logloss: 0.257131	valid_0's macroF1: 0.762993
# [25]	valid_0's binary_logloss: 0.256099	valid_0's macroF1: 0.756892
# [26]	valid_0's binary_logloss: 0.255587	valid_0's macroF1: 0.756892
# [27]	valid_0's binary_logloss: 0.255077	valid_0's macroF1: 0.757561
# [28]	valid_0's binary_logloss: 0.25456	valid_0's macroF1: 0.757108
# [29]	valid_0's binary_logloss: 0.254008	valid_0's macroF1: 0.757319
# [30]	valid_0's binary_logloss: 0.253551	valid_0's macroF1: 0.757319
# [31]	valid_0's binary_logloss: 0.253199	valid_0's macroF1: 0.757108
# [32]	valid_0's binary_logloss: 0.252967	valid_0's macroF1: 0.756444
# [33]	valid_0's binary_logloss: 0.252802	valid_0's macroF1: 0.757108
# [34]	valid_0's binary_logloss: 0.252714	valid_0's macroF1: 0.757319
# [35]	valid_0's binary_logloss: 0.252378	valid_0's macroF1: 0.756658
# [36]	valid_0's binary_logloss: 0.251901	valid_0's macroF1: 0.757319
# [37]	valid_0's binary_logloss: 0.251688	valid_0's macroF1: 0.752089
# [38]	valid_0's binary_logloss: 0.251368	valid_0's macroF1: 0.755123
# [39]	valid_0's binary_logloss: 0.250979	valid_0's macroF1: 0.756444
# [40]	valid_0's binary_logloss: 0.250714	valid_0's macroF1: 0.755782
# [41]	valid_0's binary_logloss: 0.250643	valid_0's macroF1: 0.755782
# [42]	valid_0's binary_logloss: 0.250586	valid_0's macroF1: 0.755999
# [43]	valid_0's binary_logloss: 0.250295	valid_0's macroF1: 0.755999
# [44]	valid_0's binary_logloss: 0.250211	valid_0's macroF1: 0.755999
# [45]	valid_0's binary_logloss: 0.250226	valid_0's macroF1: 0.755342
# [46]	valid_0's binary_logloss: 0.250037	valid_0's macroF1: 0.755342
# [47]	valid_0's binary_logloss: 0.249984	valid_0's macroF1: 0.755999
# [48]	valid_0's binary_logloss: 0.249763	valid_0's macroF1: 0.757319
# [49]	valid_0's binary_logloss: 0.249872	valid_0's macroF1: 0.756658
# [50]	valid_0's binary_logloss: 0.24972	valid_0's macroF1: 0.756658
# [51]	valid_0's binary_logloss: 0.249836	valid_0's macroF1: 0.756658
# [52]	valid_0's binary_logloss: 0.249694	valid_0's macroF1: 0.756658
# [53]	valid_0's binary_logloss: 0.249913	valid_0's macroF1: 0.756658
# [54]	valid_0's binary_logloss: 0.249761	valid_0's macroF1: 0.756658
# [55]	valid_0's binary_logloss: 0.249754	valid_0's macroF1: 0.756658
# [56]	valid_0's binary_logloss: 0.249594	valid_0's macroF1: 0.757319
# [57]	valid_0's binary_logloss: 0.249644	valid_0's macroF1: 0.757319
# [58]	valid_0's binary_logloss: 0.249617	valid_0's macroF1: 0.756658
# [59]	valid_0's binary_logloss: 0.249656	valid_0's macroF1: 0.755342
# [60]	valid_0's binary_logloss: 0.249675	valid_0's macroF1: 0.755342
# [61]	valid_0's binary_logloss: 0.249492	valid_0's macroF1: 0.755782
# [62]	valid_0's binary_logloss: 0.249286	valid_0's macroF1: 0.755782
# [63]	valid_0's binary_logloss: 0.249149	valid_0's macroF1: 0.755782
# [64]	valid_0's binary_logloss: 0.249208	valid_0's macroF1: 0.755782
# [65]	valid_0's binary_logloss: 0.249258	valid_0's macroF1: 0.755782
# [66]	valid_0's binary_logloss: 0.249212	valid_0's macroF1: 0.755782
# [67]	valid_0's binary_logloss: 0.248996	valid_0's macroF1: 0.755782
# [68]	valid_0's binary_logloss: 0.24892	valid_0's macroF1: 0.756444
# [69]	valid_0's binary_logloss: 0.249081	valid_0's macroF1: 0.756444
# [70]	valid_0's binary_logloss: 0.249149	valid_0's macroF1: 0.756444
# [71]	valid_0's binary_logloss: 0.249177	valid_0's macroF1: 0.757108
# [72]	valid_0's binary_logloss: 0.249069	valid_0's macroF1: 0.757319
# [73]	valid_0's binary_logloss: 0.24925	valid_0's macroF1: 0.756658
# [74]	valid_0's binary_logloss: 0.249029	valid_0's macroF1: 0.760183
# [75]	valid_0's binary_logloss: 0.249138	valid_0's macroF1: 0.760852
# [76]	valid_0's binary_logloss: 0.249352	valid_0's macroF1: 0.761524
# [77]	valid_0's binary_logloss: 0.249419	valid_0's macroF1: 0.759316
# [78]	valid_0's binary_logloss: 0.249525	valid_0's macroF1: 0.761524
# [79]	valid_0's binary_logloss: 0.249614	valid_0's macroF1: 0.760183
# [80]	valid_0's binary_logloss: 0.249366	valid_0's macroF1: 0.760183
# [81]	valid_0's binary_logloss: 0.249315	valid_0's macroF1: 0.759515
# [82]	valid_0's binary_logloss: 0.249382	valid_0's macroF1: 0.760183
# [83]	valid_0's binary_logloss: 0.249267	valid_0's macroF1: 0.760183
# [84]	valid_0's binary_logloss: 0.249233	valid_0's macroF1: 0.760183
# [85]	valid_0's binary_logloss: 0.249292	valid_0's macroF1: 0.760852
# [86]	valid_0's binary_logloss: 0.249367	valid_0's macroF1: 0.760852
# [87]	valid_0's binary_logloss: 0.249312	valid_0's macroF1: 0.761524
# [88]	valid_0's binary_logloss: 0.249251	valid_0's macroF1: 0.760852
# [89]	valid_0's binary_logloss: 0.249441	valid_0's macroF1: 0.760183
# [90]	valid_0's binary_logloss: 0.249533	valid_0's macroF1: 0.760183
# [91]	valid_0's binary_logloss: 0.249535	valid_0's macroF1: 0.760183
# [92]	valid_0's binary_logloss: 0.249384	valid_0's macroF1: 0.760183
# [93]	valid_0's binary_logloss: 0.24938	valid_0's macroF1: 0.760183
# [94]	valid_0's binary_logloss: 0.249269	valid_0's macroF1: 0.760852
# [95]	valid_0's binary_logloss: 0.249242	valid_0's macroF1: 0.759515
# [96]	valid_0's binary_logloss: 0.249124	valid_0's macroF1: 0.759515
# [97]	valid_0's binary_logloss: 0.249139	valid_0's macroF1: 0.760183
# [98]	valid_0's binary_logloss: 0.249246	valid_0's macroF1: 0.762198
# [99]	valid_0's binary_logloss: 0.249442	valid_0's macroF1: 0.762198
# [100]	valid_0's binary_logloss: 0.249326	valid_0's macroF1: 0.762198
# [1]	valid_0's binary_logloss: 0.370615	valid_0's macroF1: 0.474268
# [2]	valid_0's binary_logloss: 0.354561	valid_0's macroF1: 0.474268
# [3]	valid_0's binary_logloss: 0.341465	valid_0's macroF1: 0.474268
# [4]	valid_0's binary_logloss: 0.330735	valid_0's macroF1: 0.65699
# [5]	valid_0's binary_logloss: 0.321764	valid_0's macroF1: 0.689256
# [6]	valid_0's binary_logloss: 0.314277	valid_0's macroF1: 0.738283
# [7]	valid_0's binary_logloss: 0.307704	valid_0's macroF1: 0.742123
# [8]	valid_0's binary_logloss: 0.302158	valid_0's macroF1: 0.742123
# [9]	valid_0's binary_logloss: 0.29733	valid_0's macroF1: 0.741389
# [10]	valid_0's binary_logloss: 0.293263	valid_0's macroF1: 0.741389
# [11]	valid_0's binary_logloss: 0.289599	valid_0's macroF1: 0.73497
# [12]	valid_0's binary_logloss: 0.286291	valid_0's macroF1: 0.732929
# [13]	valid_0's binary_logloss: 0.283431	valid_0's macroF1: 0.731581
# [14]	valid_0's binary_logloss: 0.281004	valid_0's macroF1: 0.731581
# [15]	valid_0's binary_logloss: 0.2792	valid_0's macroF1: 0.727597
# [16]	valid_0's binary_logloss: 0.277496	valid_0's macroF1: 0.727597
# [17]	valid_0's binary_logloss: 0.275969	valid_0's macroF1: 0.725187
# [18]	valid_0's binary_logloss: 0.274796	valid_0's macroF1: 0.729347
# [19]	valid_0's binary_logloss: 0.273813	valid_0's macroF1: 0.729347
# [20]	valid_0's binary_logloss: 0.272403	valid_0's macroF1: 0.73043
# [21]	valid_0's binary_logloss: 0.271635	valid_0's macroF1: 0.731503
# [22]	valid_0's binary_logloss: 0.270847	valid_0's macroF1: 0.732701
# [23]	valid_0's binary_logloss: 0.270096	valid_0's macroF1: 0.73439
# [24]	valid_0's binary_logloss: 0.269295	valid_0's macroF1: 0.734944
# [25]	valid_0's binary_logloss: 0.26871	valid_0's macroF1: 0.734944
# [26]	valid_0's binary_logloss: 0.268439	valid_0's macroF1: 0.733737
# [27]	valid_0's binary_logloss: 0.267973	valid_0's macroF1: 0.735495
# [28]	valid_0's binary_logloss: 0.267651	valid_0's macroF1: 0.73492
# [29]	valid_0's binary_logloss: 0.267237	valid_0's macroF1: 0.735612
# [30]	valid_0's binary_logloss: 0.266972	valid_0's macroF1: 0.736883
# [31]	valid_0's binary_logloss: 0.266855	valid_0's macroF1: 0.736883
# [32]	valid_0's binary_logloss: 0.26622	valid_0's macroF1: 0.736883
# [33]	valid_0's binary_logloss: 0.26586	valid_0's macroF1: 0.735269
# [34]	valid_0's binary_logloss: 0.266019	valid_0's macroF1: 0.735269
# [35]	valid_0's binary_logloss: 0.265509	valid_0's macroF1: 0.735269
# [36]	valid_0's binary_logloss: 0.26535	valid_0's macroF1: 0.735269
# [37]	valid_0's binary_logloss: 0.265336	valid_0's macroF1: 0.734634
# [38]	valid_0's binary_logloss: 0.265602	valid_0's macroF1: 0.734002
# [39]	valid_0's binary_logloss: 0.265531	valid_0's macroF1: 0.734002
# [40]	valid_0's binary_logloss: 0.265245	valid_0's macroF1: 0.73492
# [41]	valid_0's binary_logloss: 0.265359	valid_0's macroF1: 0.733649
# [42]	valid_0's binary_logloss: 0.26533	valid_0's macroF1: 0.733649
# [43]	valid_0's binary_logloss: 0.265363	valid_0's macroF1: 0.733016
# [44]	valid_0's binary_logloss: 0.265372	valid_0's macroF1: 0.732386
# [45]	valid_0's binary_logloss: 0.265632	valid_0's macroF1: 0.732386
# [46]	valid_0's binary_logloss: 0.265651	valid_0's macroF1: 0.733721
# [47]	valid_0's binary_logloss: 0.265498	valid_0's macroF1: 0.733721
# [48]	valid_0's binary_logloss: 0.265259	valid_0's macroF1: 0.733095
# [49]	valid_0's binary_logloss: 0.265397	valid_0's macroF1: 0.734349
# [50]	valid_0's binary_logloss: 0.26562	valid_0's macroF1: 0.733095
# [51]	valid_0's binary_logloss: 0.265626	valid_0's macroF1: 0.732743
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [52]	valid_0's binary_logloss: 0.265379	valid_0's macroF1: 0.734002
# [53]	valid_0's binary_logloss: 0.265551	valid_0's macroF1: 0.734002
# [54]	valid_0's binary_logloss: 0.265634	valid_0's macroF1: 0.734002
# [55]	valid_0's binary_logloss: 0.265648	valid_0's macroF1: 0.734979
# [56]	valid_0's binary_logloss: 0.265629	valid_0's macroF1: 0.733721
# [57]	valid_0's binary_logloss: 0.265811	valid_0's macroF1: 0.733721
# [58]	valid_0's binary_logloss: 0.266004	valid_0's macroF1: 0.73492
# [59]	valid_0's binary_logloss: 0.265956	valid_0's macroF1: 0.734349
# [60]	valid_0's binary_logloss: 0.266003	valid_0's macroF1: 0.734349
# [61]	valid_0's binary_logloss: 0.265981	valid_0's macroF1: 0.732117
# [62]	valid_0's binary_logloss: 0.265751	valid_0's macroF1: 0.732117
# [63]	valid_0's binary_logloss: 0.265783	valid_0's macroF1: 0.732117
# [64]	valid_0's binary_logloss: 0.265985	valid_0's macroF1: 0.732655
# [65]	valid_0's binary_logloss: 0.266	valid_0's macroF1: 0.73329
# [66]	valid_0's binary_logloss: 0.265992	valid_0's macroF1: 0.732655
# [67]	valid_0's binary_logloss: 0.26631	valid_0's macroF1: 0.73329
# [68]	valid_0's binary_logloss: 0.266348	valid_0's macroF1: 0.73329
# [69]	valid_0's binary_logloss: 0.26641	valid_0's macroF1: 0.73492
# [70]	valid_0's binary_logloss: 0.266503	valid_0's macroF1: 0.736545
# [71]	valid_0's binary_logloss: 0.266521	valid_0's macroF1: 0.736545
# [72]	valid_0's binary_logloss: 0.266811	valid_0's macroF1: 0.735906
# [73]	valid_0's binary_logloss: 0.266844	valid_0's macroF1: 0.735906
# [74]	valid_0's binary_logloss: 0.266734	valid_0's macroF1: 0.734284
# [75]	valid_0's binary_logloss: 0.266741	valid_0's macroF1: 0.734284
# [76]	valid_0's binary_logloss: 0.266855	valid_0's macroF1: 0.732022
# [77]	valid_0's binary_logloss: 0.267029	valid_0's macroF1: 0.733649
# [78]	valid_0's binary_logloss: 0.267559	valid_0's macroF1: 0.733649
# [79]	valid_0's binary_logloss: 0.267599	valid_0's macroF1: 0.734634
# [80]	valid_0's binary_logloss: 0.267533	valid_0's macroF1: 0.734634
# [81]	valid_0's binary_logloss: 0.267644	valid_0's macroF1: 0.732386
# [82]	valid_0's binary_logloss: 0.267906	valid_0's macroF1: 0.732386
# [83]	valid_0's binary_logloss: 0.267975	valid_0's macroF1: 0.732386
# [84]	valid_0's binary_logloss: 0.268066	valid_0's macroF1: 0.730763
# [85]	valid_0's binary_logloss: 0.267916	valid_0's macroF1: 0.730137
# [86]	valid_0's binary_logloss: 0.268045	valid_0's macroF1: 0.730137
# [87]	valid_0's binary_logloss: 0.268065	valid_0's macroF1: 0.731757
# [88]	valid_0's binary_logloss: 0.268275	valid_0's macroF1: 0.730137
# [89]	valid_0's binary_logloss: 0.268262	valid_0's macroF1: 0.731757
# [90]	valid_0's binary_logloss: 0.268213	valid_0's macroF1: 0.731757
# [91]	valid_0's binary_logloss: 0.268294	valid_0's macroF1: 0.735612
# [92]	valid_0's binary_logloss: 0.268248	valid_0's macroF1: 0.735612
# [93]	valid_0's binary_logloss: 0.268209	valid_0's macroF1: 0.736247
# [94]	valid_0's binary_logloss: 0.268116	valid_0's macroF1: 0.735612
# [95]	valid_0's binary_logloss: 0.268038	valid_0's macroF1: 0.735612
# [96]	valid_0's binary_logloss: 0.268087	valid_0's macroF1: 0.735612
# [97]	valid_0's binary_logloss: 0.268051	valid_0's macroF1: 0.735612
# [98]	valid_0's binary_logloss: 0.267854	valid_0's macroF1: 0.735612
# [99]	valid_0's binary_logloss: 0.267982	valid_0's macroF1: 0.735612
# [100]	valid_0's binary_logloss: 0.267992	valid_0's macroF1: 0.734979
# [1]	valid_0's binary_logloss: 0.369536	valid_0's macroF1: 0.474168
# [2]	valid_0's binary_logloss: 0.35219	valid_0's macroF1: 0.474168
# [3]	valid_0's binary_logloss: 0.33852	valid_0's macroF1: 0.474168
# [4]	valid_0's binary_logloss: 0.326999	valid_0's macroF1: 0.658912
# [5]	valid_0's binary_logloss: 0.31764	valid_0's macroF1: 0.743325
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [6]	valid_0's binary_logloss: 0.309702	valid_0's macroF1: 0.761227
# [7]	valid_0's binary_logloss: 0.303004	valid_0's macroF1: 0.764631
# [8]	valid_0's binary_logloss: 0.297262	valid_0's macroF1: 0.771762
# [9]	valid_0's binary_logloss: 0.292479	valid_0's macroF1: 0.770981
# [10]	valid_0's binary_logloss: 0.288186	valid_0's macroF1: 0.770203
# [11]	valid_0's binary_logloss: 0.284525	valid_0's macroF1: 0.772155
# [12]	valid_0's binary_logloss: 0.28105	valid_0's macroF1: 0.770611
# [13]	valid_0's binary_logloss: 0.278461	valid_0's macroF1: 0.770809
# [14]	valid_0's binary_logloss: 0.276145	valid_0's macroF1: 0.767772
# [15]	valid_0's binary_logloss: 0.274048	valid_0's macroF1: 0.765913
# [16]	valid_0's binary_logloss: 0.27191	valid_0's macroF1: 0.763096
# [17]	valid_0's binary_logloss: 0.27008	valid_0's macroF1: 0.76349
# [18]	valid_0's binary_logloss: 0.268438	valid_0's macroF1: 0.76349
# [19]	valid_0's binary_logloss: 0.266746	valid_0's macroF1: 0.762798
# [20]	valid_0's binary_logloss: 0.26554	valid_0's macroF1: 0.760528
# [21]	valid_0's binary_logloss: 0.26452	valid_0's macroF1: 0.760528
# [22]	valid_0's binary_logloss: 0.263437	valid_0's macroF1: 0.762108
# [23]	valid_0's binary_logloss: 0.262516	valid_0's macroF1: 0.760735
# [24]	valid_0's binary_logloss: 0.26175	valid_0's macroF1: 0.756673
# [25]	valid_0's binary_logloss: 0.260997	valid_0's macroF1: 0.758232
# [26]	valid_0's binary_logloss: 0.260465	valid_0's macroF1: 0.757561
# [27]	valid_0's binary_logloss: 0.259911	valid_0's macroF1: 0.756226
# [28]	valid_0's binary_logloss: 0.259715	valid_0's macroF1: 0.756892
# [29]	valid_0's binary_logloss: 0.259335	valid_0's macroF1: 0.756892
# [30]	valid_0's binary_logloss: 0.259222	valid_0's macroF1: 0.756892
# [31]	valid_0's binary_logloss: 0.259145	valid_0's macroF1: 0.756892
# [32]	valid_0's binary_logloss: 0.258994	valid_0's macroF1: 0.7549
# [33]	valid_0's binary_logloss: 0.258974	valid_0's macroF1: 0.75424
# [34]	valid_0's binary_logloss: 0.258782	valid_0's macroF1: 0.75424
# [35]	valid_0's binary_logloss: 0.25847	valid_0's macroF1: 0.7549
# [36]	valid_0's binary_logloss: 0.258388	valid_0's macroF1: 0.7549
# [37]	valid_0's binary_logloss: 0.258269	valid_0's macroF1: 0.756226
# [38]	valid_0's binary_logloss: 0.258014	valid_0's macroF1: 0.756226
# [39]	valid_0's binary_logloss: 0.258078	valid_0's macroF1: 0.756226
# [40]	valid_0's binary_logloss: 0.258152	valid_0's macroF1: 0.760183
# [41]	valid_0's binary_logloss: 0.257948	valid_0's macroF1: 0.75885
# [42]	valid_0's binary_logloss: 0.257714	valid_0's macroF1: 0.75885
# [43]	valid_0's binary_logloss: 0.257854	valid_0's macroF1: 0.757526
# [44]	valid_0's binary_logloss: 0.25793	valid_0's macroF1: 0.755123
# [45]	valid_0's binary_logloss: 0.257711	valid_0's macroF1: 0.755782
# [46]	valid_0's binary_logloss: 0.257639	valid_0's macroF1: 0.755782
# [47]	valid_0's binary_logloss: 0.257372	valid_0's macroF1: 0.757108
# [48]	valid_0's binary_logloss: 0.257391	valid_0's macroF1: 0.757108
# [49]	valid_0's binary_logloss: 0.257502	valid_0's macroF1: 0.759515
# [50]	valid_0's binary_logloss: 0.257479	valid_0's macroF1: 0.760183
# [51]	valid_0's binary_logloss: 0.257457	valid_0's macroF1: 0.760183
# [52]	valid_0's binary_logloss: 0.25748	valid_0's macroF1: 0.759316
# [53]	valid_0's binary_logloss: 0.257635	valid_0's macroF1: 0.757774
# [54]	valid_0's binary_logloss: 0.257556	valid_0's macroF1: 0.758442
# [55]	valid_0's binary_logloss: 0.257804	valid_0's macroF1: 0.758442
# [56]	valid_0's binary_logloss: 0.257925	valid_0's macroF1: 0.755999
# [57]	valid_0's binary_logloss: 0.257932	valid_0's macroF1: 0.755999
# [58]	valid_0's binary_logloss: 0.257975	valid_0's macroF1: 0.755342
# [59]	valid_0's binary_logloss: 0.258181	valid_0's macroF1: 0.754687
# [60]	valid_0's binary_logloss: 0.25799	valid_0's macroF1: 0.754687
# [61]	valid_0's binary_logloss: 0.25795	valid_0's macroF1: 0.754687
# [62]	valid_0's binary_logloss: 0.258101	valid_0's macroF1: 0.755118
# [63]	valid_0's binary_logloss: 0.258152	valid_0's macroF1: 0.755768
# [64]	valid_0's binary_logloss: 0.258041	valid_0's macroF1: 0.755118
# [65]	valid_0's binary_logloss: 0.25796	valid_0's macroF1: 0.755118
# [66]	valid_0's binary_logloss: 0.257809	valid_0's macroF1: 0.755118
# [67]	valid_0's binary_logloss: 0.257971	valid_0's macroF1: 0.755118
# [68]	valid_0's binary_logloss: 0.257942	valid_0's macroF1: 0.755768
# [69]	valid_0's binary_logloss: 0.257865	valid_0's macroF1: 0.757074
# [70]	valid_0's binary_logloss: 0.257874	valid_0's macroF1: 0.75773
# [71]	valid_0's binary_logloss: 0.257893	valid_0's macroF1: 0.758388
# [72]	valid_0's binary_logloss: 0.258007	valid_0's macroF1: 0.757074
# [73]	valid_0's binary_logloss: 0.258082	valid_0's macroF1: 0.75773
# [74]	valid_0's binary_logloss: 0.258077	valid_0's macroF1: 0.757074
# [75]	valid_0's binary_logloss: 0.258093	valid_0's macroF1: 0.757074
# [76]	valid_0's binary_logloss: 0.258099	valid_0's macroF1: 0.757074
# [77]	valid_0's binary_logloss: 0.258155	valid_0's macroF1: 0.758585
# [78]	valid_0's binary_logloss: 0.258372	valid_0's macroF1: 0.758585
# [79]	valid_0's binary_logloss: 0.258437	valid_0's macroF1: 0.760091
# [80]	valid_0's binary_logloss: 0.258695	valid_0's macroF1: 0.758585
# [81]	valid_0's binary_logloss: 0.258611	valid_0's macroF1: 0.757929
# [82]	valid_0's binary_logloss: 0.258592	valid_0's macroF1: 0.757929
# [83]	valid_0's binary_logloss: 0.258535	valid_0's macroF1: 0.760091
# [84]	valid_0's binary_logloss: 0.258606	valid_0's macroF1: 0.759433
# [85]	valid_0's binary_logloss: 0.258687	valid_0's macroF1: 0.759433
# [86]	valid_0's binary_logloss: 0.258807	valid_0's macroF1: 0.759433
# [87]	valid_0's binary_logloss: 0.258632	valid_0's macroF1: 0.759433
# [88]	valid_0's binary_logloss: 0.258658	valid_0's macroF1: 0.759433
# [89]	valid_0's binary_logloss: 0.258813	valid_0's macroF1: 0.759903
# [90]	valid_0's binary_logloss: 0.258915	valid_0's macroF1: 0.759048
# [91]	valid_0's binary_logloss: 0.258903	valid_0's macroF1: 0.759048
# [92]	valid_0's binary_logloss: 0.258863	valid_0's macroF1: 0.758388
# [93]	valid_0's binary_logloss: 0.258806	valid_0's macroF1: 0.758388
# [94]	valid_0's binary_logloss: 0.259013	valid_0's macroF1: 0.75773
# [95]	valid_0's binary_logloss: 0.259219	valid_0's macroF1: 0.75773
# [96]	valid_0's binary_logloss: 0.259316	valid_0's macroF1: 0.75773
# [97]	valid_0's binary_logloss: 0.259181	valid_0's macroF1: 0.757074
# [98]	valid_0's binary_logloss: 0.259335	valid_0's macroF1: 0.757074
# [99]	valid_0's binary_logloss: 0.259335	valid_0's macroF1: 0.755557
# [100]	valid_0's binary_logloss: 0.259356	valid_0's macroF1: 0.755557

# %%
predicted_y = model.predict(x_test)
train_pred_y = model.predict(x)

# %%
print(); print(metrics.classification_report(y,train_pred_y))
print(); print(metrics.confusion_matrix(y, train_pred_y))

print(); print(metrics.classification_report(y_test, predicted_y))
print(); print(metrics.confusion_matrix(y_test, predicted_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.57      0.61      1346
#            1       0.95      0.97      0.96     12394
#
#     accuracy                           0.93     13740
#    macro avg       0.81      0.77      0.79     13740
# weighted avg       0.92      0.93      0.93     13740
#
#
# [[  767   579]
#  [  402 11992]]
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.53      0.58       335
#            1       0.95      0.97      0.96      3100
#
#     accuracy                           0.93      3435
#    macro avg       0.80      0.75      0.77      3435
# weighted avg       0.92      0.93      0.92      3435
#
#
# [[ 176  159]
#  [  98 3002]]

# %% [markdown]
# <h1>Model Validation</h1>

# %% [markdown]
# <h2>Loading the test data set</h2>

# %%
test_set = pd.read_csv(DATA_PATH / "test.csv", index_col="tripid")
test_set.head()

# %%
test_set.isna().sum()

# %% [markdown]
# <h2>Feature Addition for the Test Dataset</h2>

# %%
test_set['pickup_time'] = pd.to_datetime(test_set['pickup_time'], format="%m/%d/%Y %H:%M")
test_set['drop_time'] = pd.to_datetime(test_set['drop_time'], format="%m/%d/%Y %H:%M")

# %%
test_set = test_set.assign(timeOfDay=pd.cut(test_set.pickup_time.dt.hour,[-1, 8, 20, 24],labels=['dawn','day', 'night']))

# %%
new_column = []                    #empty column for distance
for index,row in test_set.iterrows():
  lat1 = row['pick_lat'] #first row of location.lat column here
  lon1 = row['pick_lon'] #first row of location.long column here
  lat2 = row['drop_lat'] #second row of location.lat column here
  lon2 = row['drop_lon'] #second row of location.long column here
  value = dist_from_coordinates(lat1, lon1, lat2, lon2)  #get the distance
  new_column.append(value)   #append the empty list with distance values

test_set .insert(4,"distance",new_column)

# %%
durations = []
for index,row in test_set.iterrows():
  provided_duration = row['duration'] #first row of location.lat column here
  if math.isnan(provided_duration) or provided_duration <= 0 :
    time_dif = (row['drop_time'] - row['pickup_time']).seconds
    if(time_dif == 0):
        time_dif = 60
    durations.append(time_dif)
  else :  
    durations.append(provided_duration)

test_set.insert(4,"time_dif",durations)

# %%
test_set['avg_speed'] = (test_set['distance'] /  ( test_set['time_dif']) * 3600 )

# %%
test_set

# %%
test_features = test_set[['additional_fare', 'duration', 'meter_waiting', 'meter_waiting_fare',
       'meter_waiting_till_pickup','distance','avg_speed']]
preprocessed_test_features = preprocessor.fit_transform(test_features)
preprocessed_test_features_data_frame = pd.DataFrame(data=preprocessed_test_features, columns=new_columns)

# %% [markdown]
# <h2>Fare prediction and correctness prediction using Test Dataset </h2>

# %%
test_probs = estimator.predict(preprocessed_test_features_data_frame)

# %%
test_set.insert(10,'predicted_price',test_probs)

# %%
classifier_test_features = test_set[['predicted_price','fare']]

# %%
predicted_labels = classifier.predict(classifier_test_features)

# %% [markdown]
# <h2>Writing to the Submission File</h2>

# %%
submission_set = pd.read_csv(DATA_PATH / "sample_submission.csv", index_col="tripid")
submission_set.head()

submission_set['prediction']= predicted_labels

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "theNotebook = " + "'"+thename+"'";
# kernel.execute(command);

# %%
filename = '../../submissions/'+theNotebook+'/teamCluster_submission_{%i}.csv'
dirname = '../../submissions/'+theNotebook
fileversion = 1

if not os.path.exists(dirname):
    os.makedirs(dirname)
while glob.glob(filename.replace('{%i}',str(fileversion))) :
    fileversion+=1
submission_set.to_csv(filename.replace('{%i}',str(fileversion)), index=True)
print("Completed!")

# %%
submission_set['prediction'].idxmin()

# %%
submission_set['prediction'].value_counts()
