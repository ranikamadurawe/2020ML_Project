# %%
import numpy as np
import pandas as pd
import lightgbm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import math
from sklearn import metrics
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import os
import glob

from sklearn.cluster import DBSCAN, KMeans

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import pandas as pd

train_path=os.path.abspath(os.path.join(os.path.dirname("__file__"), '..', '/content/drive/My Drive/datasets/train.csv'))
training_df = pd.read_csv(train_path, index_col="tripid")

# %%
def dist_from_coordinates(lat1, lon1, lat2, lon2):
  R = 6371  # Earth radius in km

  #conversion to radians
  d_lat = np.radians(lat2-lat1)
  d_lon = np.radians(lon2-lon1)

  r_lat1 = np.radians(lat1)
  r_lat2 = np.radians(lat2)

  #haversine formula
  a = np.sin(d_lat/2.) **2 + np.cos(r_lat1) * np.cos(r_lat2) * np.sin(d_lon/2.)**2

  haversine = 2 * R * np.arcsin(np.sqrt(a))

  return haversine

# %%
training_df['pickup_time'] = pd.to_datetime(training_df['pickup_time'], format="%m/%d/%Y %H:%M")
training_df['drop_time'] = pd.to_datetime(training_df['drop_time'], format="%m/%d/%Y %H:%M")

# %%
training_df = training_df.assign(timeOfDay=pd.cut(training_df.pickup_time.dt.hour,[-1, 8, 20, 24],labels=['dawn','day', 'night']))

# %%
training_df.loc[training_df['timeOfDay'] == 'day', 'isNormalCharge'] = 1
training_df.loc[training_df['timeOfDay'] != 'day', 'isNormalCharge'] = 0

# %%
durations = []
for index,row in training_df.iterrows():
  provided_duration = row['duration'] #first row of location.lat column here
  if math.isnan(provided_duration) or provided_duration <= 0 :
    time_dif = (row['drop_time'] - row['pickup_time']).seconds
    if(time_dif == 0):
        time_dif = np.nan
    durations.append(time_dif)
  else :  
    durations.append(provided_duration)

training_df.insert(4,"time_dif",durations)

# %%
new_column = []                    #empty column for distance
for index,row in training_df.iterrows():
  lat1 = row['pick_lat'] #first row of location.lat column here
  lon1 = row['pick_lon'] #first row of location.long column here
  lat2 = row['drop_lat'] #second row of location.lat column here
  lon2 = row['drop_lon'] #second row of location.long column here
  value = dist_from_coordinates(lat1, lon1, lat2, lon2)  #get the distance
  new_column.append(value)   #append the empty list with distance values

training_df.insert(4,"distance",new_column)

# %%
training_df['time_driven'] = training_df['duration']  - training_df['meter_waiting']

# %%
chargeperhours = []
for index,row in training_df.iterrows():
    if(row['meter_waiting'] == 0):
        chargeperhour = np.nan
    else:
        chargeperhour = (row['meter_waiting_fare'] / row['meter_waiting'] * 3600)
    chargeperhours.append(chargeperhour)

training_df.insert(4,'charge_per_hour',chargeperhours)

# %%
training_df['driving_fare'] = training_df['fare']  - training_df['meter_waiting_fare'] - training_df['additional_fare']

# %%
avgspeeds = []
for index,row in training_df.iterrows():
    if(row['time_driven'] == 0):
        avgspeed = np.nan
    else:
        avgspeed = (row['distance'] / row['time_driven'] * 3600)
    avgspeeds.append(avgspeed)

training_df.insert(4,"avg_speed",avgspeeds)

# %%
costsperkm = []
for index,row in training_df.iterrows():
    if row['distance'] == 0:
        costperkm = np.nan
            
    else:
        costperkm = (row['driving_fare'] / row['distance'])
    costsperkm.append(costperkm)

training_df.insert(4,"cost_per_km",costsperkm)

# %%
training_df = training_df.replace({'label': {'incorrect': 0, 'correct' : 1}})

# %% [markdown]
# <h2>Geolocation clustering</h2>

# %%
test_path =os.path.abspath(os.path.join(os.path.dirname("__file__"), '..', '/content/drive/My Drive/datasets/test.csv'))
test_set = pd.read_csv(test_path, index_col="tripid")

# %%
pickup_locations = pd.DataFrame()
drop_locations = pd.DataFrame()
test_pickup_locations = pd.DataFrame()
test_drop_locations = pd.DataFrame()

# %%
pickup_locations[['lat','lon']] = training_df[['pick_lat','pick_lon']]
drop_locations[['lat','lon']] = training_df[['drop_lat','drop_lon']]

# %%
test_pickup_locations[['lat','lon']] = test_set[['pick_lat','pick_lon']]
test_drop_locations[['lat','lon']] = test_set[['drop_lat','drop_lon']]

# %%
test_set.shape
# Out:
# (8576, 12)

# %%
training_df.shape
# Out:
# (17176, 22)

# %%
pickup_locations = pickup_locations.reset_index()
drop_locations = drop_locations.reset_index()
test_pickup_locations = test_pickup_locations.reset_index()
test_drop_locations = test_drop_locations.reset_index()

# %%
df = pd.concat([pickup_locations,drop_locations,test_pickup_locations,test_drop_locations],ignore_index=True )

# %%
db_pick = DBSCAN(eps=1/6371., min_samples=5, algorithm='ball_tree', metric='haversine').fit(np.radians(df[['lat','lon']]))

# %%
db_pick.labels_[0:17176]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
training_df['pickup_cluster_label'] = db_pick.labels_[0:17176]

# %%
training_df['drop_cluster_label'] = db_pick.labels_[17176:17176*2]

# %%
training_df['drop_cluster_label'].value_counts()
# Out:
#  0     14315
#  1      1818
#  4       307
#  2       262
# -1       244
#  6        67
#  3        55
#  5        25
#  15        9
#  17        8
#  11        8
#  7         6
#  21        6
#  20        5
#  16        4
#  25        4
#  18        3
#  24        3
#  23        3
#  26        3
#  13        3
#  19        3
#  14        2
#  10        2
#  28        2
#  12        2
#  22        2
#  8         2
#  9         2
#  27        1
# Name: drop_cluster_label, dtype: int64

# %% [markdown]
# <h2>Selecting the features</h2>

# %%
training_df.columns
# Out:
# Index(['additional_fare', 'duration', 'meter_waiting', 'meter_waiting_fare',
#        'cost_per_km', 'avg_speed', 'charge_per_hour', 'distance', 'time_dif',
#        'meter_waiting_till_pickup', 'pickup_time', 'drop_time', 'pick_lat',
#        'pick_lon', 'drop_lat', 'drop_lon', 'fare', 'label', 'timeOfDay',
#        'isNormalCharge', 'time_driven', 'driving_fare', 'pickup_cluster_label',
#        'drop_cluster_label'],
#       dtype='object')

# %%
training_columns = ['meter_waiting','meter_waiting_fare','fare','additional_fare', 'distance','cost_per_km', 'avg_speed',  'time_dif','time_driven', 'charge_per_hour', 'driving_fare', 'isNormalCharge','drop_cluster_label','pickup_cluster_label']

# %%
training_columns = ['meter_waiting','meter_waiting_fare','fare','additional_fare', 'distance','cost_per_km', 'avg_speed',  'time_dif','time_driven', 'charge_per_hour', 'driving_fare', 'isNormalCharge','pick_lat','pick_lon','drop_lat','drop_lon','drop_cluster_label','pickup_cluster_label']

# %%
target_column = ['label']

# %%
training_df = training_df.drop(190167541)

# %%
x = training_df[training_columns].values
y = training_df[target_column].values

# %%
x, x_test, y, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
training_df['label'].value_counts()
# Out:
# 1    15494
# 0     1681
# Name: label, dtype: int64

# %% [markdown]
# <h2>Choosing the best model</h2>

# %%
def focal_loss_lgb_eval_error(y_true, y_pred, alpha=.25, gamma=2.):
    a,g = alpha, gamma
    p = 1/(1+np.exp(-y_pred))
    loss = -( a*y_true + (1-a)*(1-y_true) ) * (( 1 - ( y_true*p + (1-y_true)*(1-p)) )**g) * ( y_true*np.log(p)+(1-y_true)*np.log(1-p) )
    return 'focal_loss', np.mean(loss), False

# %%
from sklearn.metrics import f1_score
def evaluate_macroF1_lgb(y_true, y_pred):  
    y_hat = np.where(y_pred < 0.5, 0, 1) 
    f1 = f1_score(y_true, y_hat, average='macro')
    return ('macroF1', f1, True)

# %%
gkf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
model = lightgbm.LGBMClassifier(class_weight={0:1.5,1:1}, learning_rate=0.1)

# %%
for training_index, testing_index in gkf.split(X=x, y=y):
    x_train_fold, y_train_fold = x[training_index], y[training_index]
    x_test_fold, y_test_fold = x[testing_index], y[testing_index]
    model.fit(x_train_fold, y_train_fold, eval_set=(x_test_fold,y_test_fold),eval_metric = lambda y_true, y_pred: [evaluate_macroF1_lgb(y_true,y_pred)])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	valid_0's binary_logloss: 0.28951	valid_0's macroF1: 0.474268
# [2]	valid_0's binary_logloss: 0.266245	valid_0's macroF1: 0.474268
# [3]	valid_0's binary_logloss: 0.248837	valid_0's macroF1: 0.474268
# [4]	valid_0's binary_logloss: 0.235365	valid_0's macroF1: 0.474268
# [5]	valid_0's binary_logloss: 0.224279	valid_0's macroF1: 0.691565
# [6]	valid_0's binary_logloss: 0.214593	valid_0's macroF1: 0.743383
# [7]	valid_0's binary_logloss: 0.206098	valid_0's macroF1: 0.79792
# [8]	valid_0's binary_logloss: 0.198465	valid_0's macroF1: 0.810983
# [9]	valid_0's binary_logloss: 0.192515	valid_0's macroF1: 0.820103
# [10]	valid_0's binary_logloss: 0.186296	valid_0's macroF1: 0.826652
# [11]	valid_0's binary_logloss: 0.181639	valid_0's macroF1: 0.837845
# [12]	valid_0's binary_logloss: 0.177881	valid_0's macroF1: 0.839369
# [13]	valid_0's binary_logloss: 0.174443	valid_0's macroF1: 0.837385
# [14]	valid_0's binary_logloss: 0.171348	valid_0's macroF1: 0.840413
# [15]	valid_0's binary_logloss: 0.16799	valid_0's macroF1: 0.842038
# [16]	valid_0's binary_logloss: 0.165425	valid_0's macroF1: 0.845577
# [17]	valid_0's binary_logloss: 0.163209	valid_0's macroF1: 0.842649
# [18]	valid_0's binary_logloss: 0.160744	valid_0's macroF1: 0.844116
# [19]	valid_0's binary_logloss: 0.159037	valid_0's macroF1: 0.847617
# [20]	valid_0's binary_logloss: 0.156753	valid_0's macroF1: 0.849633
# [21]	valid_0's binary_logloss: 0.155292	valid_0's macroF1: 0.851364
# [22]	valid_0's binary_logloss: 0.153446	valid_0's macroF1: 0.855646
# [23]	valid_0's binary_logloss: 0.152051	valid_0's macroF1: 0.8576
# [24]	valid_0's binary_logloss: 0.150811	valid_0's macroF1: 0.85619
# [25]	valid_0's binary_logloss: 0.14998	valid_0's macroF1: 0.859878
# [26]	valid_0's binary_logloss: 0.148799	valid_0's macroF1: 0.85673
# [27]	valid_0's binary_logloss: 0.14769	valid_0's macroF1: 0.860923
# [28]	valid_0's binary_logloss: 0.146607	valid_0's macroF1: 0.864567
# [29]	valid_0's binary_logloss: 0.145951	valid_0's macroF1: 0.863692
# [30]	valid_0's binary_logloss: 0.14511	valid_0's macroF1: 0.864567
# [31]	valid_0's binary_logloss: 0.144297	valid_0's macroF1: 0.865446
# [32]	valid_0's binary_logloss: 0.143852	valid_0's macroF1: 0.866824
# [33]	valid_0's binary_logloss: 0.143348	valid_0's macroF1: 0.865446
# [34]	valid_0's binary_logloss: 0.143105	valid_0's macroF1: 0.865945
# [35]	valid_0's binary_logloss: 0.142956	valid_0's macroF1: 0.863184
# [36]	valid_0's binary_logloss: 0.142659	valid_0's macroF1: 0.863184
# [37]	valid_0's binary_logloss: 0.142366	valid_0's macroF1: 0.864062
# [38]	valid_0's binary_logloss: 0.142309	valid_0's macroF1: 0.864062
# [39]	valid_0's binary_logloss: 0.1419	valid_0's macroF1: 0.862673
# [40]	valid_0's binary_logloss: 0.141738	valid_0's macroF1: 0.864062
# [41]	valid_0's binary_logloss: 0.141852	valid_0's macroF1: 0.865446
# [42]	valid_0's binary_logloss: 0.141933	valid_0's macroF1: 0.863184
# [43]	valid_0's binary_logloss: 0.141744	valid_0's macroF1: 0.866327
# [44]	valid_0's binary_logloss: 0.141486	valid_0's macroF1: 0.865446
# [45]	valid_0's binary_logloss: 0.14161	valid_0's macroF1: 0.864062
# [46]	valid_0's binary_logloss: 0.141476	valid_0's macroF1: 0.863184
# [47]	valid_0's binary_logloss: 0.141062	valid_0's macroF1: 0.864062
# [48]	valid_0's binary_logloss: 0.141358	valid_0's macroF1: 0.860571
# [49]	valid_0's binary_logloss: 0.141011	valid_0's macroF1: 0.859706
# [50]	valid_0's binary_logloss: 0.141058	valid_0's macroF1: 0.859706
# [51]	valid_0's binary_logloss: 0.141031	valid_0's macroF1: 0.860571
# [52]	valid_0's binary_logloss: 0.140924	valid_0's macroF1: 0.861439
# [53]	valid_0's binary_logloss: 0.140942	valid_0's macroF1: 0.861439
# [54]	valid_0's binary_logloss: 0.141006	valid_0's macroF1: 0.862819
# [55]	valid_0's binary_logloss: 0.140852	valid_0's macroF1: 0.862819
# [56]	valid_0's binary_logloss: 0.140914	valid_0's macroF1: 0.863325
# [57]	valid_0's binary_logloss: 0.140564	valid_0's macroF1: 0.865565
# [58]	valid_0's binary_logloss: 0.140215	valid_0's macroF1: 0.86644
# [59]	valid_0's binary_logloss: 0.139924	valid_0's macroF1: 0.86644
# [60]	valid_0's binary_logloss: 0.140166	valid_0's macroF1: 0.867317
# [61]	valid_0's binary_logloss: 0.140276	valid_0's macroF1: 0.867317
# [62]	valid_0's binary_logloss: 0.1402	valid_0's macroF1: 0.869167
# [63]	valid_0's binary_logloss: 0.140125	valid_0's macroF1: 0.868291
# [64]	valid_0's binary_logloss: 0.139915	valid_0's macroF1: 0.867417
# [65]	valid_0's binary_logloss: 0.139903	valid_0's macroF1: 0.867417
# [66]	valid_0's binary_logloss: 0.140099	valid_0's macroF1: 0.864323
# [67]	valid_0's binary_logloss: 0.139875	valid_0's macroF1: 0.863826
# [68]	valid_0's binary_logloss: 0.139869	valid_0's macroF1: 0.863826
# [69]	valid_0's binary_logloss: 0.139894	valid_0's macroF1: 0.864694
# [70]	valid_0's binary_logloss: 0.139931	valid_0's macroF1: 0.864694
# [71]	valid_0's binary_logloss: 0.139994	valid_0's macroF1: 0.865565
# [72]	valid_0's binary_logloss: 0.14011	valid_0's macroF1: 0.864694
# [73]	valid_0's binary_logloss: 0.139958	valid_0's macroF1: 0.863826
# [74]	valid_0's binary_logloss: 0.14027	valid_0's macroF1: 0.861594
# [75]	valid_0's binary_logloss: 0.140353	valid_0's macroF1: 0.861594
# [76]	valid_0's binary_logloss: 0.140468	valid_0's macroF1: 0.861594
# [77]	valid_0's binary_logloss: 0.140514	valid_0's macroF1: 0.862458
# [78]	valid_0's binary_logloss: 0.140288	valid_0's macroF1: 0.86195
# [79]	valid_0's binary_logloss: 0.140136	valid_0's macroF1: 0.860571
# [80]	valid_0's binary_logloss: 0.140028	valid_0's macroF1: 0.86195
# [81]	valid_0's binary_logloss: 0.140104	valid_0's macroF1: 0.86195
# [82]	valid_0's binary_logloss: 0.140225	valid_0's macroF1: 0.861084
# [83]	valid_0's binary_logloss: 0.140172	valid_0's macroF1: 0.860221
# [84]	valid_0's binary_logloss: 0.140489	valid_0's macroF1: 0.860221
# [85]	valid_0's binary_logloss: 0.140643	valid_0's macroF1: 0.860221
# [86]	valid_0's binary_logloss: 0.140933	valid_0's macroF1: 0.859706
# [87]	valid_0's binary_logloss: 0.141206	valid_0's macroF1: 0.858844
# [88]	valid_0's binary_logloss: 0.141413	valid_0's macroF1: 0.858844
# [89]	valid_0's binary_logloss: 0.141618	valid_0's macroF1: 0.858844
# [90]	valid_0's binary_logloss: 0.141554	valid_0's macroF1: 0.859706
# [91]	valid_0's binary_logloss: 0.141516	valid_0's macroF1: 0.859706
# [92]	valid_0's binary_logloss: 0.141639	valid_0's macroF1: 0.859706
# [93]	valid_0's binary_logloss: 0.141932	valid_0's macroF1: 0.859706
# [94]	valid_0's binary_logloss: 0.141928	valid_0's macroF1: 0.859706
# [95]	valid_0's binary_logloss: 0.14173	valid_0's macroF1: 0.859706
# [96]	valid_0's binary_logloss: 0.141983	valid_0's macroF1: 0.860221
# [97]	valid_0's binary_logloss: 0.142107	valid_0's macroF1: 0.861084
# [98]	valid_0's binary_logloss: 0.142052	valid_0's macroF1: 0.861084
# [99]	valid_0's binary_logloss: 0.142103	valid_0's macroF1: 0.861084
# [100]	valid_0's binary_logloss: 0.142221	valid_0's macroF1: 0.857461
# [1]	valid_0's binary_logloss: 0.292416	valid_0's macroF1: 0.474268
# [2]	valid_0's binary_logloss: 0.27074	valid_0's macroF1: 0.474268
# [3]	valid_0's binary_logloss: 0.254827	valid_0's macroF1: 0.474268
# [4]	valid_0's binary_logloss: 0.241028	valid_0's macroF1: 0.474268
# [5]	valid_0's binary_logloss: 0.229839	valid_0's macroF1: 0.664717
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [6]	valid_0's binary_logloss: 0.220006	valid_0's macroF1: 0.739199
# [7]	valid_0's binary_logloss: 0.212167	valid_0's macroF1: 0.765945
# [8]	valid_0's binary_logloss: 0.204256	valid_0's macroF1: 0.786269
# [9]	valid_0's binary_logloss: 0.198526	valid_0's macroF1: 0.801485
# [10]	valid_0's binary_logloss: 0.193344	valid_0's macroF1: 0.804075
# [11]	valid_0's binary_logloss: 0.188255	valid_0's macroF1: 0.810014
# [12]	valid_0's binary_logloss: 0.184398	valid_0's macroF1: 0.812437
# [13]	valid_0's binary_logloss: 0.180773	valid_0's macroF1: 0.80992
# [14]	valid_0's binary_logloss: 0.17735	valid_0's macroF1: 0.813939
# [15]	valid_0's binary_logloss: 0.174694	valid_0's macroF1: 0.813939
# [16]	valid_0's binary_logloss: 0.171739	valid_0's macroF1: 0.815564
# [17]	valid_0's binary_logloss: 0.169926	valid_0's macroF1: 0.817085
# [18]	valid_0's binary_logloss: 0.167485	valid_0's macroF1: 0.823448
# [19]	valid_0's binary_logloss: 0.166202	valid_0's macroF1: 0.831932
# [20]	valid_0's binary_logloss: 0.164609	valid_0's macroF1: 0.832602
# [21]	valid_0's binary_logloss: 0.163247	valid_0's macroF1: 0.832409
# [22]	valid_0's binary_logloss: 0.162132	valid_0's macroF1: 0.830702
# [23]	valid_0's binary_logloss: 0.160998	valid_0's macroF1: 0.833524
# [24]	valid_0's binary_logloss: 0.160235	valid_0's macroF1: 0.832678
# [25]	valid_0's binary_logloss: 0.158948	valid_0's macroF1: 0.835656
# [26]	valid_0's binary_logloss: 0.158129	valid_0's macroF1: 0.836289
# [27]	valid_0's binary_logloss: 0.157753	valid_0's macroF1: 0.837136
# [28]	valid_0's binary_logloss: 0.157178	valid_0's macroF1: 0.837987
# [29]	valid_0's binary_logloss: 0.156258	valid_0's macroF1: 0.836505
# [30]	valid_0's binary_logloss: 0.155995	valid_0's macroF1: 0.840318
# [31]	valid_0's binary_logloss: 0.155091	valid_0's macroF1: 0.840079
# [32]	valid_0's binary_logloss: 0.155131	valid_0's macroF1: 0.842397
# [33]	valid_0's binary_logloss: 0.154852	valid_0's macroF1: 0.843
# [34]	valid_0's binary_logloss: 0.154415	valid_0's macroF1: 0.846756
# [35]	valid_0's binary_logloss: 0.154173	valid_0's macroF1: 0.846756
# [36]	valid_0's binary_logloss: 0.154101	valid_0's macroF1: 0.847337
# [37]	valid_0's binary_logloss: 0.153974	valid_0's macroF1: 0.846481
# [38]	valid_0's binary_logloss: 0.153943	valid_0's macroF1: 0.848772
# [39]	valid_0's binary_logloss: 0.154246	valid_0's macroF1: 0.851625
# [40]	valid_0's binary_logloss: 0.154162	valid_0's macroF1: 0.850765
# [41]	valid_0's binary_logloss: 0.154519	valid_0's macroF1: 0.850765
# [42]	valid_0's binary_logloss: 0.154208	valid_0's macroF1: 0.848486
# [43]	valid_0's binary_logloss: 0.153618	valid_0's macroF1: 0.849342
# [44]	valid_0's binary_logloss: 0.153795	valid_0's macroF1: 0.848486
# [45]	valid_0's binary_logloss: 0.153477	valid_0's macroF1: 0.847059
# [46]	valid_0's binary_logloss: 0.153255	valid_0's macroF1: 0.842494
# [47]	valid_0's binary_logloss: 0.153097	valid_0's macroF1: 0.841053
# [48]	valid_0's binary_logloss: 0.152779	valid_0's macroF1: 0.84334
# [49]	valid_0's binary_logloss: 0.152613	valid_0's macroF1: 0.84334
# [50]	valid_0's binary_logloss: 0.152815	valid_0's macroF1: 0.84334
# [51]	valid_0's binary_logloss: 0.152644	valid_0's macroF1: 0.84334
# [52]	valid_0's binary_logloss: 0.152525	valid_0's macroF1: 0.844189
# [53]	valid_0's binary_logloss: 0.152284	valid_0's macroF1: 0.84334
# [54]	valid_0's binary_logloss: 0.152227	valid_0's macroF1: 0.844189
# [55]	valid_0's binary_logloss: 0.152489	valid_0's macroF1: 0.845897
# [56]	valid_0's binary_logloss: 0.152477	valid_0's macroF1: 0.845042
# [57]	valid_0's binary_logloss: 0.152454	valid_0's macroF1: 0.844189
# [58]	valid_0's binary_logloss: 0.152214	valid_0's macroF1: 0.845042
# [59]	valid_0's binary_logloss: 0.152015	valid_0's macroF1: 0.845308
# [60]	valid_0's binary_logloss: 0.151822	valid_0's macroF1: 0.848197
# [61]	valid_0's binary_logloss: 0.151575	valid_0's macroF1: 0.845897
# [62]	valid_0's binary_logloss: 0.151673	valid_0's macroF1: 0.843856
# [63]	valid_0's binary_logloss: 0.151498	valid_0's macroF1: 0.844451
# [64]	valid_0's binary_logloss: 0.15138	valid_0's macroF1: 0.842147
# [65]	valid_0's binary_logloss: 0.151429	valid_0's macroF1: 0.842147
# [66]	valid_0's binary_logloss: 0.151733	valid_0's macroF1: 0.843856
# [67]	valid_0's binary_logloss: 0.15173	valid_0's macroF1: 0.843
# [68]	valid_0's binary_logloss: 0.151643	valid_0's macroF1: 0.843
# [69]	valid_0's binary_logloss: 0.151889	valid_0's macroF1: 0.842147
# [70]	valid_0's binary_logloss: 0.151771	valid_0's macroF1: 0.842746
# [71]	valid_0's binary_logloss: 0.151815	valid_0's macroF1: 0.843597
# [72]	valid_0's binary_logloss: 0.152105	valid_0's macroF1: 0.843597
# [73]	valid_0's binary_logloss: 0.152128	valid_0's macroF1: 0.844189
# [74]	valid_0's binary_logloss: 0.152045	valid_0's macroF1: 0.848197
# [75]	valid_0's binary_logloss: 0.152288	valid_0's macroF1: 0.84906
# [76]	valid_0's binary_logloss: 0.152472	valid_0's macroF1: 0.849633
# [77]	valid_0's binary_logloss: 0.152306	valid_0's macroF1: 0.847914
# [78]	valid_0's binary_logloss: 0.152364	valid_0's macroF1: 0.846481
# [79]	valid_0's binary_logloss: 0.15231	valid_0's macroF1: 0.847337
# [80]	valid_0's binary_logloss: 0.152267	valid_0's macroF1: 0.847337
# [81]	valid_0's binary_logloss: 0.152321	valid_0's macroF1: 0.849633
# [82]	valid_0's binary_logloss: 0.15279	valid_0's macroF1: 0.848772
# [83]	valid_0's binary_logloss: 0.153121	valid_0's macroF1: 0.847914
# [84]	valid_0's binary_logloss: 0.153223	valid_0's macroF1: 0.846481
# [85]	valid_0's binary_logloss: 0.153468	valid_0's macroF1: 0.846481
# [86]	valid_0's binary_logloss: 0.153668	valid_0's macroF1: 0.845627
# [87]	valid_0's binary_logloss: 0.153717	valid_0's macroF1: 0.845627
# [88]	valid_0's binary_logloss: 0.153695	valid_0's macroF1: 0.846481
# [89]	valid_0's binary_logloss: 0.153705	valid_0's macroF1: 0.846481
# [90]	valid_0's binary_logloss: 0.153814	valid_0's macroF1: 0.845897
# [91]	valid_0's binary_logloss: 0.153433	valid_0's macroF1: 0.845897
# [92]	valid_0's binary_logloss: 0.153386	valid_0's macroF1: 0.847617
# [93]	valid_0's binary_logloss: 0.15351	valid_0's macroF1: 0.847617
# [94]	valid_0's binary_logloss: 0.153485	valid_0's macroF1: 0.846169
# [95]	valid_0's binary_logloss: 0.153587	valid_0's macroF1: 0.847033
# [96]	valid_0's binary_logloss: 0.153571	valid_0's macroF1: 0.847033
# [97]	valid_0's binary_logloss: 0.153318	valid_0's macroF1: 0.84935
# [98]	valid_0's binary_logloss: 0.153385	valid_0's macroF1: 0.84935
# [99]	valid_0's binary_logloss: 0.153714	valid_0's macroF1: 0.84935
# [100]	valid_0's binary_logloss: 0.153801	valid_0's macroF1: 0.84935
# [1]	valid_0's binary_logloss: 0.29398	valid_0's macroF1: 0.474268
# [2]	valid_0's binary_logloss: 0.271964	valid_0's macroF1: 0.474268
# [3]	valid_0's binary_logloss: 0.2559	valid_0's macroF1: 0.474268
# [4]	valid_0's binary_logloss: 0.242102	valid_0's macroF1: 0.474268
# [5]	valid_0's binary_logloss: 0.230446	valid_0's macroF1: 0.648442
# [6]	valid_0's binary_logloss: 0.220618	valid_0's macroF1: 0.750002
# [7]	valid_0's binary_logloss: 0.212485	valid_0's macroF1: 0.771408
# [8]	valid_0's binary_logloss: 0.205891	valid_0's macroF1: 0.787239
# [9]	valid_0's binary_logloss: 0.200296	valid_0's macroF1: 0.804069
# [10]	valid_0's binary_logloss: 0.195181	valid_0's macroF1: 0.809109
# [11]	valid_0's binary_logloss: 0.189827	valid_0's macroF1: 0.819008
# [12]	valid_0's binary_logloss: 0.185093	valid_0's macroF1: 0.824594
# [13]	valid_0's binary_logloss: 0.181413	valid_0's macroF1: 0.82445
# [14]	valid_0's binary_logloss: 0.177784	valid_0's macroF1: 0.826748
# [15]	valid_0's binary_logloss: 0.17459	valid_0's macroF1: 0.828152
# [16]	valid_0's binary_logloss: 0.172302	valid_0's macroF1: 0.833267
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [17]	valid_0's binary_logloss: 0.1701	valid_0's macroF1: 0.832409
# [18]	valid_0's binary_logloss: 0.168271	valid_0's macroF1: 0.835437
# [19]	valid_0's binary_logloss: 0.166474	valid_0's macroF1: 0.83307
# [20]	valid_0's binary_logloss: 0.164585	valid_0's macroF1: 0.839935
# [21]	valid_0's binary_logloss: 0.163084	valid_0's macroF1: 0.842038
# [22]	valid_0's binary_logloss: 0.161557	valid_0's macroF1: 0.84179
# [23]	valid_0's binary_logloss: 0.160355	valid_0's macroF1: 0.843856
# [24]	valid_0's binary_logloss: 0.159455	valid_0's macroF1: 0.843
# [25]	valid_0's binary_logloss: 0.158441	valid_0's macroF1: 0.844451
# [26]	valid_0's binary_logloss: 0.15743	valid_0's macroF1: 0.846756
# [27]	valid_0's binary_logloss: 0.156431	valid_0's macroF1: 0.848772
# [28]	valid_0's binary_logloss: 0.155634	valid_0's macroF1: 0.849633
# [29]	valid_0's binary_logloss: 0.15501	valid_0's macroF1: 0.849633
# [30]	valid_0's binary_logloss: 0.154152	valid_0's macroF1: 0.848772
# [31]	valid_0's binary_logloss: 0.153281	valid_0's macroF1: 0.848772
# [32]	valid_0's binary_logloss: 0.153081	valid_0's macroF1: 0.848197
# [33]	valid_0's binary_logloss: 0.152585	valid_0's macroF1: 0.847337
# [34]	valid_0's binary_logloss: 0.152078	valid_0's macroF1: 0.843597
# [35]	valid_0's binary_logloss: 0.151619	valid_0's macroF1: 0.844777
# [36]	valid_0's binary_logloss: 0.151709	valid_0's macroF1: 0.847059
# [37]	valid_0's binary_logloss: 0.151291	valid_0's macroF1: 0.846783
# [38]	valid_0's binary_logloss: 0.15079	valid_0's macroF1: 0.845359
# [39]	valid_0's binary_logloss: 0.150771	valid_0's macroF1: 0.845627
# [40]	valid_0's binary_logloss: 0.150653	valid_0's macroF1: 0.84334
# [41]	valid_0's binary_logloss: 0.150576	valid_0's macroF1: 0.844189
# [42]	valid_0's binary_logloss: 0.150794	valid_0's macroF1: 0.845042
# [43]	valid_0's binary_logloss: 0.150732	valid_0's macroF1: 0.847914
# [44]	valid_0's binary_logloss: 0.150378	valid_0's macroF1: 0.849342
# [45]	valid_0's binary_logloss: 0.149732	valid_0's macroF1: 0.851063
# [46]	valid_0's binary_logloss: 0.150142	valid_0's macroF1: 0.851063
# [47]	valid_0's binary_logloss: 0.150112	valid_0's macroF1: 0.851929
# [48]	valid_0's binary_logloss: 0.150024	valid_0's macroF1: 0.851364
# [49]	valid_0's binary_logloss: 0.150115	valid_0's macroF1: 0.850497
# [50]	valid_0's binary_logloss: 0.149764	valid_0's macroF1: 0.850497
# [51]	valid_0's binary_logloss: 0.149858	valid_0's macroF1: 0.84906
# [52]	valid_0's binary_logloss: 0.149858	valid_0's macroF1: 0.846756
# [53]	valid_0's binary_logloss: 0.149756	valid_0's macroF1: 0.849633
# [54]	valid_0's binary_logloss: 0.149382	valid_0's macroF1: 0.850497
# [55]	valid_0's binary_logloss: 0.149138	valid_0's macroF1: 0.849633
# [56]	valid_0's binary_logloss: 0.149028	valid_0's macroF1: 0.847337
# [57]	valid_0's binary_logloss: 0.148854	valid_0's macroF1: 0.851063
# [58]	valid_0's binary_logloss: 0.148796	valid_0's macroF1: 0.849633
# [59]	valid_0's binary_logloss: 0.148751	valid_0's macroF1: 0.851063
# [60]	valid_0's binary_logloss: 0.14858	valid_0's macroF1: 0.849633
# [61]	valid_0's binary_logloss: 0.148302	valid_0's macroF1: 0.847617
# [62]	valid_0's binary_logloss: 0.148077	valid_0's macroF1: 0.847617
# [63]	valid_0's binary_logloss: 0.147857	valid_0's macroF1: 0.84906
# [64]	valid_0's binary_logloss: 0.147717	valid_0's macroF1: 0.848197
# [65]	valid_0's binary_logloss: 0.147625	valid_0's macroF1: 0.848197
# [66]	valid_0's binary_logloss: 0.147359	valid_0's macroF1: 0.849633
# [67]	valid_0's binary_logloss: 0.147447	valid_0's macroF1: 0.848772
# [68]	valid_0's binary_logloss: 0.147553	valid_0's macroF1: 0.850201
# [69]	valid_0's binary_logloss: 0.147772	valid_0's macroF1: 0.850201
# [70]	valid_0's binary_logloss: 0.147845	valid_0's macroF1: 0.850201
# [71]	valid_0's binary_logloss: 0.147825	valid_0's macroF1: 0.852488
# [72]	valid_0's binary_logloss: 0.148012	valid_0's macroF1: 0.850765
# [73]	valid_0's binary_logloss: 0.148092	valid_0's macroF1: 0.850765
# [74]	valid_0's binary_logloss: 0.148173	valid_0's macroF1: 0.850765
# [75]	valid_0's binary_logloss: 0.148363	valid_0's macroF1: 0.850765
# [76]	valid_0's binary_logloss: 0.148563	valid_0's macroF1: 0.849907
# [77]	valid_0's binary_logloss: 0.148694	valid_0's macroF1: 0.850765
# [78]	valid_0's binary_logloss: 0.148548	valid_0's macroF1: 0.850201
# [79]	valid_0's binary_logloss: 0.148971	valid_0's macroF1: 0.849907
# [80]	valid_0's binary_logloss: 0.149311	valid_0's macroF1: 0.848202
# [81]	valid_0's binary_logloss: 0.149534	valid_0's macroF1: 0.846783
# [82]	valid_0's binary_logloss: 0.149634	valid_0's macroF1: 0.849053
# [83]	valid_0's binary_logloss: 0.1495	valid_0's macroF1: 0.847633
# [84]	valid_0's binary_logloss: 0.149597	valid_0's macroF1: 0.847633
# [85]	valid_0's binary_logloss: 0.149625	valid_0's macroF1: 0.848202
# [86]	valid_0's binary_logloss: 0.14977	valid_0's macroF1: 0.847633
# [87]	valid_0's binary_logloss: 0.14986	valid_0's macroF1: 0.847633
# [88]	valid_0's binary_logloss: 0.149938	valid_0's macroF1: 0.848486
# [89]	valid_0's binary_logloss: 0.14984	valid_0's macroF1: 0.849342
# [90]	valid_0's binary_logloss: 0.149795	valid_0's macroF1: 0.848486
# [91]	valid_0's binary_logloss: 0.149771	valid_0's macroF1: 0.849907
# [92]	valid_0's binary_logloss: 0.150039	valid_0's macroF1: 0.849342
# [93]	valid_0's binary_logloss: 0.150001	valid_0's macroF1: 0.849342
# [94]	valid_0's binary_logloss: 0.150018	valid_0's macroF1: 0.849342
# [95]	valid_0's binary_logloss: 0.15034	valid_0's macroF1: 0.848486
# [96]	valid_0's binary_logloss: 0.150294	valid_0's macroF1: 0.849342
# [97]	valid_0's binary_logloss: 0.150344	valid_0's macroF1: 0.850201
# [98]	valid_0's binary_logloss: 0.150596	valid_0's macroF1: 0.850201
# [99]	valid_0's binary_logloss: 0.151004	valid_0's macroF1: 0.850201
# [100]	valid_0's binary_logloss: 0.151062	valid_0's macroF1: 0.851063
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	valid_0's binary_logloss: 0.29051	valid_0's macroF1: 0.474268
# [2]	valid_0's binary_logloss: 0.267613	valid_0's macroF1: 0.474268
# [3]	valid_0's binary_logloss: 0.249636	valid_0's macroF1: 0.474268
# [4]	valid_0's binary_logloss: 0.235278	valid_0's macroF1: 0.48183
# [5]	valid_0's binary_logloss: 0.223721	valid_0's macroF1: 0.722897
# [6]	valid_0's binary_logloss: 0.21301	valid_0's macroF1: 0.752442
# [7]	valid_0's binary_logloss: 0.204443	valid_0's macroF1: 0.79875
# [8]	valid_0's binary_logloss: 0.196781	valid_0's macroF1: 0.81865
# [9]	valid_0's binary_logloss: 0.190795	valid_0's macroF1: 0.817665
# [10]	valid_0's binary_logloss: 0.185426	valid_0's macroF1: 0.822636
# [11]	valid_0's binary_logloss: 0.179764	valid_0's macroF1: 0.819008
# [12]	valid_0's binary_logloss: 0.175199	valid_0's macroF1: 0.823862
# [13]	valid_0's binary_logloss: 0.171453	valid_0's macroF1: 0.832506
# [14]	valid_0's binary_logloss: 0.16819	valid_0's macroF1: 0.833189
# [15]	valid_0's binary_logloss: 0.164845	valid_0's macroF1: 0.835413
# [16]	valid_0's binary_logloss: 0.162316	valid_0's macroF1: 0.841289
# [17]	valid_0's binary_logloss: 0.160308	valid_0's macroF1: 0.840413
# [18]	valid_0's binary_logloss: 0.158481	valid_0's macroF1: 0.841044
# [19]	valid_0's binary_logloss: 0.155831	valid_0's macroF1: 0.840173
# [20]	valid_0's binary_logloss: 0.154315	valid_0's macroF1: 0.839306
# [21]	valid_0's binary_logloss: 0.152352	valid_0's macroF1: 0.8408
# [22]	valid_0's binary_logloss: 0.150401	valid_0's macroF1: 0.841422
# [23]	valid_0's binary_logloss: 0.14888	valid_0's macroF1: 0.8408
# [24]	valid_0's binary_logloss: 0.147554	valid_0's macroF1: 0.842541
# [25]	valid_0's binary_logloss: 0.146243	valid_0's macroF1: 0.845248
# [26]	valid_0's binary_logloss: 0.145166	valid_0's macroF1: 0.846121
# [27]	valid_0's binary_logloss: 0.144065	valid_0's macroF1: 0.847593
# [28]	valid_0's binary_logloss: 0.143214	valid_0's macroF1: 0.849643
# [29]	valid_0's binary_logloss: 0.142093	valid_0's macroF1: 0.852855
# [30]	valid_0's binary_logloss: 0.140691	valid_0's macroF1: 0.854305
# [31]	valid_0's binary_logloss: 0.140198	valid_0's macroF1: 0.852855
# [32]	valid_0's binary_logloss: 0.139267	valid_0's macroF1: 0.855749
# [33]	valid_0's binary_logloss: 0.13886	valid_0's macroF1: 0.857188
# [34]	valid_0's binary_logloss: 0.138637	valid_0's macroF1: 0.857188
# [35]	valid_0's binary_logloss: 0.137998	valid_0's macroF1: 0.858621
# [36]	valid_0's binary_logloss: 0.137351	valid_0's macroF1: 0.858621
# [37]	valid_0's binary_logloss: 0.137457	valid_0's macroF1: 0.857188
# [38]	valid_0's binary_logloss: 0.137229	valid_0's macroF1: 0.857188
# [39]	valid_0's binary_logloss: 0.137157	valid_0's macroF1: 0.857188
# [40]	valid_0's binary_logloss: 0.136761	valid_0's macroF1: 0.857735
# [41]	valid_0's binary_logloss: 0.136701	valid_0's macroF1: 0.857735
# [42]	valid_0's binary_logloss: 0.136303	valid_0's macroF1: 0.859161
# [43]	valid_0's binary_logloss: 0.136152	valid_0's macroF1: 0.856853
# [44]	valid_0's binary_logloss: 0.135764	valid_0's macroF1: 0.860048
# [45]	valid_0's binary_logloss: 0.135696	valid_0's macroF1: 0.858816
# [46]	valid_0's binary_logloss: 0.135693	valid_0's macroF1: 0.859697
# [47]	valid_0's binary_logloss: 0.135644	valid_0's macroF1: 0.857397
# [48]	valid_0's binary_logloss: 0.135838	valid_0's macroF1: 0.857397
# [49]	valid_0's binary_logloss: 0.135935	valid_0's macroF1: 0.857397
# [50]	valid_0's binary_logloss: 0.135658	valid_0's macroF1: 0.857397
# [51]	valid_0's binary_logloss: 0.135957	valid_0's macroF1: 0.857397
# [52]	valid_0's binary_logloss: 0.135823	valid_0's macroF1: 0.857397
# [53]	valid_0's binary_logloss: 0.136098	valid_0's macroF1: 0.85652
# [54]	valid_0's binary_logloss: 0.135842	valid_0's macroF1: 0.85652
# [55]	valid_0's binary_logloss: 0.13588	valid_0's macroF1: 0.855646
# [56]	valid_0's binary_logloss: 0.135514	valid_0's macroF1: 0.857062
# [57]	valid_0's binary_logloss: 0.135829	valid_0's macroF1: 0.85619
# [58]	valid_0's binary_logloss: 0.135735	valid_0's macroF1: 0.854775
# [59]	valid_0's binary_logloss: 0.135541	valid_0's macroF1: 0.854775
# [60]	valid_0's binary_logloss: 0.135647	valid_0's macroF1: 0.85619
# [61]	valid_0's binary_logloss: 0.135804	valid_0's macroF1: 0.853907
# [62]	valid_0's binary_logloss: 0.135783	valid_0's macroF1: 0.854775
# [63]	valid_0's binary_logloss: 0.13567	valid_0's macroF1: 0.85619
# [64]	valid_0's binary_logloss: 0.135798	valid_0's macroF1: 0.853907
# [65]	valid_0's binary_logloss: 0.135778	valid_0's macroF1: 0.85673
# [66]	valid_0's binary_logloss: 0.135858	valid_0's macroF1: 0.853907
# [67]	valid_0's binary_logloss: 0.135866	valid_0's macroF1: 0.853907
# [68]	valid_0's binary_logloss: 0.135887	valid_0's macroF1: 0.855321
# [69]	valid_0's binary_logloss: 0.135952	valid_0's macroF1: 0.853043
# [70]	valid_0's binary_logloss: 0.136028	valid_0's macroF1: 0.853043
# [71]	valid_0's binary_logloss: 0.13582	valid_0's macroF1: 0.853593
# [72]	valid_0's binary_logloss: 0.135637	valid_0's macroF1: 0.853043
# [73]	valid_0's binary_logloss: 0.135547	valid_0's macroF1: 0.853907
# [74]	valid_0's binary_logloss: 0.135515	valid_0's macroF1: 0.853907
# [75]	valid_0's binary_logloss: 0.135497	valid_0's macroF1: 0.853907
# [76]	valid_0's binary_logloss: 0.135444	valid_0's macroF1: 0.852488
# [77]	valid_0's binary_logloss: 0.135223	valid_0's macroF1: 0.853043
# [78]	valid_0's binary_logloss: 0.13541	valid_0's macroF1: 0.854456
# [79]	valid_0's binary_logloss: 0.13558	valid_0's macroF1: 0.853043
# [80]	valid_0's binary_logloss: 0.135422	valid_0's macroF1: 0.853043
# [81]	valid_0's binary_logloss: 0.135478	valid_0's macroF1: 0.851625
# [82]	valid_0's binary_logloss: 0.135459	valid_0's macroF1: 0.853043
# [83]	valid_0's binary_logloss: 0.135476	valid_0's macroF1: 0.851625
# [84]	valid_0's binary_logloss: 0.135447	valid_0's macroF1: 0.851625
# [85]	valid_0's binary_logloss: 0.135713	valid_0's macroF1: 0.852182
# [86]	valid_0's binary_logloss: 0.135899	valid_0's macroF1: 0.851323
# [87]	valid_0's binary_logloss: 0.136098	valid_0's macroF1: 0.851323
# [88]	valid_0's binary_logloss: 0.136102	valid_0's macroF1: 0.849907
# [89]	valid_0's binary_logloss: 0.135842	valid_0's macroF1: 0.849342
# [90]	valid_0's binary_logloss: 0.135863	valid_0's macroF1: 0.849342
# [91]	valid_0's binary_logloss: 0.135617	valid_0's macroF1: 0.849342
# [92]	valid_0's binary_logloss: 0.135694	valid_0's macroF1: 0.849342
# [93]	valid_0's binary_logloss: 0.135702	valid_0's macroF1: 0.847914
# [94]	valid_0's binary_logloss: 0.135627	valid_0's macroF1: 0.849342
# [95]	valid_0's binary_logloss: 0.135567	valid_0's macroF1: 0.848486
# [96]	valid_0's binary_logloss: 0.13564	valid_0's macroF1: 0.850201
# [97]	valid_0's binary_logloss: 0.135645	valid_0's macroF1: 0.850201
# [98]	valid_0's binary_logloss: 0.135473	valid_0's macroF1: 0.850201
# [99]	valid_0's binary_logloss: 0.135393	valid_0's macroF1: 0.850201
# [100]	valid_0's binary_logloss: 0.135185	valid_0's macroF1: 0.850201
# [1]	valid_0's binary_logloss: 0.292137	valid_0's macroF1: 0.474268
# [2]	valid_0's binary_logloss: 0.269654	valid_0's macroF1: 0.474268
# [3]	valid_0's binary_logloss: 0.253914	valid_0's macroF1: 0.474268
# [4]	valid_0's binary_logloss: 0.240474	valid_0's macroF1: 0.474268
# [5]	valid_0's binary_logloss: 0.229607	valid_0's macroF1: 0.681602
# [6]	valid_0's binary_logloss: 0.219052	valid_0's macroF1: 0.756874
# [7]	valid_0's binary_logloss: 0.210476	valid_0's macroF1: 0.78712
# [8]	valid_0's binary_logloss: 0.203759	valid_0's macroF1: 0.803209
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [9]	valid_0's binary_logloss: 0.197348	valid_0's macroF1: 0.813505
# [10]	valid_0's binary_logloss: 0.191841	valid_0's macroF1: 0.819329
# [11]	valid_0's binary_logloss: 0.186658	valid_0's macroF1: 0.825765
# [12]	valid_0's binary_logloss: 0.182245	valid_0's macroF1: 0.833786
# [13]	valid_0's binary_logloss: 0.178329	valid_0's macroF1: 0.834476
# [14]	valid_0's binary_logloss: 0.174701	valid_0's macroF1: 0.835837
# [15]	valid_0's binary_logloss: 0.171059	valid_0's macroF1: 0.842034
# [16]	valid_0's binary_logloss: 0.168671	valid_0's macroF1: 0.841142
# [17]	valid_0's binary_logloss: 0.166137	valid_0's macroF1: 0.843308
# [18]	valid_0's binary_logloss: 0.164266	valid_0's macroF1: 0.848449
# [19]	valid_0's binary_logloss: 0.162328	valid_0's macroF1: 0.848161
# [20]	valid_0's binary_logloss: 0.160462	valid_0's macroF1: 0.849644
# [21]	valid_0's binary_logloss: 0.158972	valid_0's macroF1: 0.852906
# [22]	valid_0's binary_logloss: 0.157162	valid_0's macroF1: 0.855279
# [23]	valid_0's binary_logloss: 0.155345	valid_0's macroF1: 0.856748
# [24]	valid_0's binary_logloss: 0.154014	valid_0's macroF1: 0.856412
# [25]	valid_0's binary_logloss: 0.153307	valid_0's macroF1: 0.858211
# [26]	valid_0's binary_logloss: 0.152426	valid_0's macroF1: 0.855518
# [27]	valid_0's binary_logloss: 0.151514	valid_0's macroF1: 0.855518
# [28]	valid_0's binary_logloss: 0.150248	valid_0's macroF1: 0.854627
# [29]	valid_0's binary_logloss: 0.149658	valid_0's macroF1: 0.854627
# [30]	valid_0's binary_logloss: 0.148634	valid_0's macroF1: 0.852855
# [31]	valid_0's binary_logloss: 0.147743	valid_0's macroF1: 0.853423
# [32]	valid_0's binary_logloss: 0.147117	valid_0's macroF1: 0.852544
# [33]	valid_0's binary_logloss: 0.146391	valid_0's macroF1: 0.855422
# [34]	valid_0's binary_logloss: 0.146115	valid_0's macroF1: 0.853986
# [35]	valid_0's binary_logloss: 0.145746	valid_0's macroF1: 0.858278
# [36]	valid_0's binary_logloss: 0.145426	valid_0's macroF1: 0.860229
# [37]	valid_0's binary_logloss: 0.144931	valid_0's macroF1: 0.858473
# [38]	valid_0's binary_logloss: 0.14454	valid_0's macroF1: 0.861278
# [39]	valid_0's binary_logloss: 0.144233	valid_0's macroF1: 0.861278
# [40]	valid_0's binary_logloss: 0.144156	valid_0's macroF1: 0.860923
# [41]	valid_0's binary_logloss: 0.14394	valid_0's macroF1: 0.860403
# [42]	valid_0's binary_logloss: 0.143692	valid_0's macroF1: 0.862673
# [43]	valid_0's binary_logloss: 0.143328	valid_0's macroF1: 0.864942
# [44]	valid_0's binary_logloss: 0.142619	valid_0's macroF1: 0.864942
# [45]	valid_0's binary_logloss: 0.14243	valid_0's macroF1: 0.864942
# [46]	valid_0's binary_logloss: 0.142522	valid_0's macroF1: 0.863038
# [47]	valid_0's binary_logloss: 0.142118	valid_0's macroF1: 0.862157
# [48]	valid_0's binary_logloss: 0.142145	valid_0's macroF1: 0.864062
# [49]	valid_0's binary_logloss: 0.141757	valid_0's macroF1: 0.864062
# [50]	valid_0's binary_logloss: 0.141941	valid_0's macroF1: 0.865826
# [51]	valid_0's binary_logloss: 0.141786	valid_0's macroF1: 0.864942
# [52]	valid_0's binary_logloss: 0.141763	valid_0's macroF1: 0.864942
# [53]	valid_0's binary_logloss: 0.141639	valid_0's macroF1: 0.865826
# [54]	valid_0's binary_logloss: 0.141357	valid_0's macroF1: 0.865826
# [55]	valid_0's binary_logloss: 0.141366	valid_0's macroF1: 0.865826
# [56]	valid_0's binary_logloss: 0.141499	valid_0's macroF1: 0.864942
# [57]	valid_0's binary_logloss: 0.141444	valid_0's macroF1: 0.864062
# [58]	valid_0's binary_logloss: 0.141249	valid_0's macroF1: 0.864062
# [59]	valid_0's binary_logloss: 0.141465	valid_0's macroF1: 0.866327
# [60]	valid_0's binary_logloss: 0.141164	valid_0's macroF1: 0.867707
# [61]	valid_0's binary_logloss: 0.141271	valid_0's macroF1: 0.867707
# [62]	valid_0's binary_logloss: 0.141042	valid_0's macroF1: 0.867707
# [63]	valid_0's binary_logloss: 0.140968	valid_0's macroF1: 0.868593
# [64]	valid_0's binary_logloss: 0.141185	valid_0's macroF1: 0.864942
# [65]	valid_0's binary_logloss: 0.141266	valid_0's macroF1: 0.865826
# [66]	valid_0's binary_logloss: 0.141287	valid_0's macroF1: 0.866327
# [67]	valid_0's binary_logloss: 0.141545	valid_0's macroF1: 0.867212
# [68]	valid_0's binary_logloss: 0.141443	valid_0's macroF1: 0.8681
# [69]	valid_0's binary_logloss: 0.141168	valid_0's macroF1: 0.869482
# [70]	valid_0's binary_logloss: 0.14137	valid_0's macroF1: 0.8681
# [71]	valid_0's binary_logloss: 0.141233	valid_0's macroF1: 0.869482
# [72]	valid_0's binary_logloss: 0.141168	valid_0's macroF1: 0.870375
# [73]	valid_0's binary_logloss: 0.141202	valid_0's macroF1: 0.870375
# [74]	valid_0's binary_logloss: 0.140924	valid_0's macroF1: 0.870375
# [75]	valid_0's binary_logloss: 0.140888	valid_0's macroF1: 0.870375
# [76]	valid_0's binary_logloss: 0.140772	valid_0's macroF1: 0.87127
# [77]	valid_0's binary_logloss: 0.14053	valid_0's macroF1: 0.870375
# [78]	valid_0's binary_logloss: 0.140632	valid_0's macroF1: 0.872169
# [79]	valid_0's binary_logloss: 0.140772	valid_0's macroF1: 0.870294
# [80]	valid_0's binary_logloss: 0.140565	valid_0's macroF1: 0.871685
# [81]	valid_0's binary_logloss: 0.14048	valid_0's macroF1: 0.870784
# [82]	valid_0's binary_logloss: 0.140519	valid_0's macroF1: 0.869394
# [83]	valid_0's binary_logloss: 0.140348	valid_0's macroF1: 0.868497
# [84]	valid_0's binary_logloss: 0.140247	valid_0's macroF1: 0.869394
# [85]	valid_0's binary_logloss: 0.140241	valid_0's macroF1: 0.868898
# [86]	valid_0's binary_logloss: 0.140092	valid_0's macroF1: 0.867103
# [87]	valid_0's binary_logloss: 0.140115	valid_0's macroF1: 0.867998
# [88]	valid_0's binary_logloss: 0.140104	valid_0's macroF1: 0.866597
# [89]	valid_0's binary_logloss: 0.140245	valid_0's macroF1: 0.867495
# [90]	valid_0's binary_logloss: 0.140126	valid_0's macroF1: 0.866988
# [91]	valid_0's binary_logloss: 0.140159	valid_0's macroF1: 0.868397
# [92]	valid_0's binary_logloss: 0.140282	valid_0's macroF1: 0.868397
# [93]	valid_0's binary_logloss: 0.140521	valid_0's macroF1: 0.868898
# [94]	valid_0's binary_logloss: 0.140843	valid_0's macroF1: 0.8698
# [95]	valid_0's binary_logloss: 0.141032	valid_0's macroF1: 0.868397
# [96]	valid_0's binary_logloss: 0.141006	valid_0's macroF1: 0.8698
# [97]	valid_0's binary_logloss: 0.141109	valid_0's macroF1: 0.867998
# [98]	valid_0's binary_logloss: 0.141166	valid_0's macroF1: 0.867998
# [99]	valid_0's binary_logloss: 0.141078	valid_0's macroF1: 0.868898
# [100]	valid_0's binary_logloss: 0.141079	valid_0's macroF1: 0.867495

# %%
predicted_y = model.predict(x_test)
train_pred_y = model.predict(x)

# %%
print(); print(metrics.classification_report(y,train_pred_y))
print(); print(metrics.confusion_matrix(y, train_pred_y))

print(); print(metrics.classification_report(y_test, predicted_y))
print(); print(metrics.confusion_matrix(y_test, predicted_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.84      0.89      1345
#            1       0.98      1.00      0.99     12395
#
#     accuracy                           0.98     13740
#    macro avg       0.97      0.92      0.94     13740
# weighted avg       0.98      0.98      0.98     13740
#
#
# [[ 1135   210]
#  [   57 12338]]
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.68      0.77       336
#            1       0.97      0.99      0.98      3099
#
#     accuracy                           0.96      3435
#    macro avg       0.92      0.84      0.87      3435
# weighted avg       0.96      0.96      0.96      3435
#
#
# [[ 229  107]
#  [  32 3067]]

# %% [markdown]
# <h2>Testing</h2>

# %%
test_path =os.path.abspath(os.path.join(os.path.dirname("__file__"), '..', '/content/drive/My Drive/datasets/test.csv'))
test_set = pd.read_csv(test_path, index_col="tripid")

# %%
test_set['pickup_time'] = pd.to_datetime(test_set['pickup_time'], format="%m/%d/%Y %H:%M")
test_set['drop_time'] = pd.to_datetime(test_set['drop_time'], format="%m/%d/%Y %H:%M")

# %%
test_set = test_set.assign(timeOfDay=pd.cut(test_set.pickup_time.dt.hour,[-1, 8, 20, 24],labels=['dawn','day', 'night']))

# %%
test_set.loc[test_set['timeOfDay'] == 'day', 'isNormalCharge'] = 1
test_set.loc[test_set['timeOfDay'] != 'day', 'isNormalCharge'] = 0

# %%
durations = []
for index,row in test_set.iterrows():
  provided_duration = row['duration'] #first row of location.lat column here
  if math.isnan(provided_duration) or provided_duration <= 0 :
    time_dif = (row['drop_time'] - row['pickup_time']).seconds
    if(time_dif == 0):
        time_dif = np.nan
    durations.append(time_dif)
  else :  
    durations.append(provided_duration)

test_set.insert(4,"time_dif",durations)

# %%
new_column = []                    #empty column for distance
for index,row in test_set.iterrows():
  lat1 = row['pick_lat'] #first row of location.lat column here
  lon1 = row['pick_lon'] #first row of location.long column here
  lat2 = row['drop_lat'] #second row of location.lat column here
  lon2 = row['drop_lon'] #second row of location.long column here
  value = dist_from_coordinates(lat1, lon1, lat2, lon2)  #get the distance
  new_column.append(value)   #append the empty list with distance values

test_set.insert(4,"distance",new_column)

# %%
test_set['time_driven'] = test_set['duration']  - test_set['meter_waiting']

# %%
chargeperhours = []
for index,row in test_set.iterrows():
    if(row['meter_waiting'] == 0):
        chargeperhour = np.nan
    else:
        chargeperhour = (row['meter_waiting_fare'] / row['meter_waiting'] * 3600)
    chargeperhours.append(chargeperhour)

test_set.insert(4,'charge_per_hour',chargeperhours)

# %%
test_set['driving_fare'] = test_set['fare']  - test_set['meter_waiting_fare'] - test_set['additional_fare']

# %%
avgspeeds = []
for index,row in test_set.iterrows():
    if(row['time_driven'] == 0):
        avgspeed = np.nan    
    else:
        avgspeed = (row['distance'] / row['time_driven'] * 3600)
    avgspeeds.append(avgspeed)

test_set.insert(4,"avg_speed",avgspeeds)

# %%
costsperkm = []
for index,row in test_set.iterrows():
    if row['distance'] == 0:
        costperkm = np.nan
            
    else:
        costperkm = (row['driving_fare'] / row['distance'])
    costsperkm.append(costperkm)

test_set.insert(4,"cost_per_km",costsperkm)

# %%
test_set['pickup_cluster_label'] = db_pick.labels_[17176*2:17176*2 + 8576 ]
test_set['drop_cluster_label'] = db_pick.labels_[17176*2 + 8576: 2*(17176+8576) ]

# %%
test_features = test_set[training_columns]

# %%
test_features.isna().sum()
# Out:
# meter_waiting             0
# meter_waiting_fare        0
# fare                      0
# additional_fare           0
# distance                  0
# cost_per_km              25
# avg_speed                 9
# time_dif                  0
# time_driven               0
# charge_per_hour         298
# driving_fare              0
# isNormalCharge            0
# pick_lat                  0
# pick_lon                  0
# drop_lat                  0
# drop_lon                  0
# drop_cluster_label        0
# pickup_cluster_label      0
# dtype: int64

# %%
predicted_labels = model.predict(test_features)

# %%
predicted_labels_df = pd.DataFrame(predicted_labels )

# %%
sub_path =os.path.abspath(os.path.join(os.path.dirname("__file__"), '..', '/content/drive/My Drive/datasets/sample_submission.csv'))
submission_set = pd.read_csv(sub_path)

# %%
submission_set['prediction']= predicted_labels_df.values[:,0]

# %%
theNotebook = "dbscan"

# %%
filename = '/content/drive/My Drive/datasets/'+theNotebook+'/'+theNotebook+'_{%i}.csv'
dirname = '/content/drive/My Drive/datasets/'+theNotebook
fileversion = 1

if not os.path.exists(dirname):
    os.makedirs(dirname)
while glob.glob(filename.replace('{%i}',str(fileversion))) :
    fileversion+=1
submission_set.to_csv(filename.replace('{%i}',str(fileversion)), index=False)
print("Completed!")
# Out:
# Completed!

# %%
submission_set['prediction'].value_counts()
# Out:
# 1    8121
# 0     455
# Name: prediction, dtype: int64
