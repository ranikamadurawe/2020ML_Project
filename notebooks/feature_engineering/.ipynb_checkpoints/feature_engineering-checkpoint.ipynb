# %% [markdown]
# <h1>Imports</h1>

# %%
from pathlib import Path
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats


import seaborn as sns
from IPython.display import display

# %%
pd.set_option("display.max_columns", 100)
# %matplotlib inline

# %% [markdown]
# <h1>Dataset Importing</h1>

# %%
DATA_PATH = Path.cwd() / "../../datasets"

# %%
training_df = pd.read_csv(DATA_PATH / "train.csv", index_col="tripid")
training_df.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0              0.0000
# 189125358             10.5     791.0           47.0              0.0000
# 189125719             10.5    1087.0           80.0              0.0000
# 189127273             10.5     598.0          271.0             15.6638
# 189128020              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup     pickup_time       drop_time  \
# tripid
# 189123628                       64.0  11/1/2019 0:20  11/1/2019 0:34
# 189125358                      134.0  11/1/2019 0:56  11/1/2019 1:09
# 189125719                       61.0  11/1/2019 1:08  11/1/2019 1:26
# 189127273                       68.0  11/1/2019 2:27  11/1/2019 2:37
# 189128020                        NaN  11/1/2019 3:34  11/1/2019 3:51
#
#            pick_lat  pick_lon  drop_lat  drop_lon    fare    label
# tripid
# 189123628   6.86252   79.8993   6.90330   79.8783  270.32  correct
# 189125358   6.88589   79.8984   6.91373   79.8923  197.85  correct
# 189125719   6.90839   79.8651   6.93669   79.9146  301.64  correct
# 189127273   6.92570   79.8895   6.92748   79.8971   82.30  correct
# 189128020   6.87441   79.8615   6.84478   79.9290  358.39  correct

# %%
training_df.columns
# Out:
# Index(['additional_fare', 'duration', 'meter_waiting', 'meter_waiting_fare',
#        'meter_waiting_till_pickup', 'pickup_time', 'drop_time', 'pick_lat',
#        'pick_lon', 'drop_lat', 'drop_lon', 'fare', 'label'],
#       dtype='object')

# %% [markdown]
# <h1>Data Preprocessing</h1>

# %%
training_df['pickup_time'] = pd.to_datetime(training_df['pickup_time'], format="%m/%d/%Y %H:%M")
training_df['drop_time'] = pd.to_datetime(training_df['drop_time'], format="%m/%d/%Y %H:%M")

# %%
training_df['label_marker']=(training_df['label']=='correct').astype(int)

# %% [markdown]
# <h1>Initial Data Analyisis</h1>

# %% [markdown]
# <h3>Weka analysis of outliers</h3>

# %%
weka_outliers = pd.read_csv(DATA_PATH / "train_outlier.csv", index_col="tripid")

# %%
print(weka_outliers[ (weka_outliers['Outlier'] == 'yes') & (weka_outliers['label']=='correct' ) ].index.tolist())
# Out:
# [189146174, 189176766, 189182800, 189227008, 189236485, 189259043, 189277797, 189284005, 189307311, 189323004, 189345964, 189363308, 189370252, 189372731, 189391717, 189394373, 189420181, 189428397, 189431382, 189445521, 189465650, 189475280, 189551186, 189572039, 189615129, 189623692, 189627696, 189640410, 189655834, 189667686, 189698072, 189738377, 189737409, 189748039, 189747601, 189752791, 189778822, 189801272, 189820422, 189820090, 189821179, 189824507, 189826263, 189829043, 189835514, 189841958, 189842329, 189877959, 189882220, 189884798, 189894385, 189925207, 189980243, 189978643, 189995541, 190007029, 190008226, 190009896, 190010618, 190023371, 190025934, 190042045, 190050433, 190050729, 190056653, 190059653, 190065135, 190070075, 190080854, 190108454, 190166142, 190173251, 190176497, 190184600, 190189374, 190207045, 190212978, 190218103, 190
for i in ['additional_fare', 'duration', 'meter_waiting', 'meter_waiting_fare', 'meter_waiting_till_pickup', 'fare'] :
    plt.figure(figsize=(20,5))
    sns.boxplot(x = i, y = 'label', data = training_df) 
    plt.show()

# %% [markdown]
# <b>Two feature comparisions</b>

# %%
figure, axes = plt.subplots(1, 2, figsize=(15,10))
index = 0
colors = ["#4CB391", "#FF0000"]
for i in ['correct', 'incorrect'] :
    sns.regplot('duration', 'fare', training_df[training_df['label']==i], fit_reg=False, ax=axes[index], color=colors[index])
    axes[index].set_title(i)
    index = index + 1
plt.show()

# %%
figure, axes = plt.subplots(1, 2, figsize=(15,10))
index = 0
colors = ["#4CB391", "#FF0000"]
for i in ['correct', 'incorrect'] :
    sns.regplot('meter_waiting', 'meter_waiting_fare', training_df[training_df['label']==i], fit_reg=False, ax=axes[index], color=colors[index])
    axes[index].set_title(i)
    index = index + 1
plt.show()

# %% [markdown]
# <h2>Identification of Anomalies within the Correct dataset</h2>
# <b>Consider only correct as Anomalies within the correct data maybe called 'incorrect' due to the anomaly<b>

# %%
training_df.isna().sum()
# Out:
# additional_fare              202
# duration                     202
# meter_waiting                202
# meter_waiting_fare           202
# meter_waiting_till_pickup    202
# pickup_time                    0
# drop_time                      0
# pick_lat                       0
# pick_lon                       0
# drop_lat                       0
# drop_lon                       0
# fare                         137
# label                          0
# label_marker                   0
# dtype: int64

# %%
correct_training_df = training_df[training_df['label']=='correct']

# %% [markdown]
# <h3>Null and Zero variable Analysis</h3>

# %%
correct_training_df.isna().sum()
# Out:
# additional_fare              53
# duration                     53
# meter_waiting                53
# meter_waiting_fare           53
# meter_waiting_till_pickup    53
# pickup_time                   0
# drop_time                     0
# pick_lat                      0
# pick_lon                      0
# drop_lat                      0
# drop_lon                      0
# fare                          0
# label                         0
# label_marker                  0
# dtype: int64

# %% [markdown]
# <b>All Rows with unspecified fare are incorrect<b>

# %%
corrNaNRows = correct_training_df[correct_training_df.isnull().any(axis=1)]

# %% [markdown]
# <b>All NaN entries are on the same row and are not dispersed<b>

# %%
zero_count = {}
negative_count = {}
for i in ['additional_fare', 'duration', 'meter_waiting', 'meter_waiting_fare',
       'meter_waiting_till_pickup', 'fare'] :
    zero_count[i] = 0
    negative_count[i] = 0
    for index,row in correct_training_df.iterrows():
        if row[i] < 0:
            negative_count[i]+=1
        if row[i] == 0:
            zero_count[i]+=1

# %%
print(zero_count)
print(negative_count)
# Out:
# {'additional_fare': 1, 'duration': 0, 'meter_waiting': 636, 'meter_waiting_fare': 7568, 'meter_waiting_till_pickup': 1319, 'fare': 1}
# {'additional_fare': 0, 'duration': 0, 'meter_waiting': 0, 'meter_waiting_fare': 0, 'meter_waiting_till_pickup': 0, 'fare': 0}

# %% [markdown]
# <b>No negative counts<b>

# %%
correct_training_df[correct_training_df['fare']==0]
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 191841099              0.0    2446.0          840.0                 0.0
#
#            meter_waiting_till_pickup         pickup_time           drop_time  \
# tripid
# 191841099                      231.0 2019-11-14 08:25:00 2019-11-14 09:06:00
#
#            pick_lat  pick_lon  drop_lat  drop_lon  fare    label  label_marker
# tripid
# 191841099   6.85527   79.8882   6.87782   79.8773   0.0  correct             1

# %% [markdown]
# <b>All rows with fare = 0 [except 191841099] are marked incorrect <b> <br/>
# <b>All rows with fare = 0 also have 0 additional fare and meter waiting fare<b> <br/>
# <b>Row could be an anomaly<b>

# %% [markdown]
# <h1>Initial Data Cleaning</h1>

# %% [markdown]
# <h1>Feature Engineering</h1>

# %%
# Bin times into 3 ranges to simplify time ascpect
training_df = training_df.assign(timeOfDay=pd.cut(training_df.pickup_time.dt.hour,[-1, 8, 20, 24],labels=['dawn','day', 'night']))

training_df['isDawn']=(training_df['timeOfDay']=='dawn').astype(int)
training_df['isNight']=(training_df['timeOfDay']=='night').astype(int)
training_df['isDay']=(training_df['timeOfDay']=='day').astype(int)

# %%
durations = []
for index,row in training_df.iterrows():
    provided_duration = row['duration'] 
    if math.isnan(provided_duration) or provided_duration <= 0 :
        time_dif = (row['drop_time'] - row['pickup_time']).seconds
        if time_dif == 0:
            time_dif = np.nan
        durations.append(time_dif)
    else :  
        durations.append(provided_duration)

training_df.insert(10,"time_dif",durations)

# %%
def dist_from_coordinates(lat1, lon1, lat2, lon2):
    R = 6371  
    d_lat = np.radians(lat2-lat1)
    d_lon = np.radians(lon2-lon1)

    r_lat1 = np.radians(lat1)
    r_lat2 = np.radians(lat2)
    a = np.sin(d_lat/2.) **2 + np.cos(r_lat1) * np.cos(r_lat2) * np.sin(d_lon/2.)**2

    haversine = 2 * R * np.arcsin(np.sqrt(a))

    return haversine

# %%
distances = []                    #empty column for distance
for index,row in training_df.iterrows():
    lat1 = row['pick_lat'] 
    lon1 = row['pick_lon'] 
    lat2 = row['drop_lat'] 
    lon2 = row['drop_lon'] 
    value = dist_from_coordinates(lat1, lon1, lat2, lon2)  
    distances.append(value)   

training_df.insert(10,"distance",distances)

# %%
training_df['time_driven'] = training_df['duration']  - training_df['meter_waiting']

# %%
training_df['driving_fare'] = training_df['fare']  - training_df['meter_waiting_fare'] - training_df['additional_fare']

# %%
costsperkm = []
for index,row in training_df.iterrows():
    if row['distance'] == 0:
        costperkm = np.nan
            
    else:
        costperkm = (row['driving_fare'] / row['distance'])
    costsperkm.append(costperkm)

training_df.insert(4,"cost_per_km",costsperkm)

# %%
avgspeeds = []
for index,row in training_df.iterrows():
    if(row['time_driven'] == 0):
        avgspeed = np.nan
    else:
        avgspeed = (row['distance'] / row['time_driven'] * 3600)
    avgspeeds.append(avgspeed)

training_df.insert(4,"avg_speed",avgspeeds)

# %%
chargeperhours = []
for index,row in training_df.iterrows():
    if(row['meter_waiting'] == 0):
        chargeperhour = np.nan
    else:
        chargeperhour = (row['meter_waiting_fare'] / row['meter_waiting'] * 3600)
    chargeperhours.append(chargeperhour)

training_df.insert(4,'charge_per_hour',chargeperhours)

# %%
training_df.loc[training_df['timeOfDay'] == 'day', 'isNormalCharge'] = 1
training_df.loc[training_df['timeOfDay'] != 'day', 'isNormalCharge'] = 0

# %% [markdown]
# <h1>Post feature engineering Analysis</h1>

# %%
training_df.columns[training_df.dtypes == "float64"].values
# Out:
# array(['additional_fare', 'duration', 'meter_waiting',
#        'meter_waiting_fare', 'charge_per_hour', 'avg_speed',
#        'cost_per_km', 'meter_waiting_till_pickup', 'pick_lat', 'pick_lon',
#        'drop_lat', 'distance', 'time_dif', 'drop_lon', 'fare',
#        'time_driven', 'driving_fare', 'isNormalCharge'], dtype=object)

# %%
numerical_features = [ 'duration', 'meter_waiting',
       'meter_waiting_fare', 'charge_per_hour', 'avg_speed',
       'cost_per_km', 'meter_waiting_till_pickup', 'distance', 'time_dif', 'fare',
       'time_driven', 'driving_fare']
numerical_features_with_label = ['duration', 'meter_waiting',
       'meter_waiting_fare', 'charge_per_hour', 'avg_speed',
       'cost_per_km', 'meter_waiting_till_pickup', 'distance', 'time_dif', 'fare',
       'time_driven', 'driving_fare','label']

# %%
training_features = training_df[numerical_features]

# %%
training_features_with_labels = training_df[numerical_features_with_label]

# %% [markdown]
# <h2>Z score for numerical columns</h2>

# %%
training_features = training_features.dropna()

# %%
training_features.index
# Out:
# Int64Index([189123628, 189125358, 189125719, 189127273, 189129552, 189132829,
#             189135103, 189139296, 189138671, 189135814,
#             ...
#             213795752, 213799350, 213800748, 213802197, 213802222, 213803193,
#             213812756, 213813930, 213815405, 213817296],
#            dtype='int64', name='tripid', length=16192)

# %%
inliers = training_features[(np.abs(stats.zscore(training_features)) < 3).all(axis=1)]

# %%
inliers.index
# Out:
# Int64Index([189123628, 189125358, 189125719, 189127273, 189129552, 189132829,
#             189135103, 189139296, 189138671, 189140969,
#             ...
#             213795752, 213799350, 213800748, 213802197, 213802222, 213803193,
#             213812756, 213813930, 213815405, 213817296],
#            dtype='int64', name='tripid', length=15673)

# %%
diff_index = training_features.index.difference(inliers.index)

# %%
print(diff_index.tolist())
# Out:
# [189135814, 189191865, 189213407, 189252401, 189258007, 189326852, 189372731, 189397242, 189418240, 189626199, 189639329, 189663502, 189734544, 189737409, 189749297, 189765236, 189800308, 189801272, 189919496, 189925207, 189989861, 190042045, 190044131, 190050729, 190167541, 190214819, 190233219, 190289312, 190292867, 190294183, 190315565, 190317323, 190367842, 190368394, 190373958, 190387837, 190390160, 190392777, 190406620, 190408980, 190426786, 190618151, 190868224, 190892867, 190906258, 190932899, 190947488, 190988783, 190996095, 191023223, 191024761, 191090473, 191093204, 191098402, 191125782, 191138239, 191198064, 191245326, 191328606, 191371136, 191408788, 191409182, 191425016, 191435886, 191475356, 191548899, 191583906, 191624916, 191664140, 191861723, 191999785, 192045536, 192079256, 192080347, 192121471, 192151023, 192151525, 192194022, 192194086, 192255373, 192471577, 192666104, 192699918, 192749835, 192930989, 192943896, 193038905, 193047517, 193089601, 193093689, 193164831, 193261350, 193317324, 193341290, 193357510, 193358705, 193415117, 193464877, 193481764, 193484505, 193528284, 193585269, 193607278, 193608496, 193649132, 193653296, 193653784, 193677619, 193682008, 193749854, 193753968, 193760421, 193777686, 193781025, 193796406, 193827380, 193837260, 193841338, 193874389, 193886201, 193898575, 193922204, 194122338, 194218927, 194253929, 194256573, 194274360, 194287357, 194287387, 194348937, 194361105, 194418073, 194464805, 194497705, 194506651, 194541864, 194549922, 194551382, 194554416, 194556014, 194640103, 194653084, 194708987, 194714168, 194742273, 194744996, 194987046, 195072266, 195083607, 195101510, 195114874, 195260495, 195269699, 195270255, 195273761, 195283686, 195284371, 195299293, 195309305, 195315462, 195317789, 195346858, 195348822, 195361340, 195385934, 195410990, 195411360, 195463949, 195505361, 195519176, 195564856, 195591012, 195593822, 195673139, 195770562, 195793708, 195882991, 195909616, 195927249, 196031368, 196472675, 196516473, 196567702, 196569476, 196575400, 196587403, 196590684, 196605553, 196608739, 196661640, 196856208, 196942121, 196943952, 196948918, 197003034, 197013051, 197019871, 197050724, 197075221, 197087667, 197153402, 197163368, 197214083, 197242047, 197298696, 197302262, 197307820, 197336591, 197368969, 197379944, 197386704, 197457871, 197465347, 197537284, 197600970, 197626954, 197984654, 197999001, 198004755, 198015626, 198076803, 198092335, 198180213, 198205664, 198223689, 198295772, 198333166, 198395566, 198429392, 198479701, 198602509, 198607847, 198626163, 198655101, 198668237, 198685804, 198704554, 198711403, 198733864, 198793721, 198860975, 198910537, 198916276, 198940643, 199025591, 199037961, 199065158, 199133715, 199211192, 199264868, 199309613, 199593615, 199689558, 199999511, 200108506, 200111110, 200119068, 200154190, 200165531, 200260060, 200422666, 200490024, 200577470, 200589221, 200608272, 200633216, 200700918, 200708149, 200764108, 200829063, 200888583, 200943864, 201036658, 201108278, 201141871, 201159410, 201167648, 201172575, 201206769, 201211325, 201493577, 201496100, 201602965, 201622567, 201640986, 201643832, 201654842, 201668590, 201699206, 201727138, 201777203, 201794142, 201900543, 201952821, 201982478, 202019238, 202115222, 202148988, 202154929, 202251004, 202642997, 202702798, 202727581, 202758689, 202771293, 202830074, 202847546, 202871200, 202902141, 202998968, 203057893, 203106388, 203198420, 203358177, 203475249, 203548470, 203578592, 203623210, 203634943, 203695038, 203736388, 203786014, 203837743, 203947769, 204081147, 204190852, 204197239, 204204952, 204268616, 204319494, 204353372, 204368169, 204385620, 204407357, 204412731, 204486093, 204499542, 204513019, 204526224, 204529573, 204570020, 204571385, 204574122, 204655606, 204745747, 204765082, 204811315, 204857540, 204881840, 204905077, 204923587, 204932258, 204944899, 204953225, 205061023, 205200937, 205247279, 205249625, 205328050, 205422364, 205677503, 206336240, 206345862, 206347 ...

# %% [markdown]
# <h2>IQR Anaylsis</h2>

# %% [markdown]
# <b>General Anaylsis of entire dataset</b>

# %%
train_features = training_df[numerical_features]

# %%
Q1 = train_features.quantile(0.25)
Q3 = train_features.quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# duration                     1255.000000
# meter_waiting                 318.000000
# meter_waiting_fare             14.341800
# charge_per_hour               208.484825
# avg_speed                       8.232176
# cost_per_km                    29.728748
# meter_waiting_till_pickup     118.000000
# distance                        4.674884
# time_dif                     1260.000000
# fare                          240.950000
# time_driven                   955.750000
# driving_fare                  224.043750
# dtype: float64

# %%
print ( (train_features < (Q1 - 3 * IQR)) | (train_features > (Q3 + 3 * IQR)) )
# Out:
#            duration  meter_waiting  meter_waiting_fare  charge_per_hour  \
# tripid
# 189123628     False          False               False            False
# 189125358     False          False               False            False
# 189125719     False          False               False            False
# 189127273     False          False               False            False
# 189128020     False          False               False            False
# 213787716      False        False                      False     False
# 213789771      False        False                      False     False
# 213795752      False         True                      False     False
# 213799350      False        False                      False     False
# 213800748      False        False                      False     False
# 213802197      False         True                      False     False
# 213802222      False        False                      False     False
# 213803193      False        False                      False     False
# 213812756      False        False                      False     False
# 213813930      False        False                      False     False
# 213815405      False        False                      False     False
# 213817296      False        False                      False     False
#
#            time_dif   fare  time_driven  driving_fare
# tripid
# 189123628     False  False        False         False
# 189125358     False  False        False         False
# 189125719     False  False        False         False
# 189127273     False  False        False         False
# 189128020     False  False        False         False
# 189129552     False  False        False          True
# 189132829     False  False        False         False
# 189135103     False  False        False         False
# 189139296     False  False        False         False
# 189138671     False  False        False         False
# 189135814     False  False        False         False
# 189140969     False  False        False         False
# 189144528     False  False        False         False
# 189147041     False  False        False         False
# 189145904     False  False        False         False
# 189146174     False  False        False         False
# 189150541     False  False        False         False
# 189153229     False  False        False         False
# 189151585     False  False        False         False
# 189157464     False  False        False         False
# 189157607     False  False        False         False
# 189157476     False  False        False         False
# 189157559     False  False        False         False
# 189159951     False  False        False         False
# 189158726     False  False        False         False
# 189160756     False  False        False         False
# 189161377     False  False        False         False
# 189163162     False  False        False         False
# 189164454     False  False        False         False
# 189164880     False  False        False         False
# ...             ...    ...          ...           ...
# 213747503     False  False        False         False
# 213751620     False  False        False         False
# 213749432     False  False        False         False
# 213754172     False  False        False         False
# 213758346     False  False        False         False
# 213759061     False  False        False         False
# 213761623     False  False        False         False
# 213776255     False  False        False         False
# 213774316     False  False        False         False
# 213774593     False  False        False         False
# 213775846     False  False        False         False
# 213774642     False  False        False         False
# 213774742     False  False        False         False
# 213779882     False  False        False         False
# 213782178     False  False        False         False
# 213782382     False  False        False         False
# 213784559     False  False        False         False
# 213784596     False  False        False         False
# 213787716     False  False        False         False
# 213789771     False  False        False         False
# 213795752     False  False        False         False
# 213799350     False  False        False         False
# 213800748     False  False        False         False
# 213802197     False  False        False         False
# 213802222     False  False        False         False
# 213803193     False  False        False         False
# 213812756     False  False        False         False
# 213813930     False  False        False         False
# 213815405     False  False        False         False
# 213817296     False  False        False         False
#
# [17176 rows x 12 columns]

# %%
training_df_out =  train_features[ ~((train_features < (Q1 - 3 * IQR)) | (train_features > (Q3 + 3 * IQR))).any(axis=1) ]

# %%
training_df_out.shape
# Out:
# (13777, 12)

# %% [markdown]
# <b>Outlier from analyzing inccorrect cases</b>

# %%
incorrect_training_df = training_features_with_labels[training_features_with_labels['label']=='incorrect']

# %%
Q1_incorr = incorrect_training_df[numerical_features].quantile(0.25)
Q3_incorr = incorrect_training_df[numerical_features].quantile(0.75)
IQR_incorr = Q3_incorr-Q1_incorr
print(IQR_incorr)
# Out:
# duration                     2044.750000
# meter_waiting                 556.500000
# meter_waiting_fare             17.466575
# charge_per_hour               208.080000
# avg_speed                      15.973111
# cost_per_km                   227.277144
# meter_waiting_till_pickup     141.000000
# distance                        5.776317
# time_dif                     2047.000000
# fare                          516.695000
# time_driven                  1388.250000
# driving_fare                  481.869600
# dtype: float64

# %%
incorrect_train_features = incorrect_training_df[numerical_features]

# %%
print ( (incorrect_train_features < (Q1_incorr - 3 * IQR_incorr)) | (incorrect_train_features > (Q3_incorr + 3 * IQR_incorr)) )
# Out:
#            duration  meter_waiting  meter_waiting_fare  charge_per_hour  \
# tripid
# 189135814     False          False               False            False
# 189140969     False          False               False            False
# 189147041     False          False               False            False
# 189157607     False          False                True            False
# 189160756     False          False               False            False
# 189161377     False          False               False            False
# 189164806     False           True                True            False
# 189164831     False          False               False            False
# 189164791     False          False               False            False
# 189174640     False          False               False            False
# 189177562     False          False               False            False
# 189191865     False          False               False            False
# 189197440     False          False               False            False
# 189228747      True          False               False            False
# 189231599     False          False               False            False
# 189230749     False          False               False            False
# 189246252     False          False               False            False
# 189246189     False           True                True            False
# 189252401     False          False               False            False
# 189260564     False          False               False            False
# 189255640     False          False               False            False
# 189301104     False          False               False            False
# 189312263     False          False               False            False
# 189328885     False          False               False            False
# 189331202     False          False               False            False
# 189387360     False          False               False            False
# 189388837     False          False               False            False
# 189393356     False          False               False            False
# 189397242     False          False               False            False
# 189411072     False          False               False            False
# ...             ...            ...                 ...              ...
# 213291965     False          False               False            False
# 213310021     False          False               False            False
# 213310572     False          False               False            False
# 213330421     False          False               False            False
# 213336417     False          False               False            False
# 213338995     False          False               False            False
# 213373523     False          False               False            False
# 213394162     False          False               False            False
# 213412693     False          False               False            False
# 213416659     False           True                True            False
# 213439115     False          False               False            False
# 213443178     False          False               False            False
# 213449192     False          False               False            False
# 213456768     False          False               False            False
# 213510465     False          False               False            False
# 213522555     False          False               False            False
# 213537462     False          False               False            False
# 213538831     False          False               False            False
# 213567037     False          False               False            False
# 213575286     False          False               False            False
# 213593706     False          False               False            False
# 213615015     False          False               False            False
# 213620129     False          False               False            False
# 213639520     False           True                True            False
# 213658727     False          False               False            False
# 213674502     False          False               False            False
# 213689462     False          False                True            False
# 213703973     False          False               False            False
# 213758346     False          False               False            False
# 213795752     False          False                True            False
#
#            avg_speed  cost_per_km  meter_waiting_till_pickup  distance  \
# tripid
# 189135814       True        False                      False     False
# 189140969       True        False                      False     False
# 189147041      False        False                      False     False
# 189157607      False        False                      False     False
# 189160756      False        False                      False     False
# 189161377       True        False                      False     False
# 189164806      False        False                      False     False
# 189164831      False        False                      False     False
# 189164791      False        False                      False     False
# 189174640      False        False                      False     False
# 189177562      False         True                      False     False
# 189191865      False         True                      False     False
# 189197440      False        False                      False     False
# 189228747      False        False                      False     False
# 189231599      False        False                      False     False
# 189230749      False        False                      False     False
# 189246252      False        False                      False     False
# 189246189      False         True                      False     False
# 189252401      False        False                      False     False
# 189260564      False        False                      False     False
# 189255640       True        False                      False     False
# 189301104      False        False                      False     False
# 189312263      False        False                      False     False
# 189328885      False        False                      False     False
# 189331202      False         True                      False     False
# 189387360       True        False                      False     False
# 189388837      False        False                      False     False
# 189393356      False        False                      False     False
# 189397242       True        False                      False     False
# 189411072      False        False                      False     False
# ...              ...          ...                        ...       ...
# 213291965      False        False                      False     False
# 213310021      False         True                      False     False
# 213310572      False        False                      False     False
# 213330421      False        False                      False     False
# 213336417      False        False                      False     False
# 213338995      False        False                      False     False
# 213373523      False         True                      False     False
# 213394162      False        False                      False     False
# 213412693      False        False                      False     False
# 213416659       True        False                       True     False
# 213439115      False        False                      False     False
# 213443178       True        False                      False     False
# 213449192      False        False                      False     False
# 213456768       True        False                      False     False
# 213510465      False        False                      False     False
# 213522555       True        False                      False     False
# 213537462      False        False                      False     False
# 213538831      False        False                      False     False
# 213567037      False        False                      False     False
# 213575286      False         True                      False     False
# 213593706       True        False                      False     False
# 213615015       True        False                      False     False
# 213620129       True        False                      False     False
# 213639520      False         True                      False     False
# 213658727      False        False                      False     False
# 213674502      False        False                      False     False
# 213689462      False        False                      False     False
# 213703973      False        False                      False     False
# 213758346      False        False                      False     False
# 213795752      False         True                      False     False
#
#            time_dif   fare  time_driven  driving_fare
# tripid
# 189135814     False  False        False         False
# 189140969     False  False        False         False
# 189147041     False  False        False         False
# 189157607     False  False        False         False
# 189160756     False  False        False         False
# 189161377     False  False        False         False
# 189164806     False  False        False         False
# 189164831     False  False        False         False
# 189164791     False  False        False         False
# 189174640     False  False        False         False
# 189177562     False  False        False         False
# 189191865     False  False        False         False
# 189197440     False  False        False         False
# 189228747      True  False         True         False
# 189231599     False  False        False         False
# 189230749     False  False        False         False
# 189246252     False  False        False         False
# 189246189     False  False        False         False
# 189252401     False  False        False         False
# 189260564     False  False        False         False
# 189255640     False  False        False         False
# 189301104     False  False        False         False
# 189312263     False  False        False         False
# 189328885     False  False        False         False
# 189331202     False  False        False         False
# 189387360     False  False        False         False
# 189388837     False  False        False         False
# 189393356     False  False        False         False
# 189397242     False  False        False         False
# 189411072     False  False        False         False
# ...             ...    ...          ...           ...
# 213291965     False  False        False         False
# 213310021     False  False        False         False
# 213310572     False  False        False         False
# 213330421     False  False        False         False
# 213336417     False  False        False         False
# 213338995     False  False        False         False
# 213373523     False  False        False         False
# 213394162      True  False        False         False
# 213412693     False  False        False         False
# 213416659     False  False        False         False
# 213439115     False  False        False         False
# 213443178     False  False        False         False
# 213449192     False  False        False         False
# 213456768     False  False        False         False
# 213510465     False  False        False         False
# 213522555     False  False        False         False
# 213537462     False  False        False         False
# 213538831     False  False        False         False
# 213567037     False  False        False         False
# 213575286     False  False        False         False
# 213593706     False  False        False         False
# 213615015     False  False        False         False
# 213620129     False  False        False         False
# 213639520     False  False        False         False
# 213658727     False  False        False         False
# 213674502     False  False        False         False
# 213689462     False  False        False         False
# 213703973     False  False        False         False
# 213758346     False  False        False         False
# 213795752     False  False        False         False
#
# [1681 rows x 12 columns]

# %%
incorrect_training_df_out =  incorrect_train_features[ ~((incorrect_train_features < (Q1_incorr - 3 * IQR_incorr)) | (incorrect_train_features > (Q3_incorr + 3 * IQR_incorr))).any(axis=1) ]

# %%
incorrect_training_df_out.shape
# Out:
# (1090, 12)

# %% [markdown]
# <b>Outlier from analyzing correct cases</b>

# %%
correct_training_df = training_features_with_labels[training_features_with_labels['label']=='correct']

# %%
Q1_corr = correct_training_df[numerical_features].quantile(0.25)
Q3_corr = correct_training_df[numerical_features].quantile(0.75)
IQR_corr = Q3_corr-Q1_corr
print(IQR_corr)
# Out:
# duration                     1201.000000
# meter_waiting                 306.750000
190947363, 190953898, 190966252, 190977696, 190985222, 190987637, 190988783, 190996095, 191007967, 191013223, 191022913, 191056435, 191089000, 191090473, 191093204, 191112330, 191113633, 191115688, 191130876, 191133495, 191138239, 191138688, 191139639, 191141096, 191149455, 191160198, 191160979, 191165416, 191170016, 191174586, 191175923, 191179020, 191187220, 191193257, 191195814, 191199643, 191200500, 191208890, 191210446, 191249649, 191253045, 191258602, 191263388, 191265767, 191266110, 191266344, 191269975, 191270817, 191271898, 191273013, 191276742, 191277252, 191281170, 191283295, 191284758, 191297030, 191298595, 191311111, 191314169, 191315804, 191321284, 191328977, 191335143, 191341552, 191346875, 191348943, 191350911, 191362196, 191365695, 191371136, 191377695, 191378896, 191379325, 191399170, 191400463, 191408788, 191409182, 191409793, 191411060, 191418029, 191419538, 191422299, 191422442, 191423853, 191424909, 191425016, 191429711, 191432473, 191432806, 191438232, 191443119, 191449647, 191457572, 191457855, 191458504, 191464200, 191475356, 191476806, 191501481, 191506681, 191512546, 191517544, 191520179, 191524024, 191538456, 191542329, 191542764, 191546586, 191554775, 191561108, 191563247, 191567745, 191576199, 191581550, 191583906, 191589327, 191626914, 191627 ...

# %%
correct_training_df_out.shape
# Out:
# (12885, 12)

# %% [markdown]
# <h2>Graph anaylsis</h2>

# %%
figure, axes = plt.subplots(1, 2, figsize=(15,10))
index = 0
colors = ["#4CB391", "#FF0000"]
for i in ['correct', 'incorrect'] :
    sns.regplot('time_driven', 'driving_fare', training_df[training_df['label']==i], fit_reg=False, ax=axes[index], color=colors[index])
    axes[index].set_title(i)
    index = index + 1
plt.show()

# %%
training_df.corr()

# %%
zero_count = {}
negative_count = {}
for i in ['avg_speed','driving_fare','time_driven','distance'] :
    zero_count[i] = 0
    negative_count[i] = 0
    for index,row in training_df.iterrows():
        if row[i] < 0:
            negative_count[i]+=1
        if row[i] == 0:
            zero_count[i]+=1

# %%
print(zero_count)
print(negative_count)

# %% [markdown]
# <h3>Viewing features of the Incorrect Dataset</h3>

# %%
incorrect_training_df = training_df[training_df['label']=='incorrect']

# %%
incorrect_training_df[incorrect_training_df['meter_waiting'] < 3600].plot(kind='scatter',x='meter_waiting',y='charge_per_hour',color='red')

# %% [markdown]
# <h2>Identification of Anomalies within the Correct dataset</h2>
# <b>Consider only correct as Anomalies within the correct data maybe called 'incorrect' due to the anomaly<b>

# %%
correct_training_df = training_df[training_df['label']=='correct']

# %%
correct_training_df.nlargest(10, ['cost_per_km'])

# %%
correct_training_df.plot(kind='scatter',y='cost_per_km',x='distance')

# %%
zero_count = {}
negative_count = {}
for i in ['avg_speed','driving_fare','time_driven','distance', 'charge_per_hour'] :
    zero_count[i] = 0
    negative_count[i] = 0
    for index,row in correct_training_df.iterrows():
        if row[i] < 0:
            negative_count[i]+=1
        if row[i] == 0:
            zero_count[i]+=1

# %%
print(zero_count)
print(negative_count)

# %%
correct_training_df[correct_training_df['avg_speed'] < 0]

# %% [markdown]
# <b>row 207947602 is anomolous as the driving time is negative<b>

# %%
correct_training_df[correct_training_df['time_driven'] == 0]

# %%
correct_training_df[correct_training_df['time_driven'] < 60]
