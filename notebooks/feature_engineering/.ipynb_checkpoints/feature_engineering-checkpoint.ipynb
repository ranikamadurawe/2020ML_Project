# %% [markdown]
# <h1>Imports</h1>

# %%
from pathlib import Path
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
5

Have you looked into seaborn?

import seaborn as sns
# Out:
# Object `seaborn` not found.

# %%
pd.set_option("display.max_columns", 100)
# %matplotlib inline

# %% [markdown]
# <h1>Dataset Importing</h1>

# %%
DATA_PATH = Path.cwd() / "../../datasets"

# %%
training_df = pd.read_csv(DATA_PATH / "train.csv", index_col="tripid")
training_df.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0              0.0000
# 189125358             10.5     791.0           47.0              0.0000
# 189125719             10.5    1087.0           80.0              0.0000
# 189127273             10.5     598.0          271.0             15.6638
# 189128020              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup     pickup_time       drop_time  \
# tripid
# 189123628                       64.0  11/1/2019 0:20  11/1/2019 0:34
# 189125358                      134.0  11/1/2019 0:56  11/1/2019 1:09
# 189125719                       61.0  11/1/2019 1:08  11/1/2019 1:26
# 189127273                       68.0  11/1/2019 2:27  11/1/2019 2:37
# 189128020                        NaN  11/1/2019 3:34  11/1/2019 3:51
#
#            pick_lat  pick_lon  drop_lat  drop_lon    fare    label
# tripid
# 189123628   6.86252   79.8993   6.90330   79.8783  270.32  correct
# 189125358   6.88589   79.8984   6.91373   79.8923  197.85  correct
# 189125719   6.90839   79.8651   6.93669   79.9146  301.64  correct
# 189127273   6.92570   79.8895   6.92748   79.8971   82.30  correct
# 189128020   6.87441   79.8615   6.84478   79.9290  358.39  correct

# %% [markdown]
# <h1>Data Preprocessing</h1>

# %%
training_df['pickup_time'] = pd.to_datetime(training_df['pickup_time'], format="%m/%d/%Y %H:%M")
training_df['drop_time'] = pd.to_datetime(training_df['drop_time'], format="%m/%d/%Y %H:%M")

# %%
training_df['label_marker']=(training_df['label']=='correct').astype(int)

# %% [markdown]
# <h1>Initial Data Analyisis</h1>

# %%
training_df.dtypes
# Out:
# additional_fare                     float64
# duration                            float64
# meter_waiting                       float64
# meter_waiting_fare                  float64
# meter_waiting_till_pickup           float64
# pickup_time                  datetime64[ns]
# drop_time                    datetime64[ns]
# pick_lat                            float64
# pick_lon                            float64
# drop_lat                            float64
# drop_lon                            float64
# fare                                float64
# label                                object
# label_marker                          int64
# dtype: object

# %%
training_df.columns
# Out:
# Index(['additional_fare', 'duration', 'meter_waiting', 'meter_waiting_fare',
#        'meter_waiting_till_pickup', 'pickup_time', 'drop_time', 'pick_lat',
#        'pick_lon', 'drop_lat', 'drop_lon', 'fare', 'label', 'label_marker'],
#       dtype='object')

# %% [markdown]
# <h2>Initial Feature Correlation</h2>

# %%
heatmap_initial = training_df.corr()

# %%
sns.heatmap(heatmap_initial)

# %%
sns.lmplot('duration', 'fare', training_df[training_df['duration']<4000], hue='label', fit_reg=False)
fig = plt.gcf()
fig.set_size_inches(15, 10)
plt.show()

# %% [markdown]
# <h2>Identification of Anomalies within the Correct dataset</h2>
# <b>Consider only correct as Anomalies within the correct data maybe called 'incorrect' due to the anomaly<b>

# %%
training_df.isna().sum()
# Out:
# additional_fare              202
# duration                     202
# meter_waiting                202
# meter_waiting_fare           202
# meter_waiting_till_pickup    202
# pickup_time                    0
# drop_time                      0
# pick_lat                       0
# pick_lon                       0
# drop_lat                       0
# drop_lon                       0
# fare                         137
# label                          0
# label_marker                   0
# dtype: int64

# %%
correct_training_df = training_df[training_df['label']=='correct']

# %% [markdown]
# <h3>Null and Zero variable Analysis</h3>

# %%
correct_training_df.isna().sum()
# Out:
# additional_fare              53
# duration                     53
# meter_waiting                53
# meter_waiting_fare           53
# meter_waiting_till_pickup    53
# pickup_time                   0
# drop_time                     0
# pick_lat                      0
# pick_lon                      0
# drop_lat                      0
# drop_lon                      0
# fare                          0
# label                         0
# label_marker                  0
# dtype: int64

# %% [markdown]
# <b>All Rows with unspecified fare are incorrect<b>

# %%
corrNaNRows = correct_training_df[correct_training_df.isnull().any(axis=1)]

# %%
corrNaNRows.shape
# Out:
# (53, 14)

# %% [markdown]
# <b>All NaN entries are on the same row and are not dispersed<b>

# %%
zero_count = {}
negative_count = {}
for i in ['additional_fare', 'duration', 'meter_waiting', 'meter_waiting_fare',
       'meter_waiting_till_pickup', 'fare'] :
    zero_count[i] = 0
    negative_count[i] = 0
    for index,row in correct_training_df.iterrows():
        if row[i] < 0:
            negative_count[i]+=1
        if row[i] == 0:
            zero_count[i]+=1

# %%
print(zero_count)
print(negative_count)
# Out:
# {'additional_fare': 1, 'duration': 0, 'meter_waiting': 636, 'meter_waiting_fare': 7568, 'meter_waiting_till_pickup': 1319, 'fare': 1}
# {'additional_fare': 0, 'duration': 0, 'meter_waiting': 0, 'meter_waiting_fare': 0, 'meter_waiting_till_pickup': 0, 'fare': 0}

# %% [markdown]
# <b>No negative counts<b>

# %%
correct_training_df[correct_training_df['fare']==0]
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 191841099              0.0    2446.0          840.0                 0.0
#
#            meter_waiting_till_pickup         pickup_time           drop_time  \
# tripid
# 191841099                      231.0 2019-11-14 08:25:00 2019-11-14 09:06:00
#
#            pick_lat  pick_lon  drop_lat  drop_lon  fare    label  label_marker
# tripid
# 191841099   6.85527   79.8882   6.87782   79.8773   0.0  correct             1

# %% [markdown]
# <b>All rows with fare = 0 [except 191841099] are marked incorrect <b> <br/>
# <b>All rows with fare = 0 also have 0 additional fare and meter waiting fare<b> <br/>
# <b>Row could be an anomaly<b>

# %% [markdown]
# <h1>Initial Data Cleaning</h1>

# %% [markdown]
# <h1>Feature Engineering</h1>

# %%
# Bin times into 3 ranges to simplify time ascpect
training_df = training_df.assign(timeOfDay=pd.cut(training_df.pickup_time.dt.hour,[-1, 8, 20, 24],labels=['dawn','day', 'night']))

training_df['isDawn']=(training_df['timeOfDay']=='dawn').astype(int)
training_df['isNight']=(training_df['timeOfDay']=='night').astype(int)
training_df['isDay']=(training_df['timeOfDay']=='day').astype(int)

# %%
durations = []
for index,row in training_df.iterrows():
    provided_duration = row['duration'] 
    if math.isnan(provided_duration) or provided_duration <= 0 :
        time_dif = (row['drop_time'] - row['pickup_time']).seconds
        if time_dif == 0:
            time_dif = np.nan
        durations.append(time_dif)
    else :  
        durations.append(provided_duration)

training_df.insert(10,"time_dif",durations)

# %%
def dist_from_coordinates(lat1, lon1, lat2, lon2):
    R = 6371  
    d_lat = np.radians(lat2-lat1)
    d_lon = np.radians(lon2-lon1)

    r_lat1 = np.radians(lat1)
    r_lat2 = np.radians(lat2)
    a = np.sin(d_lat/2.) **2 + np.cos(r_lat1) * np.cos(r_lat2) * np.sin(d_lon/2.)**2

    haversine = 2 * R * np.arcsin(np.sqrt(a))

    return haversine

# %%
distances = []                    #empty column for distance
for index,row in training_df.iterrows():
    lat1 = row['pick_lat'] 
    lon1 = row['pick_lon'] 
    lat2 = row['drop_lat'] 
    lon2 = row['drop_lon'] 
    value = dist_from_coordinates(lat1, lon1, lat2, lon2)  
    distances.append(value)   

training_df.insert(10,"distance",distances)

# %%
training_df['time_driven'] = training_df['duration']  - training_df['meter_waiting']

# %%
training_df['driving_fare'] = training_df['fare']  - training_df['meter_waiting_fare'] - training_df['additional_fare']

# %%
training_df['cost_per_km'] = training_df['distance'] / training_df['driving_fare']

# %%
training_df['avg_speed'] = (training_df['distance'] /  ( training_df['time_driven']) * 3600 )

# %%
training_df['charge_per_hour'] = training_df['meter_waiting_fare'] / training_df['meter_waiting'] * 3600

# %%
training_df[(training_df['cost_per_km']<0.05) & (training_df['duration']<1000) ]
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0            0.000000
# 189125358             10.5     791.0           47.0            0.000000
# 189127273             10.5     598.0          271.0           15.663800
# 189139296             10.5     360.0           80.0            4.664000
# 189135814             10.5      26.0           19.0            0.000000
# 189140969             10.5      31.0           20.0            0.000000
# 189145904             10.5     335.0           10.0            0.583000
# 189153229             10.5     284.0            0.0            0.000000
# 189157464             10.5     891.0          170.0            0.000000
# 189157559             10.5     693.0          280.0            9.883800
# 189159951              5.0     850.0          143.0            8.336900
# 189160756             10.5     358.0           66.0            0.000000
# 189161377             10.5     644.0          638.0           14.796800
# 189163162             10.5     618.0          128.0            7.398400
# 189164880             10.5     575.0           23.0            0.000000
# 189164791             10.5     286.0           44.0            0.000000
# 189165178             10.5     537.0           30.0            1.734000
# 189165865             10.5     345.0           10.0            0.000000
# 189168508             10.5     558.0           77.0            0.115600
# 189170729             10.5     323.0           90.0            4.103800
# 189172042             10.5     433.0           58.0            0.000000
# 189172150             10.5     188.0           10.0            0.000000
# 189177024             10.5     495.0          298.0           12.080200
# 189179135             10.5     799.0          210.0           12.138000
# 189182800             10.5     220.0           10.0            0.000000
# 189183026             10.5     500.0          247.0           11.502200
# 189183791             10.5     683.0           40.0            0.000000
# 189185482             10.5     398.0           80.0            4.664000
# 189191170             10.5     389.0           30.0            0.000000
# 189192436             10.5      22.0           21.0            0.000000
# ...                    ...       ...            ...                 ...
# 213671827             10.5     851.0          106.0            0.000000
# 213676670              5.0     526.0          191.0           11.135300
# 213679697             10.5     439.0           85.0            4.955500
# 213679658             10.5      39.0           36.0            2.098800
# 213687229             10.5     900.0          105.0            0.000000
# 213686050             10.5     643.0            5.0            0.291500
# 213703973             40.5     913.0          445.0            0.000000
# 213707443             10.5     990.0           99.0            5.771700
# 213707150             10.5     866.0          763.0           44.482900
# 213784596   6.98704   79.8800   6.95716   3.876857     831.0   79.8619
# 213787716   6.00698   80.2534   6.01562   2.718819     733.0   80.2764
# 213799350   7.09392   79.9947   7.05780   4.076082     801.0   80.0010
# 213800748   6.87659   79.9975   6.87827   1.032670     500.0   79.9883
# 213802222   6.87354   79.8799   6.86674   0.829968     400.0   79.8768
# 213803193   7.29073   80.6367   7.28891   2.105376     838.0   80.6557
# 213813930   7.09210   79.9000   7.10135   1.045518     263.0   79.9017
# 213815405   6.94540   79.8768   6.93574   2.879077     858.0   79.9010
# 213817296   6.90257   79.9557   6.90823   2.115875     262.0   79.9374
#
#              fare      label  label_marker timeOfDay  isDawn  isNight  isDay  \
# tripid
# 189123628  270.32    correct             1      dawn       1        0      0
# 189125358  197.85    correct             1      dawn       1        0      0
# 189127273   82.30    correct             1      dawn       1        0      0
# 189139296  100.32    correct             1      dawn       1        0      0
# 189135814  694.37  incorrect             0      dawn       1        0      0
# 189140969  235.59  incorrect             0      dawn       1        0      0
# 189145904  126.87    correct             1      dawn       1        0      0
# 189153229   95.31    correct             1      dawn       1        0      0
# 189157464  226.54    correct             1      dawn       1        0      0
# 189157559  109.36    correct             1      dawn       1        0      0
# 189159951  235.25    correct             1      dawn       1        0      0
# 189160756  210.58  incorrect             0      dawn       1        0      0
# 189161377  113.71  incorrect             0      dawn       1        0      0
# 189163162  106.80    correct             1       day       0        0      1
# 189164880  178.26    correct             1       day       0        0      1
# 189164791  545.89  incorrect             0       day       0        0      1
# 189165178  132.12    correct             1       day       0        0      1
# 189165865  107.79    correct             1       day       0        0      1
# 189168508  129.52    correct             1       day       0        0      1
# 189170729   81.06    correct             1       day       0        0      1
# 189172042  107.59    correct             1       day       0        0      1
# 189172150   60.50    correct             1       day       0        0      1
# 189177024   61.67    correct             1       day       0        0      1
# 189179135  106.45    correct             1       day       0        0      1
# 189182800   71.84    correct             1       day       0        0      1
# 189183026   91.77    correct             1       day       0        0      1
# 189183791  146.68    correct             1       day       0        0      1
# 189185482   83.88    correct             1       day       0        0      1
# 189191170  102.19    correct             1       day       0        0      1
# 189192436   60.50    correct             1       day       0        0      1
# ...           ...        ...           ...       ...     ...      ...    ...
# 213671827  178.96    correct             1       day       0        0      1
# 213676670  111.49    correct             1       day       0        0      1
# 213679697   91.11    correct             1       day       0        0      1
# 213679658   72.59    correct             1       day       0        0      1
# 213687229  222.35    correct             1       day       0        0      1
# 213686050  152.39    correct             1       day       0        0      1
# 213703973  534.00  incorrect             0       day       0        0      1
# 213707443  183.04    correct             1       day       0        0      1
# 213707150  104.98    correct             1       day       0        0      1
# 213719327  195.15    correct             1       day       0        0      1
# 213741503  157.43    correct             1       day       0        0      1
# 213740361  151.29    correct             1       day       0        0      1
# 213751620   70.75    correct             1       day       0        0      1
# 213759061  139.03    correct             1       day       0        0      1
# 213776255  115.22    correct             1       day       0        0      1
# 213774316  106.52    correct             1       day       0        0      1
# 213775846  131.09    correct             1       day       0        0      1
# 213774642  141.66    correct             1       day       0        0      1
# 213774742   96.70    correct             1       day       0        0      1
# 213782178        653.0    185.740000     0.020655    21.150740
# 213784596        804.0    171.280000     0.022635    17.359063
# 213787716        690.0    200.240000     0.013578    14.185144
# 213799350        794.0    199.760000     0.020405    18.480978
# 213800748        383.0     94.920000     0.010879     9.706554
# 213802222        305.0     70.730000     0.011734     9.796342
# 213803193        745.0    182.338100     0.011547    10.173627
# 213813930        254.0     65.700000     0.015914    14.818372
# 213815405        743.0    122.810000     0.023443    13.949766
# 213817296        241.0     86.845700     0.024364    31.606433
#
#            charge_per_hour
# tripid
# 189123628         0.000000
# 189125358         0.000000
# 189127273       208.080000
# 189139296       209.880000
# 189135814         0.000000
# 189140969         0.000000
# 189145904       209.880000
# 189153229              NaN
# 189157464         0.000000
# 189157559       127.077429
# 189159951       209.880000
# 189160756         0.000000
# 189161377        83.492915
# 189163162       208.080000
# 189164880         0.000000
# 189164791         0.000000
# 189165178       208.080000
# 189165865         0.000000
# 189168508         5.404675
# 189170729       164.152000
# 189172042         0.000000
# 189172150         0.000000
# 189177024       145.935302
# 189179135       208.080000
# 189182800         0.000000
# 189183026       167.643401
# 189183791         0.000000
# 189185482       209.880000
# 189191170         0.000000
# 189192436         0.000000
# ...                    ...
# 213671827         0.000000
# 213676670       209.880000
# 213679697       209.880000
# 213679658       209.880000
# 213687229         0.000000
# 213686050       209.880000
# 213703973         0.000000
# 213707443       209.880000
# 213707150       209.880000
# 213719327         0.000000
# 213741503         0.000000
# 213740361         0.000000
# 213751620       209.880000
# 213759061         0.000000
# 213776255       209.880000
# 213774316       209.880000
# 213775846       209.880000
# 213774642       208.797517
# 213774742         0.000000
# 213779882       208.530390
# 213782178         0.000000
# 213784596         0.000000
# 213787716         0.000000
# 213799350         0.000000
# 213800748         0.000000
# 213802222         0.000000
# 213803193       209.880000
# 213813930         0.000000
# 213815405         0.000000
# 213817296       209.880000
#
# [8250 rows x 25 columns]

# %% [markdown]
# <h1>Post feature engineering Analysis</h1>

# %%
hue_order = ['incorrect','correct']
sns.lmplot('time_driven', 'driving_fare',training_df[(training_df['time_driven']>0) & (training_df['time_driven']<1000)],hue_order=hue_order, hue='label', fit_reg=False)
fig = plt.gcf()
fig.set_size_inches(15, 10)
plt.show()

# %%
training_df.corr()
# Out:
#                            additional_fare  duration  meter_waiting  \
# additional_fare                   1.000000 -0.000772       0.197605
# duration                         -0.000772  1.000000       0.969787
# meter_waiting                     0.197605  0.969787       1.000000
# meter_waiting_fare                0.199604  0.968666       0.999474
# meter_waiting_till_pickup         0.002355  0.040578       0.030447
# pick_lat                          0.009124 -0.027079      -0.016171
# pick_lon                          0.000621 -0.025593      -0.014211
# drop_lat                          0.004644 -0.015969      -0.010117
# distance                         -0.000431  0.012872       0.004353
# time_dif                         -0.000775  0.999998       0.969788
# drop_lon                          0.001539 -0.013605      -0.007905
# fare                              0.315285  0.865256       0.870126
# label_marker                     -0.040910 -0.112955      -0.107266
# isDawn                            0.014425 -0.004514       0.000149
# isNight                          -0.004863 -0.005274      -0.000679
# isDay                            -0.008934  0.007241       0.000319
# time_driven                      -0.803874  0.151021      -0.094696
# driving_fare                     -0.002523  0.251025       0.145441
# cost_per_km                      -0.000194 -0.001874      -0.000998
# avg_speed                        -0.000419 -0.006568       0.002169
# charge_per_hour                   0.009425  0.079643       0.060718
#
#                            meter_waiting_fare  meter_waiting_till_pickup  \
# additional_fare                      0.199604                   0.002355
# duration                             0.968666                   0.040578
# meter_waiting                        0.999474                   0.030447
# meter_waiting_fare                   1.000000                   0.029908
# meter_waiting_till_pickup            0.029908                   1.000000
# pick_lat                            -0.015014                   0.011393
# pick_lon                            -0.012483                   0.016509
# drop_lat                            -0.009430                   0.006949
# distance                             0.003910                   0.003082
# time_dif                             0.968667                   0.040609
# drop_lon                            -0.006805                   0.011065
# fare                                 0.865073                   0.045468
# label_marker                        -0.103319                  -0.035320
# isDawn                              -0.000367                   0.003918
# isNight                             -0.000736                  -0.004043
# isDay                                0.000790                  -0.000646
# time_driven                         -0.097141                   0.042213
# driving_fare                         0.133506                   0.045641
# cost_per_km                         -0.000952                   0.000330
# avg_speed                            0.002231                   0.027056
# charge_per_hour                      0.069015                  -0.016955
#
#                            pick_lat  pick_lon  drop_lat  distance  time_dif  \
# additional_fare            0.009124  0.000621  0.004644 -0.000431 -0.000775
# duration                  -0.027079 -0.025593 -0.015969  0.012872  0.999998
# meter_waiting             -0.016171 -0.014211 -0.010117  0.004353  0.969788
# meter_waiting_fare        -0.015014 -0.012483 -0.009430  0.003910  0.968667
# meter_waiting_till_pickup  0.011393  0.016509  0.006949  0.003082  0.040609
# pick_lat                   1.000000  0.522473  0.560466  0.009705 -0.026444
# pick_lon                   0.522473  1.000000  0.307313  0.005363 -0.025014
# drop_lat                   0.560466  0.307313  1.000000  0.820331 -0.015476
# distance                   0.009705  0.005363  0.820331  1.000000  0.013199
# time_dif                  -0.026444 -0.025014 -0.015476  0.013199  1.000000
# drop_lon                   0.340161  0.654917 -0.414566 -0.739907 -0.013319
# fare                      -0.024556 -0.035237 -0.015530  0.033698  0.865080
# label_marker              -0.029237 -0.037713 -0.012781  0.000353 -0.112492
# isDawn                    -0.029274 -0.039715 -0.017055  0.004264 -0.004755
# isNight                   -0.022939 -0.041841 -0.014356  0.002953 -0.005032
# isDay                      0.039599  0.060757  0.023722 -0.005513  0.007289
# time_driven               -0.044975 -0.046853 -0.024169  0.034890  0.151010
# driving_fare              -0.030315 -0.053649 -0.018851  0.063345  0.251006
# cost_per_km                0.017133  0.018007  0.830311  0.994730 -0.001874
# avg_speed                 -0.006828 -0.015294  0.301670  0.384889 -0.006568
# charge_per_hour            0.035227  0.051764  0.025765 -0.002453  0.079643
#
#                            drop_lon      fare  label_marker    isDawn  \
# additional_fare            0.001539  0.315285     -0.040910  0.014425
# duration                  -0.013605  0.865256     -0.112955 -0.004514
# meter_waiting             -0.007905  0.870126     -0.107266  0.000149
# meter_waiting_fare        -0.006805  0.865073     -0.103319 -0.000367
# meter_waiting_till_pickup  0.011065  0.045468     -0.035320  0.003918
# pick_lat                   0.340161 -0.024556     -0.029237 -0.029274
# pick_lon                   0.654917 -0.035237     -0.037713 -0.039715
# drop_lat                  -0.414566 -0.015530     -0.012781 -0.017055
# distance                  -0.739907  0.033698      0.000353  0.004264
# time_dif                  -0.013319  0.865080     -0.112492 -0.004755
# drop_lon                   1.000000 -0.014912     -0.030347 -0.031812
# fare                      -0.014912  1.000000     -0.183336  0.015756
# label_marker              -0.030347 -0.183336      1.000000  0.009962
# isDawn                    -0.031812  0.015756      0.009962  1.000000
# isNight                   -0.018400  0.006438     -0.008581 -0.121508
# isDay                      0.038750 -0.017438     -0.002723 -0.758857
# time_driven               -0.023485  0.005000     -0.026282 -0.019024
# driving_fare              -0.020665  0.586717     -0.201719  0.028155
# cost_per_km               -0.739772 -0.004155      0.001408 -0.002743
# avg_speed                 -0.291350 -0.006351     -0.150435  0.009907
# charge_per_hour            0.030768  0.070383      0.054701 -0.079131
#
#                             isNight     isDay  time_driven  driving_fare  \
# additional_fare           -0.004863 -0.008934    -0.803874     -0.002523
# duration                  -0.005274  0.007241     0.151021      0.251025
# meter_waiting             -0.000679  0.000319    -0.094696      0.145441
# meter_waiting_fare        -0.000736  0.000790    -0.097141      0.133506
# meter_waiting_till_pickup -0.004043 -0.000646     0.042213      0.045641
# pick_lat                  -0.022939  0.039599    -0.044975     -0.030315
# pick_lon                  -0.041841  0.060757    -0.046853     -0.053649
# drop_lat                  -0.014356  0.023722    -0.024169     -0.018851
# distance                   0.002953 -0.005513     0.034890      0.063345
# time_dif                  -0.005032  0.007289     0.151010      0.251006
# drop_lon                  -0.018400  0.038750    -0.023485     -0.020665
# fare                       0.006438 -0.017438     0.005000      0.586717
# label_marker              -0.008581 -0.002723    -0.026282     -0.201719
# isDawn                    -0.121508 -0.758857    -0.019024      0.028155
# isNight                    1.000000 -0.554224    -0.018772      0.016561
# isDay                     -0.554224  1.000000     0.028257     -0.034479
# time_driven               -0.018772  0.028257     1.000000      0.435027
# driving_fare               0.016561 -0.034479     0.435027      1.000000
# cost_per_km               -0.001455  0.003255    -0.003605     -0.007001
# avg_speed                  0.038206 -0.033310    -0.035594     -0.016506
# charge_per_hour           -0.073367  0.114254     0.079314      0.032631
#
#                            cost_per_km  avg_speed  charge_per_hour
# additional_fare              -0.000194  -0.000419         0.009425
# duration                     -0.001874  -0.006568         0.079643
# meter_waiting                -0.000998   0.002169         0.060718
# meter_waiting_fare           -0.000952   0.002231         0.069015
# meter_waiting_till_pickup     0.000330   0.027056        -0.016955
# pick_lat                      0.017133  -0.006828         0.035227
# pick_lon                      0.018007  -0.015294         0.051764
# drop_lat                      0.830311   0.301670         0.025765
# distance                      0.994730   0.384889        -0.002453
# time_dif                     -0.001874  -0.006568         0.079643
# drop_lon                     -0.739772  -0.291350         0.030768
# fare                         -0.004155  -0.006351         0.070383
# label_marker                  0.001408  -0.150435         0.054701
# isDawn                       -0.002743   0.009907        -0.079131
# isNight                      -0.001455   0.038206        -0.073367
# isDay                         0.003255  -0.033310         0.114254
# time_driven                  -0.003605  -0.035594         0.079314
# driving_fare                 -0.007001  -0.016506         0.032631
# cost_per_km                   1.000000   0.384729         0.004991
# avg_speed                     0.384729   1.000000        -0.052206
# charge_per_hour               0.004991  -0.052206         1.000000

# %%
zero_count = {}
negative_count = {}
for i in ['avg_speed','driving_fare','time_driven','distance'] :
    zero_count[i] = 0
    negative_count[i] = 0
    for index,row in training_df.iterrows():
        if row[i] < 0:
            negative_count[i]+=1
        if row[i] == 0:
            zero_count[i]+=1

# %%
print(zero_count)
print(negative_count)
# Out:
# {'avg_speed': 37, 'driving_fare': 14, 'time_driven': 14, 'distance': 37}
# {'avg_speed': 4, 'driving_fare': 1, 'time_driven': 4, 'distance': 0}

# %% [markdown]
# <h3>Viewing features of the Incorrect Dataset</h3>

# %%
incorrect_training_df = training_df[training_df['label']=='incorrect']

# %%
incorrect_training_df[incorrect_training_df['meter_waiting'] < 3600].plot(kind='scatter',x='meter_waiting',y='charge_per_hour',color='red')

# %% [markdown]
# <h2>Identification of Anomalies within the Correct dataset</h2>
# <b>Consider only correct as Anomalies within the correct data maybe called 'incorrect' due to the anomaly<b>

# %%
correct_training_df = training_df[training_df['label']=='correct']

# %%
correct_training_df.nlargest(10, ['cost_per_km'])
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 191841099              0.0    2446.0          840.0            0.000000
# 190167541             10.5     313.0           50.0            2.915000
# 205179926             60.5     610.0          230.0           13.339372
# 190289312             10.5      78.0           77.0            0.000000
# 201654842             10.5      34.0           27.0            0.000000
# 198520316             10.5      31.0           10.0            0.000000
# 213412611             10.5      36.0           34.0            0.000000
# 203723763             60.5     549.0           25.0            1.445000
# 211078046             10.5      46.0           42.0            0.000000
# 204923587             10.5      44.0           41.0            0.000000
#
#            meter_waiting_till_pickup         pickup_time           drop_time  \
# tripid
# 191841099                      231.0 2019-11-14 08:25:00 2019-11-14 09:06:00
# 190167541                       98.0 2019-11-06 09:37:00 2019-11-06 09:42:00
# 205179926                       51.0 2019-12-30 17:36:00 2019-12-30 17:47:00
# 190289312                       94.0 2019-11-06 21:01:00 2019-11-06 21:02:00
# 201654842                     1250.0 2019-12-18 13:38:00 2019-12-18 13:39:00
# 198520316                      218.0 2019-12-06 19:58:00 2019-12-06 19:59:00
# 213412611                      272.0 2020-01-30 20:26:00 2020-01-30 20:27:00
# 203723763                       27.0 2019-12-24 15:45:00 2019-12-24 15:54:00
# 211078046                      155.0 2020-01-20 20:27:00 2020-01-20 20:28:00
# 204923587                      455.0 2019-12-29 18:54:00 2019-12-29 18:55:00
#
#            pick_lat  pick_lon  drop_lat     distance  time_dif  drop_lon  \
# tripid
# 191841099   6.85527   79.8882   6.87782     2.781239    2446.0   79.8773
# 190167541   7.46897   80.6227  48.13200  5609.521440     313.0   45.3077
# 205179926   7.29204   80.6370   7.29088     0.782771     610.0   80.6300
# 190289312   6.95046   79.8723   6.95682    15.910017      78.0   80.0163
# 201654842   6.97579   79.9170   6.91131    10.174379      34.0   79.8516
# 198520316   6.90294   79.9579   6.90862     8.534335      31.0   80.0350
# 213412611   6.83212   79.9123   6.80037     8.097177      36.0   79.9783
# 203723763   6.90768   79.8535   6.88925     2.140531     549.0   79.8591
# 211078046   6.97525   79.9529   7.03192     7.108067      46.0   79.9231
# 204923587   6.93782   79.9225   6.93462     6.930037      44.0   79.9852
#
#             fare    label  label_marker timeOfDay  isDawn  isNight  isDay  \
# tripid
# 191841099   0.00  correct             1      dawn       1        0      0
# 190167541  63.41  correct             1       day       0        0      1
# 205179926  75.99  correct             1       day       0        0      1
# 190289312  60.50  correct             1     night       0        1      0
# 201654842  61.00  correct             1       day       0        0      1
# 198520316  60.50  correct             1       day       0        0      1
# 213412611  60.50  correct             1       day       0        0      1
# 203723763  75.33  correct             1       day       0        0      1
# 211078046  60.50  correct             1       day       0        0      1
# 204923587  60.50  correct             1       day       0        0      1
#
#            time_driven  driving_fare  cost_per_km     avg_speed  \
# tripid
# 191841099       1606.0      0.000000          inf      6.234408
# 190167541        263.0     49.995000   112.201649  76784.323893
# 205179926        380.0      2.150628     0.363973      7.415721
# 190289312          1.0     50.000000     0.318200  57276.060589
# 201654842          7.0     50.500000     0.201473   5232.537547
# 198520316         21.0     50.000000     0.170687   1463.028887
# 213412611          2.0     50.000000     0.161944  14574.917882
# 203723763        524.0     13.385000     0.159920     14.705939
# 211078046          4.0     50.000000     0.142161   6397.259859
# 204923587          3.0     50.000000     0.138601   8316.044064
#
#            charge_per_hour
# tripid
# 191841099         0.000000
# 190167541       209.880000
# 205179926       208.790171
# 190289312         0.000000
# 201654842         0.000000
# 198520316         0.000000
# 213412611         0.000000
# 203723763       208.080000
# 211078046         0.000000
# 204923587         0.000000

# %%
correct_training_df.plot(kind='scatter',y='cost_per_km',x='distance')

# %%
zero_count = {}
negative_count = {}
for i in ['avg_speed','driving_fare','time_driven','distance', 'charge_per_hour'] :
    zero_count[i] = 0
    negative_count[i] = 0
    for index,row in correct_training_df.iterrows():
        if row[i] < 0:
            negative_count[i]+=1
        if row[i] == 0:
            zero_count[i]+=1

# %%
print(zero_count)
print(negative_count)
# Out:
# {'avg_speed': 34, 'driving_fare': 1, 'time_driven': 2, 'distance': 34, 'charge_per_hour': 6932}
# {'avg_speed': 1, 'driving_fare': 1, 'time_driven': 1, 'distance': 0, 'charge_per_hour': 0}

# %%
correct_training_df[correct_training_df['avg_speed'] < 0]
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 207947602             40.5      24.0          617.0                 0.0
#
#            meter_waiting_till_pickup         pickup_time           drop_time  \
# tripid
# 207947602                      229.0 2020-01-08 14:55:00 2020-01-08 14:56:00
#
#            pick_lat  pick_lon  drop_lat  distance  time_dif  drop_lon  fare  \
# tripid
# 207947602   6.93383   79.8545   6.93317  0.141876      24.0   79.8556  90.5
#
#              label  label_marker timeOfDay  isDawn  isNight  isDay  \
# tripid
# 207947602  correct             1       day       0        0      1
#
#            time_driven  driving_fare  cost_per_km  avg_speed  charge_per_hour
# tripid
# 207947602       -593.0          50.0     0.002838  -0.861302              0.0

# %% [markdown]
# <b>row 207947602 is anomolous as the driving time is negative<b>

# %%
correct_training_df[correct_training_df['time_driven'] == 0]

# %%
correct_training_df[correct_training_df['time_driven'] < 60]

# %% [markdown]
# <h1>Post feature engineering Data cleaning</h1>
