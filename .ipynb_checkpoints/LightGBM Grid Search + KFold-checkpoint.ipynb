# %%
import numpy as np
import pandas as pd
import lightgbm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import math
from sklearn import metrics
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import os
import glob

# %%
data_path='/home/madnisal/Documents/ML_Project/datasets/'
training_df = pd.read_csv(data_path+'train.csv', index_col="tripid")

# %%
def dist_from_coordinates(lat1, lon1, lat2, lon2):
  R = 6371  # Earth radius in km

  #conversion to radians
  d_lat = np.radians(lat2-lat1)
  d_lon = np.radians(lon2-lon1)

  r_lat1 = np.radians(lat1)
  r_lat2 = np.radians(lat2)

  #haversine formula
  a = np.sin(d_lat/2.) **2 + np.cos(r_lat1) * np.cos(r_lat2) * np.sin(d_lon/2.)**2

  haversine = 2 * R * np.arcsin(np.sqrt(a))

  return haversine

# %%
training_df['pickup_time'] = pd.to_datetime(training_df['pickup_time'], format="%m/%d/%Y %H:%M")
training_df['drop_time'] = pd.to_datetime(training_df['drop_time'], format="%m/%d/%Y %H:%M")

# %%
training_df = training_df.assign(timeOfDay=pd.cut(training_df.pickup_time.dt.hour,[-1, 8, 20, 24],labels=['dawn','day', 'night']))

# %%
training_df.loc[training_df['timeOfDay'] == 'day', 'isNormalCharge'] = 1
training_df.loc[training_df['timeOfDay'] != 'day', 'isNormalCharge'] = 0

# %%
durations = []
for index,row in training_df.iterrows():
  provided_duration = row['duration'] #first row of location.lat column here
  if math.isnan(provided_duration) or provided_duration <= 0 :
    time_dif = (row['drop_time'] - row['pickup_time']).seconds
    if(time_dif == 0):
        time_dif = np.nan
    durations.append(time_dif)
  else :  
    durations.append(provided_duration)

training_df.insert(4,"time_dif",durations)

# %%
new_column = []                    #empty column for distance
for index,row in training_df.iterrows():
  lat1 = row['pick_lat'] #first row of location.lat column here
  lon1 = row['pick_lon'] #first row of location.long column here
  lat2 = row['drop_lat'] #second row of location.lat column here
  lon2 = row['drop_lon'] #second row of location.long column here
  value = dist_from_coordinates(lat1, lon1, lat2, lon2)  #get the distance
  new_column.append(value)   #append the empty list with distance values

training_df.insert(4,"distance",new_column)

# %%
training_df['time_driven'] = training_df['duration']  - training_df['meter_waiting']

# %%
chargeperhours = []
for index,row in training_df.iterrows():
    if(row['meter_waiting'] == 0):
        chargeperhour = np.nan
    else:
        chargeperhour = (row['meter_waiting_fare'] / row['meter_waiting'] * 3600)
    chargeperhours.append(chargeperhour)

training_df.insert(4,'charge_per_hour',chargeperhours)

# %%
training_df['driving_fare'] = training_df['fare']  - training_df['meter_waiting_fare'] - training_df['additional_fare']

# %%
avgspeeds = []
for index,row in training_df.iterrows():
    if(row['time_driven'] == 0):
        avgspeed = np.nan
    else:
        avgspeed = (row['distance'] / row['time_driven'] * 3600)
    avgspeeds.append(avgspeed)

training_df.insert(4,"avg_speed",avgspeeds)

# %%
costsperkm = []
for index,row in training_df.iterrows():
    if row['distance'] == 0:
        costperkm = np.nan
            
    else:
        costperkm = (row['driving_fare'] / row['distance'])
    costsperkm.append(costperkm)

training_df.insert(4,"cost_per_km",costsperkm)

# %%
training_df = training_df.replace({'label': {'incorrect': 0, 'correct' : 1}})

# %%
training_df.columns
# Out:
# Index(['additional_fare', 'duration', 'meter_waiting', 'meter_waiting_fare',
#        'cost_per_km', 'avg_speed', 'charge_per_hour', 'distance', 'time_dif',
#        'meter_waiting_till_pickup', 'pickup_time', 'drop_time', 'pick_lat',
#        'pick_lon', 'drop_lat', 'drop_lon', 'fare', 'label', 'timeOfDay',
#        'isNormalCharge', 'time_driven', 'driving_fare'],
#       dtype='object')

# %%
#training_columns = ['duration','meter_waiting','meter_waiting_fare','fare','additional_fare']

# %%
training_columns = ['meter_waiting','meter_waiting_fare','fare','additional_fare', 'distance','cost_per_km', 'avg_speed',  'time_dif','time_driven', 'charge_per_hour', 'driving_fare', 'isNormalCharge','pick_lat','pick_lon','drop_lat','drop_lon']

# %%
#training_columns = ['additional_fare', 'meter_waiting','cost_per_km', 'avg_speed', 'charge_per_hour', 'time_dif','isNormalCharge', 'time_driven']

# %%
#training_columns = ['duration','meter_waiting','meter_waiting_fare','fare','additional_fare', 'distance','cost_per_km', 'avg_speed',  'time_dif','time_driven', 'charge_per_hour', 'driving_fare', 'isNormalCharge']

# %%
target_column = ['label']

# %%
training_df = training_df.drop(190167541)

# %%
x = training_df[training_columns].values
y = training_df[target_column].values

# %%
x, x_test, y, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
training_df['label'].value_counts()
# Out:
# 1    15494
# 0     1681
# Name: label, dtype: int64

# %% [markdown]
# <h2>Hyper tuning</h2>

# %%
param_grid = {
    'num_leaves': [15,31, 63],
    'learning_rate': [0.1, 0.01],
    'class_weight' : [{0:4,1:1}, {0:3,1:1}],
    'num_boosting_rounds': [100,500],
    'max_bins': [10,100,1000],
    'n_estimators': [50,100,200],
    'reg_alpha': [0.1, 0.5],
    'random_state': [1,8,16,64],
    'min_data_in_leaf': [30,100,400],
    'lambda_l2': [0, 1]
    }

# %%
model = lightgbm.LGBMClassifier()

# %%
gkf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42).split(X=x, y=y)

# %%
gs = GridSearchCV(
    estimator=model, param_grid=param_grid, cv=gkf, scoring='f1_macro',
    verbose=True, n_jobs=3)

# %%
gs.fit(x, y.ravel())

# %%
print('Best score reached: {} with params: {} '.format(gs.best_score_, gs.best_params_))

# %%
predicted_y = gs.predict(x_test)
train_pred_y = gs.predict(x)

# %%
print(); print(metrics.classification_report(y,train_pred_y))
print(); print(metrics.confusion_matrix(y, train_pred_y))

print(); print(metrics.classification_report(y_test, predicted_y))
print(); print(metrics.confusion_matrix(y_test, predicted_y))

# %% [markdown]
# <h2>Choosing the best model</h2>

# %%
import math

# %%
scale_pos_weight = math.sqrt(1681/15494)

# %%
scale_pos_weight
# Out:
# 0.32938368270125923

# %%
from sklearn.metrics import f1_score
def evaluate_macroF1_lgb(y_true, y_pred):  
    y_hat = np.where(y_pred < 0.5, 0, 1) 
    f1 = f1_score(y_true, y_hat, average='macro')
    return ('macroF1', f1, True)

# %%
def focal_loss_lgb_eval_error(y_true, y_pred, alpha=.25, gamma=2.):
    a,g = alpha, gamma
    p = 1/(1+np.exp(-y_pred))
    loss = -( a*y_true + (1-a)*(1-y_true) ) * (( 1 - ( y_true*p + (1-y_true)*(1-p)) )**g) * ( y_true*np.log(p)+(1-y_true)*np.log(1-p) )
    return 'focal_loss', np.mean(loss), False

# %%
gkf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
model = lightgbm.LGBMClassifier(boosting_type='gbdt',scale_pos_weight = scale_pos_weight, learning_rate=0.01, max_bins=10, min_data_in_leaf=60, n_estimators=100, num_iterations=1000, num_leaves=63, random_state=1, reg_alpha=0.1, metric=["custom",'binary_logloss'],early_stopping_rounds=250)

# %%
model = lightgbm.LGBMClassifier(class_weight={0:3,1:1}, learning_rate=0.1)

# %%
for training_index, testing_index in gkf.split(X=x, y=y):
    x_train_fold, y_train_fold = x[training_index], y[training_index]
    x_test_fold, y_test_fold = x[testing_index], y[testing_index]
    model.fit(x_train_fold, y_train_fold, eval_set=(x_test_fold,y_test_fold),eval_metric = lambda y_true, y_pred: [evaluate_macroF1_lgb(y_true,y_pred)])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's binary_logloss: 0.315027	valid_0's macroF1: 0.474268
# Training until validation scores don't improve for 250 rounds
# [2]	valid_0's binary_logloss: 0.309945	valid_0's macroF1: 0.474268
# [3]	valid_0's binary_logloss: 0.305411	valid_0's macroF1: 0.474268
# [4]	valid_0's binary_logloss: 0.301144	valid_0's macroF1: 0.474268
# [5]	valid_0's binary_logloss: 0.297285	valid_0's macroF1: 0.474268
# [6]	valid_0's binary_logloss: 0.29356	valid_0's macroF1: 0.474268
# [7]	valid_0's binary_logloss: 0.290109	valid_0's macroF1: 0.474268
# [8]	valid_0's binary_logloss: 0.286888	valid_0's macroF1: 0.474268
# [9]	valid_0's binary_logloss: 0.283737	valid_0's macroF1: 0.474268
# [10]	valid_0's binary_logloss: 0.280807	valid_0's macroF1: 0.474268
# [11]	valid_0's binary_logloss: 0.278013	valid_0's macroF1: 0.474268
# [12]	valid_0's binary_logloss: 0.275339	valid_0's macroF1: 0.474268
# [13]	valid_0's binary_logloss: 0.272753	valid_0's macroF1: 0.474268
# [14]	valid_0's binary_logloss: 0.270256	valid_0's macroF1: 0.474268
# [15]	valid_0's binary_logloss: 0.267889	valid_0's macroF1: 0.474268
# [16]	valid_0's binary_logloss: 0.265616	valid_0's macroF1: 0.474268
# [17]	valid_0's binary_logloss: 0.263472	valid_0's macroF1: 0.474268
# [18]	valid_0's binary_logloss: 0.261365	valid_0's macroF1: 0.474268
# [19]	valid_0's binary_logloss: 0.259352	valid_0's macroF1: 0.474268
# [20]	valid_0's binary_logloss: 0.257386	valid_0's macroF1: 0.474268
# [21]	valid_0's binary_logloss: 0.255482	valid_0's macroF1: 0.474268
# [22]	valid_0's binary_logloss: 0.253602	valid_0's macroF1: 0.474268
# [23]	valid_0's binary_logloss: 0.251783	valid_0's macroF1: 0.474268
# [24]	valid_0's binary_logloss: 0.250064	valid_0's macroF1: 0.474268
# [25]	valid_0's binary_logloss: 0.248439	valid_0's macroF1: 0.474268
# [26]	valid_0's binary_logloss: 0.246879	valid_0's macroF1: 0.474268
# [27]	valid_0's binary_logloss: 0.245271	valid_0's macroF1: 0.474268
# [28]	valid_0's binary_logloss: 0.243749	valid_0's macroF1: 0.474268
# [29]	valid_0's binary_logloss: 0.242248	valid_0's macroF1: 0.474268
# [30]	valid_0's binary_logloss: 0.240827	valid_0's macroF1: 0.474268
# [31]	valid_0's binary_logloss: 0.239335	valid_0's macroF1: 0.474268
# [32]	valid_0's binary_logloss: 0.238024	valid_0's macroF1: 0.474268
# [33]	valid_0's binary_logloss: 0.236676	valid_0's macroF1: 0.474268
# [34]	valid_0's binary_logloss: 0.235401	valid_0's macroF1: 0.474268
# [35]	valid_0's binary_logloss: 0.234172	valid_0's macroF1: 0.474268
# [36]	valid_0's binary_logloss: 0.232918	valid_0's macroF1: 0.474268
# [37]	valid_0's binary_logloss: 0.231699	valid_0's macroF1: 0.474268
# [38]	valid_0's binary_logloss: 0.230528	valid_0's macroF1: 0.474268
# [39]	valid_0's binary_logloss: 0.229343	valid_0's macroF1: 0.474268
# [40]	valid_0's binary_logloss: 0.228211	valid_0's macroF1: 0.474268
# [41]	valid_0's binary_logloss: 0.227084	valid_0's macroF1: 0.474268
# [42]	valid_0's binary_logloss: 0.226022	valid_0's macroF1: 0.474268
# [43]	valid_0's binary_logloss: 0.224958	valid_0's macroF1: 0.474268
# [44]	valid_0's binary_logloss: 0.223947	valid_0's macroF1: 0.474268
# [45]	valid_0's binary_logloss: 0.222942	valid_0's macroF1: 0.474268
# [46]	valid_0's binary_logloss: 0.221979	valid_0's macroF1: 0.474268
# [47]	valid_0's binary_logloss: 0.221004	valid_0's macroF1: 0.474268
# [48]	valid_0's binary_logloss: 0.220074	valid_0's macroF1: 0.474268
# [49]	valid_0's binary_logloss: 0.219215	valid_0's macroF1: 0.474268
# [50]	valid_0's binary_logloss: 0.218328	valid_0's macroF1: 0.474268
# [51]	valid_0's binary_logloss: 0.217477	valid_0's macroF1: 0.474268
# [52]	valid_0's binary_logloss: 0.216665	valid_0's macroF1: 0.474268
# [53]	valid_0's binary_logloss: 0.215855	valid_0's macroF1: 0.474268
# [54]	valid_0's binary_logloss: 0.215074	valid_0's macroF1: 0.474268
# [55]	valid_0's binary_logloss: 0.214284	valid_0's macroF1: 0.474268
# [56]	valid_0's binary_logloss: 0.213493	valid_0's macroF1: 0.474268
# [57]	valid_0's binary_logloss: 0.212795	valid_0's macroF1: 0.474268
# [58]	valid_0's binary_logloss: 0.212036	valid_0's macroF1: 0.474268
# [59]	valid_0's binary_logloss: 0.21134	valid_0's macroF1: 0.592119
# [60]	valid_0's binary_logloss: 0.210578	valid_0's macroF1: 0.65568
# [61]	valid_0's binary_logloss: 0.20995	valid_0's macroF1: 0.657628
# [62]	valid_0's binary_logloss: 0.209255	valid_0's macroF1: 0.65699
# [63]	valid_0's binary_logloss: 0.208627	valid_0's macroF1: 0.67953
# [64]	valid_0's binary_logloss: 0.207934	valid_0's macroF1: 0.686791
# [65]	valid_0's binary_logloss: 0.207338	valid_0's macroF1: 0.689185
# [66]	valid_0's binary_logloss: 0.206701	valid_0's macroF1: 0.704105
# [67]	valid_0's binary_logloss: 0.20609	valid_0's macroF1: 0.713159
# [68]	valid_0's binary_logloss: 0.205476	valid_0's macroF1: 0.715393
# [69]	valid_0's binary_logloss: 0.20489	valid_0's macroF1: 0.732841
# [70]	valid_0's binary_logloss: 0.204325	valid_0's macroF1: 0.746718
# [71]	valid_0's binary_logloss: 0.203772	valid_0's macroF1: 0.750811
# [72]	valid_0's binary_logloss: 0.203235	valid_0's macroF1: 0.767894
# [73]	valid_0's binary_logloss: 0.202686	valid_0's macroF1: 0.768997
# [74]	valid_0's binary_logloss: 0.20213	valid_0's macroF1: 0.768428
# [75]	valid_0's binary_logloss: 0.201609	valid_0's macroF1: 0.77413
# [76]	valid_0's binary_logloss: 0.201096	valid_0's macroF1: 0.776012
# [77]	valid_0's binary_logloss: 0.200568	valid_0's macroF1: 0.776012
# [78]	valid_0's binary_logloss: 0.199977	valid_0's macroF1: 0.77975
# [79]	valid_0's binary_logloss: 0.199485	valid_0's macroF1: 0.785422
# [80]	valid_0's binary_logloss: 0.198966	valid_0's macroF1: 0.785422
# [81]	valid_0's binary_logloss: 0.198491	valid_0's macroF1: 0.790846
# [82]	valid_0's binary_logloss: 0.198038	valid_0's macroF1: 0.795337
# [83]	valid_0's binary_logloss: 0.197575	valid_0's macroF1: 0.798858
# [84]	valid_0's binary_logloss: 0.197117	valid_0's macroF1: 0.799746
# [85]	valid_0's binary_logloss: 0.196668	valid_0's macroF1: 0.803215
# [86]	valid_0's binary_logloss: 0.196236	valid_0's macroF1: 0.806653
# [87]	valid_0's binary_logloss: 0.195717	valid_0's macroF1: 0.807494
# [88]	valid_0's binary_logloss: 0.195214	valid_0's macroF1: 0.812501
# [89]	valid_0's binary_logloss: 0.19482	valid_0's macroF1: 0.815823
# [90]	valid_0's binary_logloss: 0.194359	valid_0's macroF1: 0.81323
# [91]	valid_0's binary_logloss: 0.193904	valid_0's macroF1: 0.817279
# [92]	valid_0's binary_logloss: 0.193467	valid_0's macroF1: 0.817279
# [93]	valid_0's binary_logloss: 0.193028	valid_0's macroF1: 0.818793
# [94]	valid_0's binary_logloss: 0.192648	valid_0's macroF1: 0.820398
# [95]	valid_0's binary_logloss: 0.192218	valid_0's macroF1: 0.820398
# [96]	valid_0's binary_logloss: 0.191859	valid_0's macroF1: 0.820398
# [97]	valid_0's binary_logloss: 0.191482	valid_0's macroF1: 0.821995
# [98]	valid_0's binary_logloss: 0.191101	valid_0's macroF1: 0.823586
# [99]	valid_0's binary_logloss: 0.19075	valid_0's macroF1: 0.821867
# [100]	valid_0's binary_logloss: 0.19039	valid_0's macroF1: 0.821867
# [101]	valid_0's binary_logloss: 0.190015	valid_0's macroF1: 0.821867
# [102]	valid_0's binary_logloss: 0.189696	valid_0's macroF1: 0.822592
# [103]	valid_0's binary_logloss: 0.189323	valid_0's macroF1: 0.82174
# [104]	valid_0's binary_logloss: 0.189025	valid_0's macroF1: 0.822592
# [105]	valid_0's binary_logloss: 0.188636	valid_0's macroF1: 0.823311
# [106]	valid_0's binary_logloss: 0.188319	valid_0's macroF1: 0.823311
# [107]	valid_0's binary_logloss: 0.187959	valid_0's macroF1: 0.827985
# [108]	valid_0's binary_logloss: 0.187616	valid_0's macroF1: 0.827985
# [109]	valid_0's binary_logloss: 0.187256	valid_0's macroF1: 0.82713
# [110]	valid_0's binary_logloss: 0.186932	valid_0's macroF1: 0.82713
# [111]	valid_0's binary_logloss: 0.186601	valid_0's macroF1: 0.825277
# [112]	valid_0's binary_logloss: 0.18628	valid_0's macroF1: 0.825277
# [113]	valid_0's binary_logloss: 0.185956	valid_0's macroF1: 0.826809
# [114]	valid_0's binary_logloss: 0.185623	valid_0's macroF1: 0.826649
# [115]	valid_0's binary_logloss: 0.185312	valid_0's macroF1: 0.825811
# [116]	valid_0's binary_logloss: 0.184971	valid_0's macroF1: 0.825811
# [117]	valid_0's binary_logloss: 0.184639	valid_0's macroF1: 0.828835
# [118]	valid_0's binary_logloss: 0.184327	valid_0's macroF1: 0.828835
# [119]	valid_0's binary_logloss: 0.184016	valid_0's macroF1: 0.828835
# [120]	valid_0's binary_logloss: 0.183714	valid_0's macroF1: 0.827997
# [121]	valid_0's binary_logloss: 0.183437	valid_0's macroF1: 0.828663
# [122]	valid_0's binary_logloss: 0.183115	valid_0's macroF1: 0.82783
# [123]	valid_0's binary_logloss: 0.182835	valid_0's macroF1: 0.827
# [124]	valid_0's binary_logloss: 0.182571	valid_0's macroF1: 0.827663
# [125]	valid_0's binary_logloss: 0.182225	valid_0's macroF1: 0.826173
# [126]	valid_0's binary_logloss: 0.181964	valid_0's macroF1: 0.827663
# [127]	valid_0's binary_logloss: 0.181728	valid_0's macroF1: 0.82832
# [128]	valid_0's binary_logloss: 0.181469	valid_0's macroF1: 0.827497
# [129]	valid_0's binary_logloss: 0.181226	valid_0's macroF1: 0.827497
# [130]	valid_0's binary_logloss: 0.180893	valid_0's macroF1: 0.827497
# [131]	valid_0's binary_logloss: 0.180679	valid_0's macroF1: 0.827497
# [132]	valid_0's binary_logloss: 0.180443	valid_0's macroF1: 0.827497
# [133]	valid_0's binary_logloss: 0.18021	valid_0's macroF1: 0.826676
# [134]	valid_0's binary_logloss: 0.180021	valid_0's macroF1: 0.82815
# [135]	valid_0's binary_logloss: 0.179771	valid_0's macroF1: 0.82815
# [136]	valid_0's binary_logloss: 0.179528	valid_0's macroF1: 0.82815
# [137]	valid_0's binary_logloss: 0.179304	valid_0's macroF1: 0.829618
# [138]	valid_0's binary_logloss: 0.179101	valid_0's macroF1: 0.829618
# [139]	valid_0's binary_logloss: 0.178886	valid_0's macroF1: 0.829618
# [140]	valid_0's binary_logloss: 0.178604	valid_0's macroF1: 0.832537
# [141]	valid_0's binary_logloss: 0.178372	valid_0's macroF1: 0.832537
# [142]	valid_0's binary_logloss: 0.178042	valid_0's macroF1: 0.832537
# [143]	valid_0's binary_logloss: 0.177759	valid_0's macroF1: 0.832537
# [144]	valid_0's binary_logloss: 0.177553	valid_0's macroF1: 0.833988
# [145]	valid_0's binary_logloss: 0.177236	valid_0's macroF1: 0.835434
# [146]	valid_0's binary_logloss: 0.176945	valid_0's macroF1: 0.835434
# [147]	valid_0's binary_logloss: 0.176773	valid_0's macroF1: 0.835434
# [148]	valid_0's binary_logloss: 0.176596	valid_0's macroF1: 0.835434
# [149]	valid_0's binary_logloss: 0.176395	valid_0's macroF1: 0.838309
# [150]	valid_0's binary_logloss: 0.176186	valid_0's macroF1: 0.836047
# [151]	valid_0's binary_logloss: 0.176028	valid_0's macroF1: 0.837481
# [152]	valid_0's binary_logloss: 0.175756	valid_0's macroF1: 0.837481
# [153]	valid_0's binary_logloss: 0.175535	valid_0's macroF1: 0.837481
# [154]	valid_0's binary_logloss: 0.175309	valid_0's macroF1: 0.835223
# [155]	valid_0's binary_logloss: 0.17512	valid_0's macroF1: 0.835223
# [156]	valid_0's binary_logloss: 0.174871	valid_0's macroF1: 0.836047
# [157]	valid_0's binary_logloss: 0.174639	valid_0's macroF1: 0.836655
# [158]	valid_0's binary_logloss: 0.174479	valid_0's macroF1: 0.837481
# [159]	valid_0's binary_logloss: 0.174301	valid_0's macroF1: 0.836655
# [160]	valid_0's binary_logloss: 0.174078	valid_0's macroF1: 0.839503
# [161]	valid_0's binary_logloss: 0.173855	valid_0's macroF1: 0.839503
# [162]	valid_0's binary_logloss: 0.173681	valid_0's macroF1: 0.839503
# [163]	valid_0's binary_logloss: 0.173524	valid_0's macroF1: 0.839503
# [164]	valid_0's binary_logloss: 0.173307	valid_0's macroF1: 0.838678
# [165]	valid_0's binary_logloss: 0.17314	valid_0's macroF1: 0.840093
# [166]	valid_0's binary_logloss: 0.172954	valid_0's macroF1: 0.841502
# [167]	valid_0's binary_logloss: 0.172816	valid_0's macroF1: 0.84233
# [168]	valid_0's binary_logloss: 0.172633	valid_0's macroF1: 0.840678
# [169]	valid_0's binary_logloss: 0.172496	valid_0's macroF1: 0.840678
# [170]	valid_0's binary_logloss: 0.172321	valid_0's macroF1: 0.842081
# [171]	valid_0's binary_logloss: 0.172033	valid_0's macroF1: 0.841258
# [172]	valid_0's binary_logloss: 0.171747	valid_0's macroF1: 0.841258
# [173]	valid_0's binary_logloss: 0.171475	valid_0's macroF1: 0.841258
# [174]	valid_0's binary_logloss: 0.171204	valid_0's macroF1: 0.840439
# [175]	valid_0's binary_logloss: 0.170939	valid_0's macroF1: 0.841258
# [176]	valid_0's binary_logloss: 0.170701	valid_0's macroF1: 0.841258
# [177]	valid_0's binary_logloss: 0.17045	valid_0's macroF1: 0.840439
# [178]	valid_0's binary_logloss: 0.170231	valid_0's macroF1: 0.840439
# [179]	valid_0's binary_logloss: 0.169998	valid_0's macroF1: 0.840439
# [180]	valid_0's binary_logloss: 0.169777	valid_0's macroF1: 0.841834
# [181]	valid_0's binary_logloss: 0.169572	valid_0's macroF1: 0.839622
# [182]	valid_0's binary_logloss: 0.169356	valid_0's macroF1: 0.841016
# [183]	valid_0's binary_logloss: 0.169148	valid_0's macroF1: 0.841016
# [184]	valid_0's binary_logloss: 0.168974	valid_0's macroF1: 0.840201
# [185]	valid_0's binary_logloss: 0.168771	valid_0's macroF1: 0.840201
# [186]	valid_0's binary_logloss: 0.168551	valid_0's macroF1: 0.840201
# [187]	valid_0's binary_logloss: 0.168357	valid_0's macroF1: 0.841588
# [188]	valid_0's binary_logloss: 0.168151	valid_0's macroF1: 0.842405
# [189]	valid_0's binary_logloss: 0.167968	valid_0's macroF1: 0.842971
# [190]	valid_0's binary_logloss: 0.167793	valid_0's macroF1: 0.842971
# [191]	valid_0's binary_logloss: 0.167568	valid_0's macroF1: 0.842971
# [192]	valid_0's binary_logloss: 0.167399	valid_0's macroF1: 0.842971
# [193]	valid_0's binary_logloss: 0.167224	valid_0's macroF1: 0.843533
# [194]	valid_0's binary_logloss: 0.167064	valid_0's macroF1: 0.843533
# [195]	valid_0's binary_logloss: 0.166884	valid_0's macroF1: 0.843533
# [196]	valid_0's binary_logloss: 0.166698	valid_0's macroF1: 0.843533
# [197]	valid_0's binary_logloss: 0.166524	valid_0's macroF1: 0.842156
# [198]	valid_0's binary_logloss: 0.166365	valid_0's macroF1: 0.842156
# [199]	valid_0's binary_logloss: 0.166219	valid_0's macroF1: 0.842156
# [200]	valid_0's binary_logloss: 0.16609	valid_0's macroF1: 0.842156
# [201]	valid_0's binary_logloss: 0.165971	valid_0's macroF1: 0.841344
# [202]	valid_0's binary_logloss: 0.165814	valid_0's macroF1: 0.841344
# [203]	valid_0's binary_logloss: 0.16568	valid_0's macroF1: 0.84272
# [204]	valid_0's binary_logloss: 0.165536	valid_0's macroF1: 0.84272
# [205]	valid_0's binary_logloss: 0.165395	valid_0's macroF1: 0.84272
# [206]	valid_0's binary_logloss: 0.165254	valid_0's macroF1: 0.841102
# [207]	valid_0's binary_logloss: 0.165094	valid_0's macroF1: 0.839729
# [208]	valid_0's binary_logloss: 0.164986	valid_0's macroF1: 0.839729
# [209]	valid_0's binary_logloss: 0.164868	valid_0's macroF1: 0.840297
# [210]	valid_0's binary_logloss: 0.164714	valid_0's macroF1: 0.840297
# [211]	valid_0's binary_logloss: 0.164588	valid_0's macroF1: 0.841664
# [212]	valid_0's binary_logloss: 0.164439	valid_0's macroF1: 0.841664
# [213]	valid_0's binary_logloss: 0.164351	valid_0's macroF1: 0.840297
# [214]	valid_0's binary_logloss: 0.164212	valid_0's macroF1: 0.840297
# [215]	valid_0's binary_logloss: 0.164107	valid_0's macroF1: 0.841664
# [216]	valid_0's binary_logloss: 0.164014	valid_0's macroF1: 0.841664
# [217]	valid_0's binary_logloss: 0.163874	valid_0's macroF1: 0.841664
# [218]	valid_0's binary_logloss: 0.163771	valid_0's macroF1: 0.841664
# [219]	valid_0's binary_logloss: 0.163666	valid_0's macroF1: 0.841664
# [220]	valid_0's binary_logloss: 0.163547	valid_0's macroF1: 0.841664
# [221]	valid_0's binary_logloss: 0.163438	valid_0's macroF1: 0.841664
# [222]	valid_0's binary_logloss: 0.163347	valid_0's macroF1: 0.841664
# [223]	valid_0's binary_logloss: 0.163196	valid_0's macroF1: 0.841664
# [224]	valid_0's binary_logloss: 0.163094	valid_0's macroF1: 0.841664
# [225]	valid_0's binary_logloss: 0.16295	valid_0's macroF1: 0.841664
# [226]	valid_0's binary_logloss: 0.162853	valid_0's macroF1: 0.841664
# [227]	valid_0's binary_logloss: 0.162761	valid_0's macroF1: 0.840861
# [228]	valid_0's binary_logloss: 0.162634	valid_0's macroF1: 0.842222
# [229]	valid_0's binary_logloss: 0.162453	valid_0's macroF1: 0.842222
# [230]	valid_0's binary_logloss: 0.162343	valid_0's macroF1: 0.843026
# [231]	valid_0's binary_logloss: 0.16225	valid_0's macroF1: 0.843026
# [232]	valid_0's binary_logloss: 0.162154	valid_0's macroF1: 0.842222
# [233]	valid_0's binary_logloss: 0.161982	valid_0's macroF1: 0.843578
# [234]	valid_0's binary_logloss: 0.161876	valid_0's macroF1: 0.844383
# [235]	valid_0's binary_logloss: 0.161744	valid_0's macroF1: 0.844383
# [236]	valid_0's binary_logloss: 0.161638	valid_0's macroF1: 0.845191
# [237]	valid_0's binary_logloss: 0.161585	valid_0's macroF1: 0.845191
# [238]	valid_0's binary_logloss: 0.161422	valid_0's macroF1: 0.843578
# [239]	valid_0's binary_logloss: 0.161302	valid_0's macroF1: 0.843578
# [240]	valid_0's binary_logloss: 0.161186	valid_0's macroF1: 0.843578
# [241]	valid_0's binary_logloss: 0.161126	valid_0's macroF1: 0.842775
# [242]	valid_0's binary_logloss: 0.161072	valid_0's macroF1: 0.841975
# [243]	valid_0's binary_logloss: 0.160914	valid_0's macroF1: 0.842775
# [244]	valid_0's binary_logloss: 0.160806	valid_0's macroF1: 0.842775
# [245]	valid_0's binary_logloss: 0.160758	valid_0's macroF1: 0.842775
# [246]	valid_0's binary_logloss: 0.160683	valid_0's macroF1: 0.841975
# [247]	valid_0's binary_logloss: 0.160593	valid_0's macroF1: 0.841975
# [248]	valid_0's binary_logloss: 0.160467	valid_0's macroF1: 0.841975
# [249]	valid_0's binary_logloss: 0.160372	valid_0's macroF1: 0.841178
# [250]	valid_0's binary_logloss: 0.160277	valid_0's macroF1: 0.841178
# [251]	valid_0's binary_logloss: 0.160143	valid_0's macroF1: 0.841178
# [252]	valid_0's binary_logloss: 0.160023	valid_0's macroF1: 0.843324
# [253]	valid_0's binary_logloss: 0.15995	valid_0's macroF1: 0.844125
# [254]	valid_0's binary_logloss: 0.159873	valid_0's macroF1: 0.843324
# [255]	valid_0's binary_logloss: 0.159805	valid_0's macroF1: 0.842525
# [256]	valid_0's binary_logloss: 0.159745	valid_0's macroF1: 0.84173
# [257]	valid_0's binary_logloss: 0.159673	valid_0's macroF1: 0.84173
# [258]	valid_0's binary_logloss: 0.15957	valid_0's macroF1: 0.842525
# [259]	valid_0's binary_logloss: 0.159453	valid_0's macroF1: 0.84173
# [260]	valid_0's binary_logloss: 0.159374	valid_0's macroF1: 0.84173
# [261]	valid_0's binary_logloss: 0.159322	valid_0's macroF1: 0.84173
# [262]	valid_0's binary_logloss: 0.159186	valid_0's macroF1: 0.84173
# [263]	valid_0's binary_logloss: 0.159152	valid_0's macroF1: 0.843324
# [264]	valid_0's binary_logloss: 0.159043	valid_0's macroF1: 0.843324
# [265]	valid_0's binary_logloss: 0.15896	valid_0's macroF1: 0.842525
# [266]	valid_0's binary_logloss: 0.158866	valid_0's macroF1: 0.843324
# [267]	valid_0's binary_logloss: 0.158802	valid_0's macroF1: 0.843324
# [268]	valid_0's binary_logloss: 0.158675	valid_0's macroF1: 0.844125
# [269]	valid_0's binary_logloss: 0.158564	valid_0's macroF1: 0.846811
# [270]	valid_0's binary_logloss: 0.158448	valid_0's macroF1: 0.846811
# [271]	valid_0's binary_logloss: 0.158337	valid_0's macroF1: 0.846811
# [272]	valid_0's binary_logloss: 0.158241	valid_0's macroF1: 0.846811
# [273]	valid_0's binary_logloss: 0.158145	valid_0's macroF1: 0.846811
# [274]	valid_0's binary_logloss: 0.158039	valid_0's macroF1: 0.846811
# [275]	valid_0's binary_logloss: 0.157934	valid_0's macroF1: 0.846811
# [276]	valid_0's binary_logloss: 0.157868	valid_0's macroF1: 0.846007
# [277]	valid_0's binary_logloss: 0.157802	valid_0's macroF1: 0.848672
# [278]	valid_0's binary_logloss: 0.157742	valid_0's macroF1: 0.849477
# [279]	valid_0's binary_logloss: 0.157654	valid_0's macroF1: 0.849477
# [280]	valid_0's binary_logloss: 0.157601	valid_0's macroF1: 0.849477
# [281]	valid_0's binary_logloss: 0.157523	valid_0's macroF1: 0.849477
# [282]	valid_0's binary_logloss: 0.157419	valid_0's macroF1: 0.849477
# [283]	valid_0's binary_logloss: 0.15733	valid_0's macroF1: 0.848672
# [284]	valid_0's binary_logloss: 0.157242	valid_0's macroF1: 0.848672
# [285]	valid_0's binary_logloss: 0.157099	valid_0's macroF1: 0.850803
# [286]	valid_0's binary_logloss: 0.157011	valid_0's macroF1: 0.850803
# [287]	valid_0's binary_logloss: 0.15688	valid_0's macroF1: 0.850803
# [288]	valid_0's binary_logloss: 0.156803	valid_0's macroF1: 0.850803
# [289]	valid_0's binary_logloss: 0.15666	valid_0's macroF1: 0.850803
# [290]	valid_0's binary_logloss: 0.1566	valid_0's macroF1: 0.849997
# [291]	valid_0's binary_logloss: 0.15654	valid_0's macroF1: 0.849997
# [292]	valid_0's binary_logloss: 0.156414	valid_0's macroF1: 0.851317
# [293]	valid_0's binary_logloss: 0.156311	valid_0's macroF1: 0.851317
# [294]	valid_0's binary_logloss: 0.156188	valid_0's macroF1: 0.851317
# [295]	valid_0's binary_logloss: 0.15613	valid_0's macroF1: 0.851317
# [296]	valid_0's binary_logloss: 0.156066	valid_0's macroF1: 0.851317
# [297]	valid_0's binary_logloss: 0.155916	valid_0's macroF1: 0.851317
# [298]	valid_0's binary_logloss: 0.15585	valid_0's macroF1: 0.851317
# [299]	valid_0's binary_logloss: 0.155798	valid_0's macroF1: 0.851317
# [300]	valid_0's binary_logloss: 0.15565	valid_0's macroF1: 0.851317
# [301]	valid_0's binary_logloss: 0.155568	valid_0's macroF1: 0.851317
# [302]	valid_0's binary_logloss: 0.155443	valid_0's macroF1: 0.852633
# [303]	valid_0's binary_logloss: 0.155365	valid_0's macroF1: 0.852633
# [304]	valid_0's binary_logloss: 0.155238	valid_0's macroF1: 0.853441
# [305]	valid_0's binary_logloss: 0.155176	valid_0's macroF1: 0.852633
# [306]	valid_0's binary_logloss: 0.15515	valid_0's macroF1: 0.853441
# [307]	valid_0's binary_logloss: 0.155018	valid_0's macroF1: 0.854252
# [308]	valid_0's binary_logloss: 0.154928	valid_0's macroF1: 0.854252
# [309]	valid_0's binary_logloss: 0.15481	valid_0's macroF1: 0.854252
# [310]	valid_0's binary_logloss: 0.154727	valid_0's macroF1: 0.854252
# [311]	valid_0's binary_logloss: 0.154674	valid_0's macroF1: 0.854252
# [312]	valid_0's binary_logloss: 0.154579	valid_0's macroF1: 0.854252
# [313]	valid_0's binary_logloss: 0.154467	valid_0's macroF1: 0.853441
# [314]	valid_0's binary_logloss: 0.154424	valid_0's macroF1: 0.853441
# [315]	valid_0's binary_logloss: 0.154302	valid_0's macroF1: 0.853441
# [316]	valid_0's binary_logloss: 0.154202	valid_0's macroF1: 0.852633
# [317]	valid_0's binary_logloss: 0.154121	valid_0's macroF1: 0.852633
# [318]	valid_0's binary_logloss: 0.154045	valid_0's macroF1: 0.852633
# [319]	valid_0's binary_logloss: 0.153965	valid_0's macroF1: 0.852633
# [320]	valid_0's binary_logloss: 0.15386	valid_0's macroF1: 0.852633
# [321]	valid_0's binary_logloss: 0.153834	valid_0's macroF1: 0.852633
# [322]	valid_0's binary_logloss: 0.153753	valid_0's macroF1: 0.852633
# [323]	valid_0's binary_logloss: 0.153727	valid_0's macroF1: 0.852633
# [324]	valid_0's binary_logloss: 0.15366	valid_0's macroF1: 0.852633
# [325]	valid_0's binary_logloss: 0.153584	valid_0's macroF1: 0.852633
# [326]	valid_0's binary_logloss: 0.153498	valid_0's macroF1: 0.852633
# [327]	valid_0's binary_logloss: 0.153453	valid_0's macroF1: 0.852633
# [328]	valid_0's binary_logloss: 0.153411	valid_0's macroF1: 0.853441
# [329]	valid_0's binary_logloss: 0.153325	valid_0's macroF1: 0.852633
# [330]	valid_0's binary_logloss: 0.153256	valid_0's macroF1: 0.852633
# [331]	valid_0's binary_logloss: 0.153216	valid_0's macroF1: 0.852633
# [332]	valid_0's binary_logloss: 0.153126	valid_0's macroF1: 0.852633
# [333]	valid_0's binary_logloss: 0.153008	valid_0's macroF1: 0.852633
# [334]	valid_0's binary_logloss: 0.152985	valid_0's macroF1: 0.852633
# [335]	valid_0's binary_logloss: 0.152937	valid_0's macroF1: 0.852633
# [336]	valid_0's binary_logloss: 0.152833	valid_0's macroF1: 0.852633
# [337]	valid_0's binary_logloss: 0.152787	valid_0's macroF1: 0.852633
# [338]	valid_0's binary_logloss: 0.152756	valid_0's macroF1: 0.852633
# [339]	valid_0's binary_logloss: 0.152721	valid_0's macroF1: 0.852633
# [340]	valid_0's binary_logloss: 0.15266	valid_0's macroF1: 0.851827
# [341]	valid_0's binary_logloss: 0.152573	valid_0's macroF1: 0.852633
# [342]	valid_0's binary_logloss: 0.152526	valid_0's macroF1: 0.851827
# [343]	valid_0's binary_logloss: 0.152485	valid_0's macroF1: 0.851827
# [344]	valid_0's binary_logloss: 0.152443	valid_0's macroF1: 0.851827
# [345]	valid_0's binary_logloss: 0.152373	valid_0's macroF1: 0.851827
# [346]	valid_0's binary_logloss: 0.152354	valid_0's macroF1: 0.851827
# [347]	valid_0's binary_logloss: 0.152273	valid_0's macroF1: 0.851827
# [348]	valid_0's binary_logloss: 0.152235	valid_0's macroF1: 0.851827
# [349]	valid_0's binary_logloss: 0.152158	valid_0's macroF1: 0.851827
# [350]	valid_0's binary_logloss: 0.152126	valid_0's macroF1: 0.851827
# [351]	valid_0's binary_logloss: 0.15207	valid_0's macroF1: 0.851827
# [352]	valid_0's binary_logloss: 0.152067	valid_0's macroF1: 0.851827
# [353]	valid_0's binary_logloss: 0.152071	valid_0's macroF1: 0.851827
# [354]	valid_0's binary_logloss: 0.152043	valid_0's macroF1: 0.851827
# [355]	valid_0's binary_logloss: 0.152014	valid_0's macroF1: 0.851827
# [356]	valid_0's binary_logloss: 0.151963	valid_0's macroF1: 0.851024
# [357]	valid_0's binary_logloss: 0.151951	valid_0's macroF1: 0.851024
# [358]	valid_0's binary_logloss: 0.151888	valid_0's macroF1: 0.852633
# [359]	valid_0's binary_logloss: 0.151801	valid_0's macroF1: 0.851827
# [360]	valid_0's binary_logloss: 0.15179	valid_0's macroF1: 0.851827
# [361]	valid_0's binary_logloss: 0.151767	valid_0's macroF1: 0.851827
# [362]	valid_0's binary_logloss: 0.151714	valid_0's macroF1: 0.851827
# [363]	valid_0's binary_logloss: 0.151714	valid_0's macroF1: 0.851827
# [364]	valid_0's binary_logloss: 0.151662	valid_0's macroF1: 0.851827
# [365]	valid_0's binary_logloss: 0.151656	valid_0's macroF1: 0.851827
# [366]	valid_0's binary_logloss: 0.151654	valid_0's macroF1: 0.851827
# [367]	valid_0's binary_logloss: 0.151631	valid_0's macroF1: 0.850512
# [368]	valid_0's binary_logloss: 0.15156	valid_0's macroF1: 0.84971
# [369]	valid_0's binary_logloss: 0.151552	valid_0's macroF1: 0.84971
# [370]	valid_0's binary_logloss: 0.151487	valid_0's macroF1: 0.850512
# [371]	valid_0's binary_logloss: 0.151473	valid_0's macroF1: 0.850512
# [372]	valid_0's binary_logloss: 0.151436	valid_0's macroF1: 0.850512
# [373]	valid_0's binary_logloss: 0.151358	valid_0's macroF1: 0.850512
# [374]	valid_0's binary_logloss: 0.151343	valid_0's macroF1: 0.850512
# [375]	valid_0's binary_logloss: 0.151292	valid_0's macroF1: 0.850512
# [376]	valid_0's binary_logloss: 0.151245	valid_0's macroF1: 0.849193
# [377]	valid_0's binary_logloss: 0.151226	valid_0's macroF1: 0.849193
# [378]	valid_0's binary_logloss: 0.151216	valid_0's macroF1: 0.850512
# [379]	valid_0's binary_logloss: 0.151205	valid_0's macroF1: 0.849193
# [380]	valid_0's binary_logloss: 0.151171	valid_0's macroF1: 0.849193
# [381]	valid_0's binary_logloss: 0.151121	valid_0's macroF1: 0.849193
# [382]	valid_0's binary_logloss: 0.151076	valid_0's macroF1: 0.849193
# [383]	valid_0's binary_logloss: 0.151019	valid_0's macroF1: 0.848392
# [384]	valid_0's binary_logloss: 0.151035	valid_0's macroF1: 0.848392
# [385]	valid_0's binary_logloss: 0.150991	valid_0's macroF1: 0.848392
# [386]	valid_0's binary_logloss: 0.150926	valid_0's macroF1: 0.848392
# [387]	valid_0's binary_logloss: 0.150908	valid_0's macroF1: 0.84971
# [388]	valid_0's binary_logloss: 0.150851	valid_0's macroF1: 0.850512
# [389]	valid_0's binary_logloss: 0.150829	valid_0's macroF1: 0.850512
# [390]	valid_0's binary_logloss: 0.150794	valid_0's macroF1: 0.850512
# [391]	valid_0's binary_logloss: 0.150717	valid_0's macroF1: 0.850512
# [392]	valid_0's binary_logloss: 0.150697	valid_0's macroF1: 0.850512
# [393]	valid_0's binary_logloss: 0.150683	valid_0's macroF1: 0.850512
# [394]	valid_0's binary_logloss: 0.150644	valid_0's macroF1: 0.850512
# [395]	valid_0's binary_logloss: 0.15063	valid_0's macroF1: 0.850512
# [396]	valid_0's binary_logloss: 0.150623	valid_0's macroF1: 0.850512
# [397]	valid_0's binary_logloss: 0.150611	valid_0's macroF1: 0.850512
# [398]	valid_0's binary_logloss: 0.150559	valid_0's macroF1: 0.850512
# [399]	valid_0's binary_logloss: 0.150532	valid_0's macroF1: 0.850512
# [400]	valid_0's binary_logloss: 0.150464	valid_0's macroF1: 0.850512
# [401]	valid_0's binary_logloss: 0.150452	valid_0's macroF1: 0.850512
# [402]	valid_0's binary_logloss: 0.150435	valid_0's macroF1: 0.850512
# [403]	valid_0's binary_logloss: 0.150397	valid_0's macroF1: 0.850512
# [404]	valid_0's binary_logloss: 0.150331	valid_0's macroF1: 0.850512
# [405]	valid_0's binary_logloss: 0.150327	valid_0's macroF1: 0.850512
# [406]	valid_0's binary_logloss: 0.150319	valid_0's macroF1: 0.84971
# [407]	valid_0's binary_logloss: 0.150304	valid_0's macroF1: 0.850512
# [408]	valid_0's binary_logloss: 0.150289	valid_0's macroF1: 0.84971
# [409]	valid_0's binary_logloss: 0.150267	valid_0's macroF1: 0.84971
# [410]	valid_0's binary_logloss: 0.150253	valid_0's macroF1: 0.84971
# [411]	valid_0's binary_logloss: 0.150185	valid_0's macroF1: 0.84971
# [412]	valid_0's binary_logloss: 0.150155	valid_0's macroF1: 0.84971
# [413]	valid_0's binary_logloss: 0.15012	valid_0's macroF1: 0.84971
# [414]	valid_0's binary_logloss: 0.150104	valid_0's macroF1: 0.84971
# [415]	valid_0's binary_logloss: 0.150065	valid_0's macroF1: 0.84971
# [416]	valid_0's binary_logloss: 0.15007	valid_0's macroF1: 0.84971
# [417]	valid_0's binary_logloss: 0.150052	valid_0's macroF1: 0.850512
# [418]	valid_0's binary_logloss: 0.150025	valid_0's macroF1: 0.850512
# [419]	valid_0's binary_logloss: 0.15	valid_0's macroF1: 0.850512
# [420]	valid_0's binary_logloss: 0.149976	valid_0's macroF1: 0.850512
# [421]	valid_0's binary_logloss: 0.149959	valid_0's macroF1: 0.850512
# [422]	valid_0's binary_logloss: 0.149904	valid_0's macroF1: 0.851317
# [423]	valid_0's binary_logloss: 0.149898	valid_0's macroF1: 0.851317
# [424]	valid_0's binary_logloss: 0.149861	valid_0's macroF1: 0.852124
# [425]	valid_0's binary_logloss: 0.149862	valid_0's macroF1: 0.853441
# [426]	valid_0's binary_logloss: 0.14988	valid_0's macroF1: 0.852633
# [427]	valid_0's binary_logloss: 0.149853	valid_0's macroF1: 0.851827
# [428]	valid_0's binary_logloss: 0.149845	valid_0's macroF1: 0.851827
# [429]	valid_0's binary_logloss: 0.149864	valid_0's macroF1: 0.851827
# [430]	valid_0's binary_logloss: 0.14981	valid_0's macroF1: 0.851827
# [431]	valid_0's binary_logloss: 0.149784	valid_0's macroF1: 0.851827
# [432]	valid_0's binary_logloss: 0.149776	valid_0's macroF1: 0.851827
# [433]	valid_0's binary_logloss: 0.149747	valid_0's macroF1: 0.851827
# [434]	valid_0's binary_logloss: 0.149779	valid_0's macroF1: 0.851827
# [435]	valid_0's binary_logloss: 0.149746	valid_0's macroF1: 0.851827
# [436]	valid_0's binary_logloss: 0.149718	valid_0's macroF1: 0.851827
# [437]	valid_0's binary_logloss: 0.149648	valid_0's macroF1: 0.852633
# [438]	valid_0's binary_logloss: 0.149614	valid_0's macroF1: 0.852633
# [439]	valid_0's binary_logloss: 0.149638	valid_0's macroF1: 0.852633
# [440]	valid_0's binary_logloss: 0.149584	valid_0's macroF1: 0.852633
# [441]	valid_0's binary_logloss: 0.149554	valid_0's macroF1: 0.852633
# [442]	valid_0's binary_logloss: 0.14952	valid_0's macroF1: 0.852633
# [443]	valid_0's binary_logloss: 0.149491	valid_0's macroF1: 0.852633
# [444]	valid_0's binary_logloss: 0.149466	valid_0's macroF1: 0.852633
# [445]	valid_0's binary_logloss: 0.149428	valid_0's macroF1: 0.852633
# [446]	valid_0's binary_logloss: 0.149453	valid_0's macroF1: 0.852633
# [447]	valid_0's binary_logloss: 0.149407	valid_0's macroF1: 0.853944
# [448]	valid_0's binary_logloss: 0.149419	valid_0's macroF1: 0.852633
# [449]	valid_0's binary_logloss: 0.149386	valid_0's macroF1: 0.853944
# [450]	valid_0's binary_logloss: 0.149362	valid_0's macroF1: 0.852633
# [451]	valid_0's binary_logloss: 0.149345	valid_0's macroF1: 0.853944
# [452]	valid_0's binary_logloss: 0.149327	valid_0's macroF1: 0.853944
# [453]	valid_0's binary_logloss: 0.149327	valid_0's macroF1: 0.853944
# [454]	valid_0's binary_logloss: 0.149301	valid_0's macroF1: 0.853944
# [455]	valid_0's binary_logloss: 0.149272	valid_0's macroF1: 0.853137
# [456]	valid_0's binary_logloss: 0.149229	valid_0's macroF1: 0.853137
# [457]	valid_0's binary_logloss: 0.149199	valid_0's macroF1: 0.853137
# [458]	valid_0's binary_logloss: 0.1492	valid_0's macroF1: 0.853137
# [459]	valid_0's binary_logloss: 0.149193	valid_0's macroF1: 0.853137
# [460]	valid_0's binary_logloss: 0.149161	valid_0's macroF1: 0.853137
# [461]	valid_0's binary_logloss: 0.149149	valid_0's macroF1: 0.853137
# [462]	valid_0's binary_logloss: 0.149101	valid_0's macroF1: 0.853944
# [463]	valid_0's binary_logloss: 0.149091	valid_0's macroF1: 0.853137
# [464]	valid_0's binary_logloss: 0.149042	valid_0's macroF1: 0.853137
# [465]	valid_0's binary_logloss: 0.149027	valid_0's macroF1: 0.853137
# [466]	valid_0's binary_logloss: 0.148957	valid_0's macroF1: 0.853944
# [467]	valid_0's binary_logloss: 0.148912	valid_0's macroF1: 0.853944
# [468]	valid_0's binary_logloss: 0.148923	valid_0's macroF1: 0.853944
# [469]	valid_0's binary_logloss: 0.148912	valid_0's macroF1: 0.853944
# [470]	valid_0's binary_logloss: 0.148904	valid_0's macroF1: 0.853944
# [471]	valid_0's binary_logloss: 0.148837	valid_0's macroF1: 0.853944
# [472]	valid_0's binary_logloss: 0.148841	valid_0's macroF1: 0.853137
# [473]	valid_0's binary_logloss: 0.148832	valid_0's macroF1: 0.853137
# [474]	valid_0's binary_logloss: 0.148781	valid_0's macroF1: 0.853137
# [475]	valid_0's binary_logloss: 0.148766	valid_0's macroF1: 0.853944
# [476]	valid_0's binary_logloss: 0.148772	valid_0's macroF1: 0.853137
# [477]	valid_0's binary_logloss: 0.148773	valid_0's macroF1: 0.853137
# [478]	valid_0's binary_logloss: 0.148747	valid_0's macroF1: 0.853137
# [479]	valid_0's binary_logloss: 0.148713	valid_0's macroF1: 0.853137
# [480]	valid_0's binary_logloss: 0.148678	valid_0's macroF1: 0.853137
# [481]	valid_0's binary_logloss: 0.148662	valid_0's macroF1: 0.853137
# [482]	valid_0's binary_logloss: 0.148648	valid_0's macroF1: 0.853137
# [483]	valid_0's binary_logloss: 0.148601	valid_0's macroF1: 0.853137
# [484]	valid_0's binary_logloss: 0.148592	valid_0's macroF1: 0.853137
# [485]	valid_0's binary_logloss: 0.148557	valid_0's macroF1: 0.853137
# [486]	valid_0's binary_logloss: 0.148539	valid_0's macroF1: 0.853137
# [487]	valid_0's binary_logloss: 0.148496	valid_0's macroF1: 0.853137
# [488]	valid_0's binary_logloss: 0.148465	valid_0's macroF1: 0.853137
# [489]	valid_0's binary_logloss: 0.148437	valid_0's macroF1: 0.853137
# [490]	valid_0's binary_logloss: 0.148412	valid_0's macroF1: 0.853137
# [491]	valid_0's binary_logloss: 0.148387	valid_0's macroF1: 0.853137
# [492]	valid_0's binary_logloss: 0.148388	valid_0's macroF1: 0.853137
# [493]	valid_0's binary_logloss: 0.148385	valid_0's macroF1: 0.853137
# [494]	valid_0's binary_logloss: 0.148389	valid_0's macroF1: 0.853137
# [495]	valid_0's binary_logloss: 0.148394	valid_0's macroF1: 0.853137
# [496]	valid_0's binary_logloss: 0.148388	valid_0's macroF1: 0.853137
# [497]	valid_0's binary_logloss: 0.148392	valid_0's macroF1: 0.853137
# [498]	valid_0's binary_logloss: 0.14835	valid_0's macroF1: 0.853137
# [499]	valid_0's binary_logloss: 0.14833	valid_0's macroF1: 0.853137
# [500]	valid_0's binary_logloss: 0.148323	valid_0's macroF1: 0.853137
# [501]	valid_0's binary_logloss: 0.148335	valid_0's macroF1: 0.853137
# [502]	valid_0's binary_logloss: 0.148308	valid_0's macroF1: 0.853137
# [503]	valid_0's binary_logloss: 0.148294	valid_0's macroF1: 0.854443
# [504]	valid_0's binary_logloss: 0.148303	valid_0's macroF1: 0.854443
# [505]	valid_0's binary_logloss: 0.148271	valid_0's macroF1: 0.854443
# [506]	valid_0's binary_logloss: 0.148226	valid_0's macroF1: 0.854443
# [507]	valid_0's binary_logloss: 0.148266	valid_0's macroF1: 0.853137
# [508]	valid_0's binary_logloss: 0.148255	valid_0's macroF1: 0.854443
# [509]	valid_0's binary_logloss: 0.148239	valid_0's macroF1: 0.854443
# [510]	valid_0's binary_logloss: 0.148251	valid_0's macroF1: 0.854443
# [511]	valid_0's binary_logloss: 0.14821	valid_0's macroF1: 0.854443
# [512]	valid_0's binary_logloss: 0.148192	valid_0's macroF1: 0.854443
# [513]	valid_0's binary_logloss: 0.148164	valid_0's macroF1: 0.854443
# [514]	valid_0's binary_logloss: 0.148144	valid_0's macroF1: 0.854443
# [515]	valid_0's binary_logloss: 0.148165	valid_0's macroF1: 0.854443
# [516]	valid_0's binary_logloss: 0.148147	valid_0's macroF1: 0.854443
# [517]	valid_0's binary_logloss: 0.148165	valid_0's macroF1: 0.853137
# [518]	valid_0's binary_logloss: 0.148162	valid_0's macroF1: 0.854443
# [519]	valid_0's binary_logloss: 0.148111	valid_0's macroF1: 0.854443
# [520]	valid_0's binary_logloss: 0.148102	valid_0's macroF1: 0.854443
# [521]	valid_0's binary_logloss: 0.148084	valid_0's macroF1: 0.854443
# [522]	valid_0's binary_logloss: 0.148068	valid_0's macroF1: 0.854443
# [523]	valid_0's binary_logloss: 0.148025	valid_0's macroF1: 0.854443
# [524]	valid_0's binary_logloss: 0.148029	valid_0's macroF1: 0.854443
# [525]	valid_0's binary_logloss: 0.148025	valid_0's macroF1: 0.854443
# [526]	valid_0's binary_logloss: 0.148027	valid_0's macroF1: 0.854443
# [527]	valid_0's binary_logloss: 0.148002	valid_0's macroF1: 0.854443
# [528]	valid_0's binary_logloss: 0.148014	valid_0's macroF1: 0.854443
# [529]	valid_0's binary_logloss: 0.14801	valid_0's macroF1: 0.853137
# [530]	valid_0's binary_logloss: 0.148006	valid_0's macroF1: 0.853137
# [531]	valid_0's binary_logloss: 0.147999	valid_0's macroF1: 0.851827
# [532]	valid_0's binary_logloss: 0.147991	valid_0's macroF1: 0.851827
# [533]	valid_0's binary_logloss: 0.148017	valid_0's macroF1: 0.851827
# [534]	valid_0's binary_logloss: 0.148017	valid_0's macroF1: 0.851827
# [535]	valid_0's binary_logloss: 0.14803	valid_0's macroF1: 0.851827
# [536]	valid_0's binary_logloss: 0.148027	valid_0's macroF1: 0.851827
# [537]	valid_0's binary_logloss: 0.148008	valid_0's macroF1: 0.852633
# [538]	valid_0's binary_logloss: 0.148001	valid_0's macroF1: 0.851827
# [539]	valid_0's binary_logloss: 0.147985	valid_0's macroF1: 0.851827
# [540]	valid_0's binary_logloss: 0.147979	valid_0's macroF1: 0.851827
# [541]	valid_0's binary_logloss: 0.147962	valid_0's macroF1: 0.850512
# [542]	valid_0's binary_logloss: 0.147972	valid_0's macroF1: 0.850512
# [543]	valid_0's binary_logloss: 0.147975	valid_0's macroF1: 0.850512
# [544]	valid_0's binary_logloss: 0.147958	valid_0's macroF1: 0.849193
# [545]	valid_0's binary_logloss: 0.147969	valid_0's macroF1: 0.850512
# [546]	valid_0's binary_logloss: 0.147956	valid_0's macroF1: 0.849193
# [547]	valid_0's binary_logloss: 0.147952	valid_0's macroF1: 0.849193
# [548]	valid_0's binary_logloss: 0.147968	valid_0's macroF1: 0.849193
# [549]	valid_0's binary_logloss: 0.147964	valid_0's macroF1: 0.849193
# [550]	valid_0's binary_logloss: 0.147955	valid_0's macroF1: 0.849193
# [551]	valid_0's binary_logloss: 0.147929	valid_0's macroF1: 0.849193
# [552]	valid_0's binary_logloss: 0.147927	valid_0's macroF1: 0.849193
# [553]	valid_0's binary_logloss: 0.147926	valid_0's macroF1: 0.849193
# [554]	valid_0's binary_logloss: 0.147882	valid_0's macroF1: 0.849997
# [555]	valid_0's binary_logloss: 0.147868	valid_0's macroF1: 0.849997
# [556]	valid_0's binary_logloss: 0.147876	valid_0's macroF1: 0.849997
# [557]	valid_0's binary_logloss: 0.147878	valid_0's macroF1: 0.849997
# [558]	valid_0's binary_logloss: 0.147877	valid_0's macroF1: 0.849997
# [559]	valid_0's binary_logloss: 0.147877	valid_0's macroF1: 0.849997
# [560]	valid_0's binary_logloss: 0.147872	valid_0's macroF1: 0.849997
# [561]	valid_0's binary_logloss: 0.147904	valid_0's macroF1: 0.849997
# [562]	valid_0's binary_logloss: 0.147908	valid_0's macroF1: 0.849997
# [563]	valid_0's binary_logloss: 0.147897	valid_0's macroF1: 0.849997
# [564]	valid_0's binary_logloss: 0.147905	valid_0's macroF1: 0.849997
# [565]	valid_0's binary_logloss: 0.147894	valid_0's macroF1: 0.849997
# [566]	valid_0's binary_logloss: 0.147878	valid_0's macroF1: 0.849997
# [567]	valid_0's binary_logloss: 0.147868	valid_0's macroF1: 0.849193
# [568]	valid_0's binary_logloss: 0.147864	valid_0's macroF1: 0.849997
# [569]	valid_0's binary_logloss: 0.147895	valid_0's macroF1: 0.849193
# [570]	valid_0's binary_logloss: 0.147867	valid_0's macroF1: 0.849193
# [571]	valid_0's binary_logloss: 0.147861	valid_0's macroF1: 0.849193
# [572]	valid_0's binary_logloss: 0.147836	valid_0's macroF1: 0.849193
# [573]	valid_0's binary_logloss: 0.147827	valid_0's macroF1: 0.849193
# [574]	valid_0's binary_logloss: 0.147817	valid_0's macroF1: 0.849997
# [575]	valid_0's binary_logloss: 0.147836	valid_0's macroF1: 0.849193
# [576]	valid_0's binary_logloss: 0.147831	valid_0's macroF1: 0.849997
# [577]	valid_0's binary_logloss: 0.147831	valid_0's macroF1: 0.849997
# [578]	valid_0's binary_logloss: 0.147816	valid_0's macroF1: 0.849997
# [579]	valid_0's binary_logloss: 0.147841	valid_0's macroF1: 0.850803
# [580]	valid_0's binary_logloss: 0.147835	valid_0's macroF1: 0.849997
# [581]	valid_0's binary_logloss: 0.147823	valid_0's macroF1: 0.850803
# [582]	valid_0's binary_logloss: 0.14782	valid_0's macroF1: 0.850803
# [583]	valid_0's binary_logloss: 0.147813	valid_0's macroF1: 0.850803
# [584]	valid_0's binary_logloss: 0.147841	valid_0's macroF1: 0.850803
# [585]	valid_0's binary_logloss: 0.147801	valid_0's macroF1: 0.850803
# [586]	valid_0's binary_logloss: 0.147812	valid_0's macroF1: 0.850803
# [587]	valid_0's binary_logloss: 0.147794	valid_0's macroF1: 0.850803
# [588]	valid_0's binary_logloss: 0.147755	valid_0's macroF1: 0.850803
# [589]	valid_0's binary_logloss: 0.147739	valid_0's macroF1: 0.852124
# [590]	valid_0's binary_logloss: 0.147739	valid_0's macroF1: 0.852124
# [591]	valid_0's binary_logloss: 0.147745	valid_0's macroF1: 0.852124
# [592]	valid_0's binary_logloss: 0.147751	valid_0's macroF1: 0.852124
# [593]	valid_0's binary_logloss: 0.147756	valid_0's macroF1: 0.852124
# [594]	valid_0's binary_logloss: 0.147745	valid_0's macroF1: 0.852124
# [595]	valid_0's binary_logloss: 0.147764	valid_0's macroF1: 0.852124
# [596]	valid_0's binary_logloss: 0.147811	valid_0's macroF1: 0.852124
# [597]	valid_0's binary_logloss: 0.147795	valid_0's macroF1: 0.852124
# [598]	valid_0's binary_logloss: 0.147809	valid_0's macroF1: 0.852934
# [599]	valid_0's binary_logloss: 0.147818	valid_0's macroF1: 0.852124
# [600]	valid_0's binary_logloss: 0.147831	valid_0's macroF1: 0.852934
# [601]	valid_0's binary_logloss: 0.147826	valid_0's macroF1: 0.852934
# [602]	valid_0's binary_logloss: 0.147813	valid_0's macroF1: 0.852934
# [603]	valid_0's binary_logloss: 0.147826	valid_0's macroF1: 0.852934
# [604]	valid_0's binary_logloss: 0.147825	valid_0's macroF1: 0.852124
# [605]	valid_0's binary_logloss: 0.147819	valid_0's macroF1: 0.852934
# [606]	valid_0's binary_logloss: 0.147833	valid_0's macroF1: 0.850803
# [607]	valid_0's binary_logloss: 0.147844	valid_0's macroF1: 0.852124
# [608]	valid_0's binary_logloss: 0.147878	valid_0's macroF1: 0.852124
# [609]	valid_0's binary_logloss: 0.14789	valid_0's macroF1: 0.850803
# [610]	valid_0's binary_logloss: 0.147886	valid_0's macroF1: 0.852124
# [611]	valid_0's binary_logloss: 0.147871	valid_0's macroF1: 0.852934
# [612]	valid_0's binary_logloss: 0.147881	valid_0's macroF1: 0.852124
# [613]	valid_0's binary_logloss: 0.147867	valid_0's macroF1: 0.851612
# [614]	valid_0's binary_logloss: 0.147853	valid_0's macroF1: 0.851612
# [615]	valid_0's binary_logloss: 0.147853	valid_0's macroF1: 0.850285
# [616]	valid_0's binary_logloss: 0.147836	valid_0's macroF1: 0.850285
# [617]	valid_0's binary_logloss: 0.147801	valid_0's macroF1: 0.850285
# [618]	valid_0's binary_logloss: 0.147793	valid_0's macroF1: 0.850285
# [619]	valid_0's binary_logloss: 0.147815	valid_0's macroF1: 0.850285
# [620]	valid_0's binary_logloss: 0.147832	valid_0's macroF1: 0.850285
# [621]	valid_0's binary_logloss: 0.147832	valid_0's macroF1: 0.851096
# [622]	valid_0's binary_logloss: 0.147834	valid_0's macroF1: 0.851096
# [623]	valid_0's binary_logloss: 0.147856	valid_0's macroF1: 0.851909
# [624]	valid_0's binary_logloss: 0.147847	valid_0's macroF1: 0.851096
# [625]	valid_0's binary_logloss: 0.147842	valid_0's macroF1: 0.851096
# [626]	valid_0's binary_logloss: 0.14784	valid_0's macroF1: 0.850285
# [627]	valid_0's binary_logloss: 0.147885	valid_0's macroF1: 0.850285
# [628]	valid_0's binary_logloss: 0.147901	valid_0's macroF1: 0.851096
# [629]	valid_0's binary_logloss: 0.147888	valid_0's macroF1: 0.851096
# [630]	valid_0's binary_logloss: 0.147876	valid_0's macroF1: 0.850285
# [631]	valid_0's binary_logloss: 0.147893	valid_0's macroF1: 0.850285
# [632]	valid_0's binary_logloss: 0.147894	valid_0's macroF1: 0.850285
# [633]	valid_0's binary_logloss: 0.14789	valid_0's macroF1: 0.850285
# [634]	valid_0's binary_logloss: 0.147957	valid_0's macroF1: 0.850285
# [635]	valid_0's binary_logloss: 0.147957	valid_0's macroF1: 0.851096
# [636]	valid_0's binary_logloss: 0.147925	valid_0's macroF1: 0.850285
# [637]	valid_0's binary_logloss: 0.147956	valid_0's macroF1: 0.851096
# [638]	valid_0's binary_logloss: 0.147955	valid_0's macroF1: 0.851096
# [639]	valid_0's binary_logloss: 0.147954	valid_0's macroF1: 0.848953
# [640]	valid_0's binary_logloss: 0.14796	valid_0's macroF1: 0.848953
# [641]	valid_0's binary_logloss: 0.147962	valid_0's macroF1: 0.848953
# [642]	valid_0's binary_logloss: 0.14797	valid_0's macroF1: 0.848953
# [643]	valid_0's binary_logloss: 0.147965	valid_0's macroF1: 0.848146
# [644]	valid_0's binary_logloss: 0.147968	valid_0's macroF1: 0.848953
# [645]	valid_0's binary_logloss: 0.147924	valid_0's macroF1: 0.848146
# [646]	valid_0's binary_logloss: 0.147924	valid_0's macroF1: 0.848953
# [647]	valid_0's binary_logloss: 0.147905	valid_0's macroF1: 0.848953
# [648]	valid_0's binary_logloss: 0.147914	valid_0's macroF1: 0.849763
# [649]	valid_0's binary_logloss: 0.147914	valid_0's macroF1: 0.849763
# [650]	valid_0's binary_logloss: 0.147924	valid_0's macroF1: 0.849763
# [651]	valid_0's binary_logloss: 0.147939	valid_0's macroF1: 0.850575
# [652]	valid_0's binary_logloss: 0.147939	valid_0's macroF1: 0.850575
# [653]	valid_0's binary_logloss: 0.147934	valid_0's macroF1: 0.850575
# [654]	valid_0's binary_logloss: 0.147931	valid_0's macroF1: 0.850575
# [655]	valid_0's binary_logloss: 0.147923	valid_0's macroF1: 0.85139
# [656]	valid_0's binary_logloss: 0.147936	valid_0's macroF1: 0.85139
# [657]	valid_0's binary_logloss: 0.147951	valid_0's macroF1: 0.85139
# [658]	valid_0's binary_logloss: 0.147953	valid_0's macroF1: 0.85139
# [659]	valid_0's binary_logloss: 0.147944	valid_0's macroF1: 0.85139
# [660]	valid_0's binary_logloss: 0.14794	valid_0's macroF1: 0.85139
# [661]	valid_0's binary_logloss: 0.147919	valid_0's macroF1: 0.85005
# [662]	valid_0's binary_logloss: 0.147964	valid_0's macroF1: 0.85139
# [663]	valid_0's binary_logloss: 0.147987	valid_0's macroF1: 0.85139
# [664]	valid_0's binary_logloss: 0.147989	valid_0's macroF1: 0.85139
# [665]	valid_0's binary_logloss: 0.147951	valid_0's macroF1: 0.85139
# [666]	valid_0's binary_logloss: 0.147942	valid_0's macroF1: 0.85139
# [667]	valid_0's binary_logloss: 0.147914	valid_0's macroF1: 0.85139
# [668]	valid_0's binary_logloss: 0.147921	valid_0's macroF1: 0.85139
# [669]	valid_0's binary_logloss: 0.147929	valid_0's macroF1: 0.85139
# [670]	valid_0's binary_logloss: 0.147938	valid_0's macroF1: 0.85139
# [671]	valid_0's binary_logloss: 0.147968	valid_0's macroF1: 0.85005
# [672]	valid_0's binary_logloss: 0.147993	valid_0's macroF1: 0.85139
# [673]	valid_0's binary_logloss: 0.14801	valid_0's macroF1: 0.85139
# [674]	valid_0's binary_logloss: 0.147988	valid_0's macroF1: 0.85005
# [675]	valid_0's binary_logloss: 0.147989	valid_0's macroF1: 0.85139
# [676]	valid_0's binary_logloss: 0.148011	valid_0's macroF1: 0.85139
# [677]	valid_0's binary_logloss: 0.148041	valid_0's macroF1: 0.85139
# [678]	valid_0's binary_logloss: 0.148065	valid_0's macroF1: 0.85139
# [679]	valid_0's binary_logloss: 0.14811	valid_0's macroF1: 0.85139
# [680]	valid_0's binary_logloss: 0.148076	valid_0's macroF1: 0.85005
# [681]	valid_0's binary_logloss: 0.148047	valid_0's macroF1: 0.85005
# [682]	valid_0's binary_logloss: 0.148071	valid_0's macroF1: 0.850867
# [683]	valid_0's binary_logloss: 0.148099	valid_0's macroF1: 0.85005
# ...
# [526]	valid_0's binary_logloss: 0.149915	valid_0's macroF1: 0.860195
# [527]	valid_0's binary_logloss: 0.149882	valid_0's macroF1: 0.859354
# [528]	valid_0's binary_logloss: 0.149829	valid_0's macroF1: 0.859354
# [529]	valid_0's binary_logloss: 0.149765	valid_0's macroF1: 0.859354
# [530]	valid_0's binary_logloss: 0.149727	valid_0's macroF1: 0.859354
# [531]	valid_0's binary_logloss: 0.149718	valid_0's macroF1: 0.858011
# [532]	valid_0's binary_logloss: 0.149686	valid_0's macroF1: 0.858011
# [533]	valid_0's binary_logloss: 0.149702	valid_0's macroF1: 0.858011
# [534]	valid_0's binary_logloss: 0.14965	valid_0's macroF1: 0.856663
# [535]	valid_0's binary_logloss: 0.149605	valid_0's macroF1: 0.856663
# [536]	valid_0's binary_logloss: 0.149574	valid_0's macroF1: 0.856663
# [537]	valid_0's binary_logloss: 0.149553	valid_0's macroF1: 0.856663
# [538]	valid_0's binary_logloss: 0.149509	valid_0's macroF1: 0.856663
# [539]	valid_0's binary_logloss: 0.149498	valid_0's macroF1: 0.856663
# [540]	valid_0's binary_logloss: 0.149504	valid_0's macroF1: 0.856663
# [541]	valid_0's binary_logloss: 0.149483	valid_0's macroF1: 0.856663
# [542]	valid_0's binary_logloss: 0.149441	valid_0's macroF1: 0.856663
# [543]	valid_0's binary_logloss: 0.149418	valid_0's macroF1: 0.856663
# [544]	valid_0's binary_logloss: 0.149418	valid_0's macroF1: 0.856663
# [545]	valid_0's binary_logloss: 0.149367	valid_0's macroF1: 0.856663
# [546]	valid_0's binary_logloss: 0.14934	valid_0's macroF1: 0.856663
# [547]	valid_0's binary_logloss: 0.149347	valid_0's macroF1: 0.856663
# [548]	valid_0's binary_logloss: 0.14936	valid_0's macroF1: 0.856663
# [549]	valid_0's binary_logloss: 0.149317	valid_0's macroF1: 0.85531
# [550]	valid_0's binary_logloss: 0.149304	valid_0's macroF1: 0.85531
# [551]	valid_0's binary_logloss: 0.149303	valid_0's macroF1: 0.85531
# [552]	valid_0's binary_logloss: 0.149272	valid_0's macroF1: 0.85531
# [553]	valid_0's binary_logloss: 0.149297	valid_0's macroF1: 0.856148
# [554]	valid_0's binary_logloss: 0.14927	valid_0's macroF1: 0.856148
# [555]	valid_0's binary_logloss: 0.149261	valid_0's macroF1: 0.857502
# [556]	valid_0's binary_logloss: 0.149259	valid_0's macroF1: 0.856663
# [557]	valid_0's binary_logloss: 0.149259	valid_0's macroF1: 0.856663
# [558]	valid_0's binary_logloss: 0.14923	valid_0's macroF1: 0.85531
# [559]	valid_0's binary_logloss: 0.149188	valid_0's macroF1: 0.856148
# [560]	valid_0's binary_logloss: 0.149187	valid_0's macroF1: 0.856148
# [561]	valid_0's binary_logloss: 0.149173	valid_0's macroF1: 0.858345
# [562]	valid_0's binary_logloss: 0.149144	valid_0's macroF1: 0.858345
# [563]	valid_0's binary_logloss: 0.149138	valid_0's macroF1: 0.858345
# [564]	valid_0's binary_logloss: 0.149133	valid_0's macroF1: 0.858345
# [565]	valid_0's binary_logloss: 0.14909	valid_0's macroF1: 0.858345
# [566]	valid_0's binary_logloss: 0.149073	valid_0's macroF1: 0.858345
# [567]	valid_0's binary_logloss: 0.14903	valid_0's macroF1: 0.85699
# [568]	valid_0's binary_logloss: 0.149029	valid_0's macroF1: 0.85699
# [569]	valid_0's binary_logloss: 0.149032	valid_0's macroF1: 0.85699
# [570]	valid_0's binary_logloss: 0.14906	valid_0's macroF1: 0.85699
# [571]	valid_0's binary_logloss: 0.149079	valid_0's macroF1: 0.85699
# [572]	valid_0's binary_logloss: 0.149071	valid_0's macroF1: 0.858345
# [573]	valid_0's binary_logloss: 0.149065	valid_0's macroF1: 0.858345
# [574]	valid_0's binary_logloss: 0.149018	valid_0's macroF1: 0.858345
# [575]	valid_0's binary_logloss: 0.148998	valid_0's macroF1: 0.858345
# [576]	valid_0's binary_logloss: 0.149005	valid_0's macroF1: 0.858345
# [577]	valid_0's binary_logloss: 0.149016	valid_0's macroF1: 0.858345
# [578]	valid_0's binary_logloss: 0.148981	valid_0's macroF1: 0.858345
# [579]	valid_0's binary_logloss: 0.148977	valid_0's macroF1: 0.858345
# [580]	valid_0's binary_logloss: 0.148979	valid_0's macroF1: 0.856148
# [581]	valid_0's binary_logloss: 0.148993	valid_0's macroF1: 0.858345
# [582]	valid_0's binary_logloss: 0.148963	valid_0's macroF1: 0.858345
# [583]	valid_0's binary_logloss: 0.148972	valid_0's macroF1: 0.857502
# [584]	valid_0's binary_logloss: 0.148963	valid_0's macroF1: 0.857502
# [585]	valid_0's binary_logloss: 0.14897	valid_0's macroF1: 0.857502
# [586]	valid_0's binary_logloss: 0.148942	valid_0's macroF1: 0.857502
# [587]	valid_0's binary_logloss: 0.148947	valid_0's macroF1: 0.857502
# [588]	valid_0's binary_logloss: 0.148923	valid_0's macroF1: 0.857502
# [589]	valid_0's binary_logloss: 0.148895	valid_0's macroF1: 0.857502
# [590]	valid_0's binary_logloss: 0.148903	valid_0's macroF1: 0.856148
# [591]	valid_0's binary_logloss: 0.148923	valid_0's macroF1: 0.857502
# [592]	valid_0's binary_logloss: 0.148906	valid_0's macroF1: 0.856148
# [593]	valid_0's binary_logloss: 0.148896	valid_0's macroF1: 0.856148
# [594]	valid_0's binary_logloss: 0.14891	valid_0's macroF1: 0.856148
# [595]	valid_0's binary_logloss: 0.148884	valid_0's macroF1: 0.854789
# [596]	valid_0's binary_logloss: 0.148901	valid_0's macroF1: 0.854789
# [597]	valid_0's binary_logloss: 0.148931	valid_0's macroF1: 0.856148
# [598]	valid_0's binary_logloss: 0.14894	valid_0's macroF1: 0.856148
# [599]	valid_0's binary_logloss: 0.148905	valid_0's macroF1: 0.856148
# [600]	valid_0's binary_logloss: 0.14889	valid_0's macroF1: 0.856148
# [601]	valid_0's binary_logloss: 0.148861	valid_0's macroF1: 0.854789
# [602]	valid_0's binary_logloss: 0.148881	valid_0's macroF1: 0.856148
# [603]	valid_0's binary_logloss: 0.148879	valid_0's macroF1: 0.856148
# [604]	valid_0's binary_logloss: 0.148868	valid_0's macroF1: 0.854789
# [605]	valid_0's binary_logloss: 0.148855	valid_0's macroF1: 0.856148
# [606]	valid_0's binary_logloss: 0.148842	valid_0's macroF1: 0.854789
# [607]	valid_0's binary_logloss: 0.148809	valid_0's macroF1: 0.854789
# [608]	valid_0's binary_logloss: 0.1488	valid_0's macroF1: 0.854789
# [609]	valid_0's binary_logloss: 0.148807	valid_0's macroF1: 0.854789
# [610]	valid_0's binary_logloss: 0.148796	valid_0's macroF1: 0.854789
# [611]	valid_0's binary_logloss: 0.148819	valid_0's macroF1: 0.854789
# [612]	valid_0's binary_logloss: 0.148815	valid_0's macroF1: 0.854789
# [613]	valid_0's binary_logloss: 0.148802	valid_0's macroF1: 0.854789
# [614]	valid_0's binary_logloss: 0.148778	valid_0's macroF1: 0.856148
# [615]	valid_0's binary_logloss: 0.148773	valid_0's macroF1: 0.854789
# [616]	valid_0's binary_logloss: 0.148763	valid_0's macroF1: 0.85563
# [617]	valid_0's binary_logloss: 0.148758	valid_0's macroF1: 0.85563
# [618]	valid_0's binary_logloss: 0.148744	valid_0's macroF1: 0.85563
# [619]	valid_0's binary_logloss: 0.148708	valid_0's macroF1: 0.85563
# [620]	valid_0's binary_logloss: 0.148718	valid_0's macroF1: 0.854789
# [621]	valid_0's binary_logloss: 0.14873	valid_0's macroF1: 0.85563
# [622]	valid_0's binary_logloss: 0.148745	valid_0's macroF1: 0.85563
# [623]	valid_0's binary_logloss: 0.148698	valid_0's macroF1: 0.854789
# [624]	valid_0's binary_logloss: 0.148663	valid_0's macroF1: 0.854789
# [625]	valid_0's binary_logloss: 0.148683	valid_0's macroF1: 0.854789
# [626]	valid_0's binary_logloss: 0.148703	valid_0's macroF1: 0.854789
# [627]	valid_0's binary_logloss: 0.148717	valid_0's macroF1: 0.854789
# [628]	valid_0's binary_logloss: 0.148658	valid_0's macroF1: 0.854789
# [629]	valid_0's binary_logloss: 0.148657	valid_0's macroF1: 0.854789
# [630]	valid_0's binary_logloss: 0.148663	valid_0's macroF1: 0.854789
# [631]	valid_0's binary_logloss: 0.148689	valid_0's macroF1: 0.854789
# [632]	valid_0's binary_logloss: 0.148676	valid_0's macroF1: 0.854789
# [633]	valid_0's binary_logloss: 0.148684	valid_0's macroF1: 0.854789
# [634]	valid_0's binary_logloss: 0.148688	valid_0's macroF1: 0.85563
# [635]	valid_0's binary_logloss: 0.148701	valid_0's macroF1: 0.85563
# [636]	valid_0's binary_logloss: 0.148729	valid_0's macroF1: 0.85563
# [637]	valid_0's binary_logloss: 0.148658	valid_0's macroF1: 0.85563
# [638]	valid_0's binary_logloss: 0.148647	valid_0's macroF1: 0.85563
# [639]	valid_0's binary_logloss: 0.148646	valid_0's macroF1: 0.85563
# [640]	valid_0's binary_logloss: 0.148611	valid_0's macroF1: 0.85563
# [641]	valid_0's binary_logloss: 0.148555	valid_0's macroF1: 0.85563
# [642]	valid_0's binary_logloss: 0.148522	valid_0's macroF1: 0.856473
# [643]	valid_0's binary_logloss: 0.148553	valid_0's macroF1: 0.856473
# [644]	valid_0's binary_logloss: 0.148488	valid_0's macroF1: 0.856473
# [645]	valid_0's binary_logloss: 0.148471	valid_0's macroF1: 0.85563
# [646]	valid_0's binary_logloss: 0.148449	valid_0's macroF1: 0.856473
# [647]	valid_0's binary_logloss: 0.148432	valid_0's macroF1: 0.854789
# [648]	valid_0's binary_logloss: 0.148405	valid_0's macroF1: 0.854789
# [649]	valid_0's binary_logloss: 0.14838	valid_0's macroF1: 0.854789
# [650]	valid_0's binary_logloss: 0.148415	valid_0's macroF1: 0.854789
# [651]	valid_0's binary_logloss: 0.148375	valid_0's macroF1: 0.854789
# [652]	valid_0's binary_logloss: 0.148388	valid_0's macroF1: 0.854789
# [653]	valid_0's binary_logloss: 0.148386	valid_0's macroF1: 0.853425
# [654]	valid_0's binary_logloss: 0.148344	valid_0's macroF1: 0.854265
# [655]	valid_0's binary_logloss: 0.148324	valid_0's macroF1: 0.854265
# [656]	valid_0's binary_logloss: 0.148313	valid_0's macroF1: 0.854265
# [657]	valid_0's binary_logloss: 0.148277	valid_0's macroF1: 0.854265
# [658]	valid_0's binary_logloss: 0.148281	valid_0's macroF1: 0.85563
# [659]	valid_0's binary_logloss: 0.148252	valid_0's macroF1: 0.85563
# [660]	valid_0's binary_logloss: 0.148246	valid_0's macroF1: 0.85563
# [661]	valid_0's binary_logloss: 0.148251	valid_0's macroF1: 0.85563
# [662]	valid_0's binary_logloss: 0.148222	valid_0's macroF1: 0.85563
# [663]	valid_0's binary_logloss: 0.148226	valid_0's macroF1: 0.85563
# [664]	valid_0's binary_logloss: 0.148193	valid_0's macroF1: 0.85563
# [665]	valid_0's binary_logloss: 0.148141	valid_0's macroF1: 0.85563
# [666]	valid_0's binary_logloss: 0.148118	valid_0's macroF1: 0.856473
# [667]	valid_0's binary_logloss: 0.148117	valid_0's macroF1: 0.856473
# [668]	valid_0's binary_logloss: 0.148087	valid_0's macroF1: 0.856473
# [669]	valid_0's binary_logloss: 0.148082	valid_0's macroF1: 0.856473
# [670]	valid_0's binary_logloss: 0.148093	valid_0's macroF1: 0.856473
# [671]	valid_0's binary_logloss: 0.148095	valid_0's macroF1: 0.856473
# [672]	valid_0's binary_logloss: 0.148069	valid_0's macroF1: 0.856473
# [673]	valid_0's binary_logloss: 0.148056	valid_0's macroF1: 0.857319
# [674]	valid_0's binary_logloss: 0.148062	valid_0's macroF1: 0.857319
# [675]	valid_0's binary_logloss: 0.148027	valid_0's macroF1: 0.857319
# [676]	valid_0's binary_logloss: 0.14805	valid_0's macroF1: 0.857319
# [677]	valid_0's binary_logloss: 0.148049	valid_0's macroF1: 0.857319
# [678]	valid_0's binary_logloss: 0.148055	valid_0's macroF1: 0.857319
# [679]	valid_0's binary_logloss: 0.148065	valid_0's macroF1: 0.857319
# [680]	valid_0's binary_logloss: 0.14806	valid_0's macroF1: 0.857319
# [681]	valid_0's binary_logloss: 0.148082	valid_0's macroF1: 0.857319
# [682]	valid_0's binary_logloss: 0.148116	valid_0's macroF1: 0.857319
# [683]	valid_0's binary_logloss: 0.148149	valid_0's macroF1: 0.857319
# [684]	valid_0's binary_logloss: 0.148178	valid_0's macroF1: 0.857319
# [685]	valid_0's binary_logloss: 0.148136	valid_0's macroF1: 0.857319
# [686]	valid_0's binary_logloss: 0.148117	valid_0's macroF1: 0.857319
# [687]	valid_0's binary_logloss: 0.148069	valid_0's macroF1: 0.857319
# [688]	valid_0's binary_logloss: 0.148076	valid_0's macroF1: 0.857319
# [689]	valid_0's binary_logloss: 0.148026	valid_0's macroF1: 0.857319
# [690]	valid_0's binary_logloss: 0.148006	valid_0's macroF1: 0.855952
# [691]	valid_0's binary_logloss: 0.147961	valid_0's macroF1: 0.855952
# [692]	valid_0's binary_logloss: 0.147996	valid_0's macroF1: 0.857319
# [693]	valid_0's binary_logloss: 0.14798	valid_0's macroF1: 0.855952
# [694]	valid_0's binary_logloss: 0.147928	valid_0's macroF1: 0.855952
# [695]	valid_0's binary_logloss: 0.147908	valid_0's macroF1: 0.855952
# [696]	valid_0's binary_logloss: 0.147869	valid_0's macroF1: 0.855952
# [697]	valid_0's binary_logloss: 0.147894	valid_0's macroF1: 0.855952
# [698]	valid_0's binary_logloss: 0.147853	valid_0's macroF1: 0.855952
# [699]	valid_0's binary_logloss: 0.14785	valid_0's macroF1: 0.855952
# [700]	valid_0's binary_logloss: 0.147823	valid_0's macroF1: 0.855952
# [701]	valid_0's binary_logloss: 0.147806	valid_0's macroF1: 0.855952
# [702]	valid_0's binary_logloss: 0.147818	valid_0's macroF1: 0.855952
# [703]	valid_0's binary_logloss: 0.147798	valid_0's macroF1: 0.855952
# [704]	valid_0's binary_logloss: 0.14777	valid_0's macroF1: 0.855952
# [705]	valid_0's binary_logloss: 0.147754	valid_0's macroF1: 0.855952
# [706]	valid_0's binary_logloss: 0.14776	valid_0's macroF1: 0.8568
# [707]	valid_0's binary_logloss: 0.147747	valid_0's macroF1: 0.8568
# [708]	valid_0's binary_logloss: 0.147739	valid_0's macroF1: 0.8568
# [709]	valid_0's binary_logloss: 0.147729	valid_0's macroF1: 0.855952
# [710]	valid_0's binary_logloss: 0.147738	valid_0's macroF1: 0.855952
# [711]	valid_0's binary_logloss: 0.147759	valid_0's macroF1: 0.855952
# [712]	valid_0's binary_logloss: 0.147771	valid_0's macroF1: 0.855952
# [713]	valid_0's binary_logloss: 0.147777	valid_0's macroF1: 0.855952
# [714]	valid_0's binary_logloss: 0.14779	valid_0's macroF1: 0.8568
# [715]	valid_0's binary_logloss: 0.147806	valid_0's macroF1: 0.855952
# [716]	valid_0's binary_logloss: 0.147808	valid_0's macroF1: 0.855952
# [717]	valid_0's binary_logloss: 0.147818	valid_0's macroF1: 0.855107
# [718]	valid_0's binary_logloss: 0.147814	valid_0's macroF1: 0.855107
# [719]	valid_0's binary_logloss: 0.147779	valid_0's macroF1: 0.855952
# [720]	valid_0's binary_logloss: 0.147762	valid_0's macroF1: 0.855952
# [721]	valid_0's binary_logloss: 0.147766	valid_0's macroF1: 0.855952
# [722]	valid_0's binary_logloss: 0.147734	valid_0's macroF1: 0.855952
# [723]	valid_0's binary_logloss: 0.147766	valid_0's macroF1: 0.855952
# [724]	valid_0's binary_logloss: 0.147733	valid_0's macroF1: 0.855952
# [725]	valid_0's binary_logloss: 0.147745	valid_0's macroF1: 0.855952
# [726]	valid_0's binary_logloss: 0.147745	valid_0's macroF1: 0.855952
# [727]	valid_0's binary_logloss: 0.147729	valid_0's macroF1: 0.855952
# [728]	valid_0's binary_logloss: 0.147717	valid_0's macroF1: 0.855952
# [729]	valid_0's binary_logloss: 0.147699	valid_0's macroF1: 0.855952
# [730]	valid_0's binary_logloss: 0.147718	valid_0's macroF1: 0.855952
# [731]	valid_0's binary_logloss: 0.147717	valid_0's macroF1: 0.855952
# [732]	valid_0's binary_logloss: 0.147694	valid_0's macroF1: 0.855952
# [733]	valid_0's binary_logloss: 0.147681	valid_0's macroF1: 0.855952
# [734]	valid_0's binary_logloss: 0.147702	valid_0's macroF1: 0.855952
# [735]	valid_0's binary_logloss: 0.147719	valid_0's macroF1: 0.85765
# [736]	valid_0's binary_logloss: 0.147705	valid_0's macroF1: 0.8568
# [737]	valid_0's binary_logloss: 0.147676	valid_0's macroF1: 0.85765
# [738]	valid_0's binary_logloss: 0.147652	valid_0's macroF1: 0.85765
# [739]	valid_0's binary_logloss: 0.147631	valid_0's macroF1: 0.85765
# [740]	valid_0's binary_logloss: 0.147633	valid_0's macroF1: 0.85765
# [741]	valid_0's binary_logloss: 0.147628	valid_0's macroF1: 0.85765
# [742]	valid_0's binary_logloss: 0.147633	valid_0's macroF1: 0.85765
# [743]	valid_0's binary_logloss: 0.147669	valid_0's macroF1: 0.85765
# [744]	valid_0's binary_logloss: 0.147647	valid_0's macroF1: 0.85765
# [745]	valid_0's binary_logloss: 0.147692	valid_0's macroF1: 0.85765
# [746]	valid_0's binary_logloss: 0.147703	valid_0's macroF1: 0.85765
# [747]	valid_0's binary_logloss: 0.14774	valid_0's macroF1: 0.85765
# [748]	valid_0's binary_logloss: 0.14772	valid_0's macroF1: 0.85765
# [749]	valid_0's binary_logloss: 0.147714	valid_0's macroF1: 0.85765
# [750]	valid_0's binary_logloss: 0.147732	valid_0's macroF1: 0.85765
# [751]	valid_0's binary_logloss: 0.147742	valid_0's macroF1: 0.85765
# [752]	valid_0's binary_logloss: 0.147781	valid_0's macroF1: 0.85765
# [753]	valid_0's binary_logloss: 0.147779	valid_0's macroF1: 0.85765
# [754]	valid_0's binary_logloss: 0.14777	valid_0's macroF1: 0.85765
# [755]	valid_0's binary_logloss: 0.147746	valid_0's macroF1: 0.85765
# [756]	valid_0's binary_logloss: 0.147722	valid_0's macroF1: 0.85765
# Early stopping, best iteration is:
# [506]	valid_0's binary_logloss: 0.150355	valid_0's macroF1: 0.86104

# %%
predicted_y = model.predict(x_test)
train_pred_y = model.predict(x)

# %%
train_pred_y = model.predict(x)

# %%
print(); print(metrics.classification_report(y,train_pred_y))
print(); print(metrics.confusion_matrix(y, train_pred_y))

print(); print(metrics.classification_report(y_test, predicted_y))
print(); print(metrics.confusion_matrix(y_test, predicted_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      1345
#            1       0.99      0.99      0.99     12395
#
#     accuracy                           0.98     13740
#    macro avg       0.93      0.95      0.94     13740
# weighted avg       0.98      0.98      0.98     13740
#
#
# [[ 1225   120]
#  [  178 12217]]
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.78       336
#            1       0.97      0.98      0.98      3099
#
#     accuracy                           0.96      3435
#    macro avg       0.90      0.87      0.88      3435
# weighted avg       0.96      0.96      0.96      3435
#
#
# [[ 252   84]
#  [  55 3044]]

# %%
print(); print(metrics.classification_report(y,train_pred_y))
print(); print(metrics.confusion_matrix(y, train_pred_y))

# %% [markdown]
# <h2>Testing</h2>

# %%
test_set = pd.read_csv(data_path+'test.csv', index_col="tripid")

# %%
test_set['pickup_time'] = pd.to_datetime(test_set['pickup_time'], format="%m/%d/%Y %H:%M")
test_set['drop_time'] = pd.to_datetime(test_set['drop_time'], format="%m/%d/%Y %H:%M")

# %%
test_set = test_set.assign(timeOfDay=pd.cut(test_set.pickup_time.dt.hour,[-1, 8, 20, 24],labels=['dawn','day', 'night']))

# %%
test_set.loc[test_set['timeOfDay'] == 'day', 'isNormalCharge'] = 1
test_set.loc[test_set['timeOfDay'] != 'day', 'isNormalCharge'] = 0

# %%
durations = []
for index,row in test_set.iterrows():
  provided_duration = row['duration'] #first row of location.lat column here
  if math.isnan(provided_duration) or provided_duration <= 0 :
    time_dif = (row['drop_time'] - row['pickup_time']).seconds
    if(time_dif == 0):
        time_dif = np.nan
    durations.append(time_dif)
  else :  
    durations.append(provided_duration)

test_set.insert(4,"time_dif",durations)

# %%
new_column = []                    #empty column for distance
for index,row in test_set.iterrows():
  lat1 = row['pick_lat'] #first row of location.lat column here
  lon1 = row['pick_lon'] #first row of location.long column here
  lat2 = row['drop_lat'] #second row of location.lat column here
  lon2 = row['drop_lon'] #second row of location.long column here
  value = dist_from_coordinates(lat1, lon1, lat2, lon2)  #get the distance
  new_column.append(value)   #append the empty list with distance values

test_set.insert(4,"distance",new_column)

# %%
test_set['time_driven'] = test_set['duration']  - test_set['meter_waiting']

# %%
chargeperhours = []
for index,row in test_set.iterrows():
    if(row['meter_waiting'] == 0):
        chargeperhour = np.nan
    else:
        chargeperhour = (row['meter_waiting_fare'] / row['meter_waiting'] * 3600)
    chargeperhours.append(chargeperhour)

test_set.insert(4,'charge_per_hour',chargeperhours)

# %%
test_set['driving_fare'] = test_set['fare']  - test_set['meter_waiting_fare'] - test_set['additional_fare']

# %%
avgspeeds = []
for index,row in test_set.iterrows():
    if(row['time_driven'] == 0):
        avgspeed = np.nan    
    else:
        avgspeed = (row['distance'] / row['time_driven'] * 3600)
    avgspeeds.append(avgspeed)

test_set.insert(4,"avg_speed",avgspeeds)

# %%
costsperkm = []
for index,row in test_set.iterrows():
    if row['distance'] == 0:
        costperkm = np.nan
            
    else:
        costperkm = (row['driving_fare'] / row['distance'])
    costsperkm.append(costperkm)

test_set.insert(4,"cost_per_km",costsperkm)

# %%
test_features = test_set[training_columns]

# %%
test_features.isna().sum()
# Out:
# meter_waiting           0
# meter_waiting_fare      0
# fare                    0
# additional_fare         0
# distance                0
# cost_per_km            25
# avg_speed               9
# time_dif                0
# time_driven             0
# charge_per_hour       298
# driving_fare            0
# isNormalCharge          0
# pick_lat                0
# pick_lon                0
# drop_lat                0
# drop_lon                0
# dtype: int64

# %%
predicted_labels = model.predict(test_features)

# %%
predicted_labels_df = pd.DataFrame(predicted_labels )

# %%
sub_path =os.path.abspath(os.path.join(data_path+'/sample_submission.csv'))
submission_set = pd.read_csv(sub_path, index_col="tripid")

# %%
submission_set['prediction']= predicted_labels_df.values[:,0]

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "theNotebook = " + "'"+thename+"'";
# kernel.execute(command);

# %%
filename = '../../submissions/'+theNotebook+'/'+theNotebook+'_{%i}.csv'
dirname = '../../submissions/'+theNotebook
fileversion = 1

if not os.path.exists(dirname):
    os.makedirs(dirname)
while glob.glob(filename.replace('{%i}',str(fileversion))) :
    fileversion+=1
submission_set.to_csv(filename.replace('{%i}',str(fileversion)), index=True)
print("Completed!")
# Out:
# Completed!

# %%
submission_set['prediction'].value_counts()
# Out:
# 1    8022
# 0     554
# Name: prediction, dtype: int64

# %% [markdown]
# <h2>testing against others</h2>

# %%
sub_path =os.path.abspath(os.path.join('/home/madnisal/Documents/ML_Project/submissions/grid-lgbm/lgbm3_23.csv'))
submission_set = pd.read_csv(sub_path, index_col="tripid")

# %%
submission_set['prediction'].value_counts()
# Out:
# 1    8022
# 0     554
# Name: prediction, dtype: int64
